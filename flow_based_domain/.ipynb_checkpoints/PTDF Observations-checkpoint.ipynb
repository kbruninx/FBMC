# %%
import pandas as pd
import requests
import numpy as np
from datetime import datetime, timedelta

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
hubs = ['ALBE', 'ALDE', 'AT', 'BE', 'CZ', 'DE_LU', 'FR', 'HR', 'HU', 'NL', 'PL', 'RO', 'SI', 'SK']

start = datetime(2022, 9, 1).strftime('%Y-%m-%d')
#end = datetime(2022, 9, 2).strftime('%Y-%m-%d')
end = datetime(2023, 7, 31).strftime('%Y-%m-%d')

# %%
def retrieve_ptdf(fromDate, toDate):
    data = {
        'fromUtc': f'{fromDate}T00:00:00.000Z',
        'toUtc': f'{toDate}T23:00:00.000Z',
    }

    try:
        response = requests.post('https://publicationtool.jao.eu/core/api/data/preFinalComputation', json=data)
        response.raise_for_status()
    except requests.exceptions.HTTPError as err:
        print(err)
   
    return pd.DataFrame(response.json()['data'])

# %%
df_grid = pd.read_excel('../flow_based_domain/grid.xlsx', index_col=0)

# %%
# ZONAL PTDF and RAM
df_ptdf = retrieve_ptdf(start, end)

df_ptdf = df_ptdf.rename(columns={
    'dateTimeUtc': 'DateTime'
})
df_ptdf = df_ptdf.set_index('DateTime')
df_ptdf.index = pd.to_datetime(df_ptdf.index)
df_ptdf = df_ptdf.tz_localize(None)
df_ptdf = df_ptdf.reset_index()

df_ptdf = df_ptdf[df_ptdf.cneEic != 'NA']
df_ptdf = df_ptdf[[
    'DateTime', 'cneName', 'cneEic', 'tso', 'direction', 'substationFrom', 'substationTo', 'contingencies', 'fref', 'frm', 'ram', 'ptdf_ALBE', 'ptdf_ALDE', 'ptdf_AT', 'ptdf_BE', 'ptdf_CZ', 'ptdf_DE', 'ptdf_FR', 'ptdf_HR', 'ptdf_HU', 'ptdf_NL', 
    'ptdf_PL', 'ptdf_RO', 'ptdf_SI', 'ptdf_SK'
]]

display(df_ptdf)
#df_ptdf.to_excel("ptdf_z_raw.xlsx")
# Out:
#                   DateTime                        cneName            cneEic  \
# 0      2022-09-01 00:00:00  Ernsthofen 2 - Hausruck 203C   14T-220-0-0203CD
# 1      2022-09-01 00:00:00  Ernsthofen 2 - Hausruck 203C   14T-220-0-0203CD
# 2      2022-09-01 00:00:00      Wien Suedost - Gyoer 245   10T-AT-HU-00002U
# 3      2022-09-01 00:00:00         Neusiedl - Gyoer 246B   10T-AT-HU-00001W
# 4      2022-09-01 00:00:00         Neusiedl - Gyoer 246B   10T-AT-HU-00001W
# ...                    ...                            ...               ...
# 868750 2023-07-31 22:00:00              V.Dur - Levice 1   24T-V490-000000G
# 868751 2023-07-31 22:00:00         Krizovany - Sokolnice   10T-CZ-SK-00003U
# 868752 2023-07-31 22:00:00           Sokolnice - Stupava   10T-CZ-SK-00005Q
# 868753 2023-07-31 22:00:00  V.Kapusany - Mukachevo (WPS)   10T-SK-UA-00001W
# 868754 2023-07-31 22:00:00               Lemesany - Vola   24T-V409-000000P
#
#          tso direction  substationFrom substationTo  \
# 0        APG    DIRECT   Ernsthofen 2      Hausruck
# 1        APG  OPPOSITE   Ernsthofen 2      Hausruck
# 2        APG    DIRECT    Wien Suedost    Gyoer 245
# 3        APG    DIRECT        Neusiedl   Gyoer 246B
# 4        APG  OPPOSITE        Neusiedl   Gyoer 246B
# ...      ...       ...             ...          ...
# 868750  SEPS    DIRECT           V.Dur       Levice
# 868751  SEPS    DIRECT       Krizovany    Sokolnice
# 868752  SEPS  OPPOSITE         Stupava    Sokolnice
# 868753  SEPS  OPPOSITE  Velke Kapusany    Mukachevo
# 868754  SEPS  OPPOSITE        Lemesany         Vola
#
#                                             contingencies    fref    frm  \
# 0       [{'number': 1, 'branchName': 'St. Peter 2 - St...    44.0   30.0
# 1       [{'number': 1, 'branchName': 'St. Peter 2 - St...   -44.0   30.0
# 2       [{'number': 1, 'branchName': 'Gyor - Neusiedl'...    27.0   23.0
# 3       [{'number': 1, 'branchName': 'Gyor - Wien', 'b...    13.0   23.0
# 4       [{'number': 1, 'branchName': 'Gyor - Wien', 'b...   -13.0   23.0
# ...                                                   ...     ...    ...
# 868750  [{'number': 1, 'branchName': 'V.Dur - Levice 2...  1141.0  138.0
# 868751  [{'number': 1, 'branchName': 'Sokolnice - Stup...  -345.0  138.0
# 868752  [{'number': 1, 'branchName': 'Krizovany - Soko...   397.0  138.0
# 868753  [{'number': 1, 'branchName': 'Levice - God', '...  -834.0  108.0
# 868754  [{'number': 1, 'branchName': 'Levice - R.Sobot...  -485.0  111.0
#
#            ram  ptdf_ALBE  ptdf_ALDE  ptdf_AT  ptdf_BE  ptdf_CZ  ptdf_DE  \
# 0        439.0   -0.06186   -0.06238 -0.06499 -0.06181 -0.02490 -0.06303
# 1        341.0    0.06186    0.06238  0.06499  0.06181  0.02490  0.06303
# 2        146.0    0.02502    0.02502  0.03672  0.02504  0.02301  0.02519
# 3        155.0    0.02473    0.02472  0.03740  0.02476  0.02248  0.02487
# 4        267.0   -0.02473   -0.02472 -0.03740 -0.02476 -0.02248 -0.02487
# ...        ...        ...        ...      ...      ...      ...      ...
# 868750   675.0    0.16353    0.16380  0.17114  0.16339  0.19863  0.16430
# 868751  1398.0   -0.11835   -0.11909 -0.10337 -0.11773 -0.20596 -0.12024
# 868752  1029.0    0.11236    0.11313  0.09446  0.11166  0.19416  0.11430
# 868753  1295.0   -0.24754   -0.24855 -0.21776 -0.24606 -0.25153 -0.24989
# 868754  1090.0   -0.18872   -0.18962 -0.15677 -0.18730 -0.18061 -0.19077
#
#         ptdf_FR  ptdf_HR  ptdf_HU  ptdf_NL  ptdf_PL  ptdf_RO  ptdf_SI  ptdf_SK
# 0      -0.06025 -0.00273  0.00340 -0.06144 -0.02183  0.00010 -0.00259 -0.00200
# 1       0.06025  0.00273 -0.00340  0.06144  0.02183 -0.00010  0.00259  0.00200
# 2       0.02522  0.01195 -0.01617  0.02482  0.01430 -0.00085  0.02081  0.00497
# 3       0.02501  0.01253 -0.01655  0.02451  0.01386 -0.00089  0.02190  0.00451
# 4      -0.02501 -0.01253  0.01655 -0.02451 -0.01386  0.00089 -0.02190 -0.00451
# ...         ...      ...      ...      ...      ...      ...      ...      ...
# 868750  0.16272  0.09523  0.03287  0.16346  0.09478 -0.00817  0.13540  0.12834
# 868751 -0.11550 -0.03759  0.02868 -0.11869 -0.01992  0.00349 -0.05669  0.11466
# 868752  0.10922  0.03236 -0.03122  0.11284  0.02911 -0.00301  0.04934 -0.12228
# 868753 -0.24161 -0.11893 -0.07090 -0.24932 -0.34483  0.01144 -0.16778 -0.33622
# 868754 -0.18315 -0.08517 -0.06007 -0.19049 -0.30821  0.00856 -0.11974 -0.24497
#
# [834165 rows x 25 columns]

# %%
df_ptdf.to_excel("../cost_curves/data-july/ptdfs.xlsx")

# %%
df_ptdf_naive = df_ptdf.copy()
df_ptdf_naive.DateTime = pd.to_datetime(df_ptdf_naive.DateTime)
df_ptdf_naive.DateTime = df_ptdf_naive.DateTime + pd.Timedelta('1 day')
df_ptdf_naive.to_excel('../cost_curves/data-july/ptdf_z_naive.xlsx')

# %%
df_ptdf.columns = ['DateTime', 'name', 'eic', 'tso', 'direction', 'substation_from', 'substation_to', 'contingencies', 'fref', 'frm', 'ram'] + hubs
df_ptdf['contingencies'] = df_ptdf['contingencies'].apply(lambda c_list: list(filter(lambda c: c['elementType'] in ['Line', 'TieLine'], c_list)))

#df_ptdf_test = df_ptdf.copy()
#df_ptdf_test['contingencies_count'] = df_ptdf_test['contingencies'].apply(lambda c_list: len(c_list))
#display(df_ptdf_test[['ram', 'eic', 'tso', 'contingencies_count']].groupby(['eic', 'tso', 'contingencies_count']).count())
#display(df_ptdf_test)

# %%
# CONTINGENCY MAPPING

contingency_tsos = []
contingency_eics = []
contingency_names = []
contingency_obs_ids = []

for index, row in df_ptdf[df_ptdf.contingencies.map(len) > 0].iterrows():
    for cont in row['contingencies']:
        contingency_tsos.append(row['tso'])
        contingency_eics.append(cont['branchEic'])
        contingency_names.append(cont['branchName'])
        contingency_obs_ids.append(index)

# %%
df_contingencies = pd.DataFrame(
    [contingency_tsos, contingency_eics, contingency_names, contingency_obs_ids],
    index=['tso', 'eic', 'name', 'obs_id']
).T

df_contingencies_unique = df_contingencies.groupby(['tso', 'eic', 'name']).obs_id.apply(list).reset_index()

display(df_contingencies)
display(df_contingencies_unique)
# Out:
#          tso               eic                       name  obs_id
# 0        APG  28T000000000301K   400 kV Cirkovce - Podlog       5
# 1        APG  28T000000000301K   400 kV Cirkovce - Podlog       6
# 2        APG  11TD2L000000201H     Pirach - Pleinting 257       7
# 3        APG  14T-380-0-0440AX  Sarasdorf - Zurndorf 440A      10
# 4       ELIA  22T-BE-IN-LI018R      Lixhe - Gramme 380.11      18
# ...      ...               ...                        ...     ...
# 785370  SEPS  10T-CZ-SK-00003U      Krizovany - Sokolnice  868752
# 785371  SEPS  10T-CZ-SK-00003U     Sokolnice - Krizovany   868752
# 785372  SEPS  10T-HU-SK-00001T               Levice - God  868753
# 785373  SEPS  10T-HU-SK-00001T               Levice - God  868753
# 785374  SEPS  24T-V426-000000W          Levice - R.Sobota  868754
#
# [785375 rows x 4 columns]
#             tso               eic                            name  \
# 0       50HERTZ  10T-CZ-DE-00002U      Hradec - Rohrsdorf - V445
# 1       50HERTZ  10T-CZ-DE-00002U          Hradec - Rohrsdorf 445
# 2       50HERTZ  10T-CZ-DE-00003S      Hradec - Rohrsdorf - V446
# 3       50HERTZ  10T-CZ-DE-00003S          Hradec - Rohrsdorf 446
# 4       50HERTZ  10T-DE-PL-00001D      Hagenwerder - Mikulowa 568
# ..          ...               ...                             ...
# 923  TRANSNETBW  12T-000000142I-U          Pradella-Sils LN301360
# 924  TRANSNETBW  14T-220-0-0405CY         Meiningen - Werben 406C
# 925  TRANSNETBW  14T-221-0-0405BQ            Walgau - Werben 405B
# 926  TRANSNETBW  17T-FR-000000317  L 400kV N0 1 MUHLBACH-SIERENTZ
# 927  TRANSNETBW  17T-FR-000000333  L 400kV N0 2 MUHLBACH-SIERENTZ
#
#                                                 obs_id
# 0    [448484, 448590, 448695, 448799, 448903, 44920...
# 1    [448484, 448590, 448695, 448799, 448903, 44920...
# 2    [448483, 448589, 448694, 448798, 448902, 44920...
# 3    [448483, 448589, 448694, 448798, 448902, 44920...
# 4    [450432, 450535, 450649, 450769, 450870, 45271...
# ..                                                 ...
# 923  [476943, 477058, 477174, 477280, 477386, 47749...
# 924                       [37607, 38833, 38933, 39139]
# 925  [637, 872, 982, 1092, 1195, 1302, 1408, 1524, ...
# 926  [5465, 12932, 13246, 13357, 13456, 19944, 2526...
# 927  [5351, 5466, 5574, 5684, 5799, 5909, 8019, 129...
#
# [928 rows x 4 columns]

# %%
df_contingencies_unique = df_contingencies.groupby(['tso', 'eic', 'name']).obs_id.apply(list).reset_index()

for index, row in df_grid.iterrows():
    if row['tso'] == 'TENNET NL':
        df_grid.loc[index, 'tso'] = 'TENNETBV'
    if row['tso'] == 'Amprion GmbH':
        df_grid.loc[index, 'tso'] = 'AMPRION'
    if row['tso'] == 'TEL':
        df_grid.loc[index, 'tso'] = 'TRANSELECTRICA'
        

manual_tso = []
manual_eic = []
manual_name = []
for index, row in df_contingencies_unique.iterrows():
    if len(df_grid[(df_grid.tso == row['tso']) & (df_grid.eic == row['eic'])]) > 1:
        manual_tso.append(row['tso'])
        manual_eic.append(row['eic'])
        manual_name.append(row['name'])
    elif len(df_grid[(df_grid.tso == row['tso']) & (df_grid.eic == row['eic'])]) > 0:
        if len(df_grid[df_grid.eic == row['eic']]) > 1:
            if len(df_grid[(df_grid.eic == row['eic']) & (df_grid.name.str[:2].str.lower() == row['name'][:2].lower())]) > 0:
                df_contingencies_unique.loc[index, 'line_id'] = df_grid[(df_grid.eic == row['eic']) & (df_grid.name.str[:2].str.lower() == row['name'][:2].lower())].index[0]
            else:
                if len(df_grid[(df_grid.eic == row['eic']) & ~(df_grid.name.str[:2].str.lower() == row['name'].split('kV ')[-1][:2].lower())]) > 1:
                    print(row['tso'], row['eic'], row['name'].split('kV ')[-1])
                    if row['eic'] == '11T-D4-D7-00005O':
                        df_contingencies_unique.loc[index, 'line_id'] = 2589
                        print('Done')
                    if row['eic'] == '10T-HR-HU-000041':
                        df_contingencies_unique.loc[index, 'line_id'] = 2776 
                        print('Done')
                else:
                    df_contingencies_unique.loc[index, 'line_id'] = df_grid[(df_grid.eic == row['eic']) & ~(df_grid.name.str[:2].str.lower() == row['name'].split('kV ')[-1][:2].lower())].index[0]
        else:
            df_contingencies_unique.loc[index, 'line_id'] = df_grid[(df_grid.tso == row['tso']) & (df_grid.eic == row['eic'])].index[0]
        
df_manual_cont_selection = pd.DataFrame({
    "tso": manual_tso,
    "eic": manual_eic,
    "name": manual_name,
})

#df_manual_cont_selection.to_excel("manual_cont_selection.xlsx")
# Out:
# AMPRION 11T-D4-D7-00005O Voehringen - Dellmensingen DONAU W
# Done
# HOPS 10T-HR-HU-000033 Ernestinovo - Pecs 1
# HOPS 10T-HR-HU-000041 Ernestinovo - Pecs 2
# Done
# MAVIR 10T-HR-HU-000033 Ernestinovo - Pecs 1
# MAVIR 10T-HR-HU-000041 Ernestinovo - Pecs 2
# Done
# PSE 10T-DE-PL-000047 Krajnik - Vierraden 508
# TRANSNETBW 11T-D4-D7-00005O Voehringen - Dellmensingen DONAU W
# Done

# %%
df_manual_cont_selection_completed = pd.read_excel("manual_cont_selection_completed.xlsx", index_col=0)

for index, row in df_contingencies_unique.iterrows():
    if len(df_grid[(df_grid.tso == row['tso']) & (df_grid.eic == row['eic'])]) > 1:
        df_contingencies_unique.loc[index, 'line_id'] = df_manual_cont_selection_completed[
            (df_manual_cont_selection_completed.tso == row['tso']) &
            (df_manual_cont_selection_completed.eic == row['eic']) &
            (df_manual_cont_selection_completed.name == row['name'])
         ].iloc[0]['line_id']
        
df_contingencies_unique = df_contingencies_unique[~df_contingencies_unique.line_id.isna()]
df_contingencies_unique.line_id = df_contingencies_unique.line_id.astype(int)

df_ptdf['contingency_list'] = df_ptdf.contingencies.copy().apply(lambda x: []).astype(object)

for index, row in df_contingencies_unique.iterrows():
    for obs_id in row['obs_id']:
        df_ptdf.loc[obs_id, 'contingency_list'].append(row['line_id']) 
        
display(df_contingencies_unique[df_contingencies_unique.eic == '22T-BE-IN-LI019P'])
# Out:
#       tso               eic                                     name  \
# 457  ELIA  22T-BE-IN-LI019P  Y-Courcelles (-Gramme - Tergnee) 380.31
# 458  ELIA  22T-BE-IN-LI019P  Y-Gramme (-Courcelles - Tergnee) 380.31
# 459  ELIA  22T-BE-IN-LI019P   Y-Tergnee (-Courcelles -Gramme) 380.31
#
#                                                 obs_id  line_id
# 457  [4461, 5005, 6841, 7052, 7158, 7258, 7361, 746...      714
# 458  [4461, 5005, 6841, 7052, 7158, 7258, 7361, 746...      715
# 459  [4461, 5005, 6841, 7052, 7158, 7258, 7361, 746...      716

# %%
display(df_ptdf[(df_ptdf.contingencies.map(len) == 2) & (df_ptdf.contingency_list.map(len) == 1)])
# Out:
#                   DateTime                                       name  \
# 505636 2023-03-17 08:00:00                      Zaya - Sokolnice 243
# 506364 2023-03-17 15:00:00                      Zaya - Sokolnice 243
# 532706 2023-03-28 06:00:00                      Zaya - Sokolnice 243
# 532790 2023-03-28 07:00:00                      Zaya - Sokolnice 243
# 533454 2023-03-28 15:00:00                      Zaya - Sokolnice 243
# ...                    ...                                        ...
# 863394 2023-07-29 20:00:00             St. Peter 2 - Altheim 233_230
# 867293 2023-07-31 09:00:00  Y-Altheim (-Simbach - St. Peter) 233/230
# 867419 2023-07-31 10:00:00  Y-Altheim (-Simbach - St. Peter) 233/230
# 867538 2023-07-31 11:00:00  Y-Altheim (-Simbach - St. Peter) 233/230
# 867661 2023-07-31 12:00:00  Y-Altheim (-Simbach - St. Peter) 233/230
#
#                      eic         tso direction substation_from substation_to  \
# 505636  10T1001C--001215         APG    DIRECT            Zaya     Sokolnice
# 506364  10T1001C--001215         APG    DIRECT            Zaya     Sokolnice
# 532706  10T1001C--001215         APG    DIRECT            Zaya     Sokolnice
# 532790  10T1001C--001215         APG    DIRECT            Zaya     Sokolnice
# 533454  10T1001C--001215         APG    DIRECT            Zaya     Sokolnice
# ...                  ...         ...       ...             ...           ...
# 863394  10T-AT-DE-00001B         APG    DIRECT     St. Peter 2       Altheim
# 867293  11T0-0000-0984-D  TENNETGMBH    DIRECT         Altheim     Y Simbach
# 867419  11T0-0000-0984-D  TENNETGMBH    DIRECT         Altheim     Y Simbach
# 867538  11T0-0000-0984-D  TENNETGMBH    DIRECT         Altheim     Y Simbach
# 867661  11T0-0000-0984-D  TENNETGMBH    DIRECT         Altheim     Y Simbach
#
#                                             contingencies   fref   frm    ram  \
# 505636  [{'number': 1, 'branchName': 'Sokolnice - Zaya...    4.0  25.0  214.0
# 506364  [{'number': 1, 'branchName': 'Sokolnice - Zaya...  -24.0  25.0  222.0
# 532706  [{'number': 1, 'branchName': 'Sokolnice - Zaya...   99.0  25.0  191.0
# 532790  [{'number': 1, 'branchName': 'Sokolnice - Zaya...  106.0  25.0  165.0
# 533454  [{'number': 1, 'branchName': 'Sokolnice - Zaya...   78.0  25.0  183.0
# ...                                                   ...    ...   ...    ...
# 863394  [{'number': 1, 'branchName': 'St. Peter 2 - Si...  153.0  41.0  347.0
# 867293  [{'number': 1, 'branchName': 'St. Peter 2 - Si...  115.0  45.0  308.0
# 867419  [{'number': 1, 'branchName': 'St. Peter 2 - Si...  111.0  45.0  317.0
# 867538  [{'number': 1, 'branchName': 'St. Peter 2 - Si...  134.0  45.0  310.0
# 867661  [{'number': 1, 'branchName': 'St. Peter 2 - Si...  168.0  45.0  306.0
#
#            ALBE     ALDE       AT       BE       CZ    DE_LU       FR  \
# 505636 -0.01638 -0.01696  0.01309 -0.01605 -0.02622 -0.01698 -0.01421
# 506364 -0.01632 -0.01691  0.01311 -0.01600 -0.02613 -0.01693 -0.01413
# 532706 -0.01614 -0.01686  0.01653 -0.01579 -0.02621 -0.01665 -0.01371
# 532790 -0.01513 -0.01586  0.01762 -0.01478 -0.02533 -0.01565 -0.01268
# 533454 -0.01582 -0.01651  0.01662 -0.01548 -0.02579 -0.01630 -0.01348
# ...         ...      ...      ...      ...      ...      ...      ...
# 863394 -0.05000 -0.05091 -0.00089 -0.04926 -0.01756 -0.04897 -0.04702
# 867293  0.04406  0.04502 -0.02285  0.04323  0.01714  0.04313  0.04086
# 867419  0.04406  0.04502 -0.01532  0.04324  0.01712  0.04313  0.04085
# 867538  0.04401  0.04497 -0.01537  0.04319  0.01704  0.04308  0.04080
# 867661  0.04402  0.04497 -0.01536  0.04319  0.01702  0.04309  0.04080
#
#              HR       HU       NL       PL       RO       SI       SK  \
# 505636  0.00556  0.00007 -0.01721 -0.03720 -0.00083  0.00839 -0.01643
# 506364  0.00584  0.00030 -0.01731 -0.03703 -0.00070  0.00839 -0.01618
# 532706  0.00677  0.00015 -0.01713 -0.03656 -0.00098  0.01063 -0.01754
# 532790  0.00776  0.00064 -0.01600 -0.03574 -0.00097  0.01220 -0.01566
# 533454  0.00763  0.00034 -0.01661 -0.03613 -0.00070  0.01088 -0.01581
# ...         ...      ...      ...      ...      ...      ...      ...
# 863394  0.00009  0.00252 -0.05035 -0.01734  0.00011 -0.00055 -0.00209
# 867293 -0.00026 -0.00195  0.04446  0.01658 -0.00004 -0.00014  0.00307
# 867419 -0.00031 -0.00200  0.04447  0.01664 -0.00003 -0.00014  0.00302
# 867538 -0.00034 -0.00199  0.04443  0.01667 -0.00003 -0.00018  0.00300
# 867661 -0.00033 -0.00199  0.04443  0.01665 -0.00003 -0.00017  0.00293
#
#        contingency_list
# 505636           [2714]
# 506364           [2714]
# 532706           [2714]
# 532790           [2714]
# 533454           [2714]
# ...                 ...
# 863394           [2704]
# 867293           [2263]
# 867419           [2263]
# 867538           [2263]
# 867661           [2263]
#
# [150 rows x 26 columns]

# %%
for index, row in df_ptdf[df_ptdf.contingencies.map(len) == 2].iterrows():
    cont = row['contingency_list']
    if len(cont) > 0:
        if cont[0] == cont[1]:
            lines = df_grid[df_grid.eic == df_grid[df_grid.index == cont[0]].iloc[0]['eic']].index.to_list()
            if len(lines) > 1:
                df_ptdf.loc[index, 'contingency_list'] = [[lines[0]], [lines[1]]]
            else:
                df_ptdf.loc[index, 'contingency_list'] = [[lines[0]]]

display(df_ptdf)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 4
#       2 cont = row['contingency_list']
#       3 if len(cont) > 0:
# ----> 4     if cont[0] == cont[1]:
#       5         lines = df_grid[df_grid.eic == df_grid[df_grid.index == cont[0]].iloc[0]['eic']].index.to_list()
#       6         if len(lines) > 1:
#
# IndexError: list index out of range

# %%
for index, row in df_ptdf[df_ptdf.contingencies.map(len) > 2].iterrows():
    #df_ptdf.loc[index, 'contingency_list'] = 
    if len(row['contingency_list']) > 2:
        if row['contingency_list'][0] == row['contingency_list'][1]:
            df_ptdf.loc[index, 'contingency_list'] = [[row['contingency_list'][1]], [row['contingency_list'][2]], [row['contingency_list'][3]]]

# %%
df_ptdf['contingency_list'] = df_ptdf['contingency_list'].apply(sorted)
display(df_ptdf)
# Out:
#                   DateTime                           name               eic  \
# 0      2022-09-01 00:00:00  Ernsthofen 2 - Hausruck 203C   14T-220-0-0203CD
# 1      2022-09-01 00:00:00  Ernsthofen 2 - Hausruck 203C   14T-220-0-0203CD
# 2      2022-09-01 00:00:00      Wien Suedost - Gyoer 245   10T-AT-HU-00002U
# 3      2022-09-01 00:00:00         Neusiedl - Gyoer 246B   10T-AT-HU-00001W
# 4      2022-09-01 00:00:00         Neusiedl - Gyoer 246B   10T-AT-HU-00001W
# ...                    ...                            ...               ...
# 541476 2023-03-31 22:00:00         Krizovany - Sokolnice   10T-CZ-SK-00003U
# 541477 2023-03-31 22:00:00           Sokolnice - Stupava   10T-CZ-SK-00005Q
# 541478 2023-03-31 22:00:00  V.Kapusany - Mukachevo (WPS)   10T-SK-UA-00001W
# 541479 2023-03-31 22:00:00              Nosovice - Varin   10T-CZ-SK-00002W
# 541480 2023-03-31 22:00:00              Nosovice - Varin   10T-CZ-SK-00002W
#
#          tso direction substation_from substation_to  \
# 0        APG    DIRECT   Ernsthofen 2       Hausruck
# 1        APG  OPPOSITE   Ernsthofen 2       Hausruck
# 2        APG    DIRECT    Wien Suedost     Gyoer 245
# 3        APG    DIRECT        Neusiedl    Gyoer 246B
# 4        APG  OPPOSITE        Neusiedl    Gyoer 246B
# ...      ...       ...             ...           ...
# 541476  SEPS    DIRECT       Krizovany     Sokolnice
# 541477  SEPS  OPPOSITE         Stupava     Sokolnice
# 541478  SEPS  OPPOSITE  Velke Kapusany     Mukachevo
# 541479  SEPS  OPPOSITE       Nosovice         Varin
# 541480  SEPS  OPPOSITE       Nosovice         Varin
#
#                                             contingencies   fref    frm  \
# 0                                                      []   44.0   30.0
# 1                                                      []  -44.0   30.0
# 2                                                      []   27.0   23.0
# 3                                                      []   13.0   23.0
# 4                                                      []  -13.0   23.0
# ...                                                   ...    ...    ...
# 541476  [{'number': 1, 'branchName': 'Sokolnice - Stup... -373.0  138.0
# 541477  [{'number': 1, 'branchName': 'Krizovany - Soko...  450.0  138.0
# 541478  [{'number': 1, 'branchName': 'R.Sobota - Sajoi... -510.0  108.0
# 541479  [{'number': 1, 'branchName': 'Krizovany - Soko...  437.0  120.0
# 541480  [{'number': 1, 'branchName': 'Sokolnice - Stup...  446.0  120.0
#
#            ram     ALBE     ALDE       AT       BE       CZ    DE_LU       FR  \
# 0        439.0 -0.06186 -0.06238 -0.06499 -0.06181 -0.02490 -0.06303 -0.06025
# 1        341.0  0.06186  0.06238  0.06499  0.06181  0.02490  0.06303  0.06025
# 2        146.0  0.02502  0.02502  0.03672  0.02504  0.02301  0.02519  0.02522
# 3        155.0  0.02473  0.02472  0.03740  0.02476  0.02248  0.02487  0.02501
# 4        267.0 -0.02473 -0.02472 -0.03740 -0.02476 -0.02248 -0.02487 -0.02501
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 541476  1421.0 -0.12423 -0.12522 -0.10793 -0.12392 -0.18969 -0.12661 -0.12154
# 541477  1004.0  0.11961  0.12068  0.09994  0.11927  0.18129  0.12210  0.11665
# 541478  1388.0 -0.21769 -0.21902 -0.19030 -0.21719 -0.21745 -0.22024 -0.21368
# 541479  1179.0  0.15186  0.15387  0.09884  0.15112  0.15771  0.15581  0.14591
# 541480  1165.0  0.14659  0.14859  0.09318  0.14584  0.14929  0.15049  0.14065
#
#              HR       HU       NL       PL       RO       SI       SK  \
# 0      -0.00273  0.00340 -0.06144 -0.02183  0.00010 -0.00259 -0.00200
# 1       0.00273 -0.00340  0.06144  0.02183 -0.00010  0.00259  0.00200
# 2       0.01195 -0.01617  0.02482  0.01430 -0.00085  0.02081  0.00497
# 3       0.01253 -0.01655  0.02451  0.01386 -0.00089  0.02190  0.00451
# 4      -0.01253  0.01655 -0.02451 -0.01386  0.00089 -0.02190 -0.00451
# ...         ...      ...      ...      ...      ...      ...      ...
# 541476 -0.03307  0.01876 -0.12507 -0.07989  0.00276 -0.06246  0.06681
# 541477  0.02803 -0.02225  0.12060  0.08492 -0.00214  0.05525 -0.07919
# 541478 -0.11134 -0.09501 -0.21954 -0.29591  0.01699 -0.15569 -0.28346
# 541479  0.03331 -0.00911  0.15457  0.19936 -0.00316  0.05968 -0.06298
# 541480  0.03086 -0.00946  0.14931  0.19816 -0.00290  0.05569 -0.06422
#
#        contingency_list
# 0                    []
# 1                    []
# 2                    []
# 3                    []
# 4                    []
# ...                 ...
# 541476     [2731, 2815]
# 541477     [2722, 2814]
# 541478     [2781, 2810]
# 541479     [2722, 2814]
# 541480     [2731, 2815]
#
# [519477 rows x 26 columns]

# %%
df_ptdf = df_ptdf[df_ptdf.direction != 'NA']

all_eics = df_ptdf.eic.unique()
unique_eics = []
invalid_obs_eics = []
non_unique_eics = []

for eic in all_eics:
    num_cne = len(df_grid[df_grid.eic == eic])
    if num_cne == 0:
        invalid_obs_eics.append(eic)
    elif num_cne == 1:
        unique_eics.append(eic)
    else:
        non_unique_eics.append(eic)
        
print('Total:', len(all_eics))
print('Unique:', len(unique_eics))
print('Non-valid observed eics:', len(invalid_obs_eics))

df_ptdf_adj = df_ptdf[~df_ptdf.eic.isin(invalid_obs_eics)]
df_ptdf_adj['line_id'] = None

for index, row in df_grid.iterrows():
    if row['tso'] == 'TENNET NL':
        df_grid.loc[index, 'tso'] = 'TENNETBV'
    if row['tso'] == 'Amprion GmbH':
        df_grid.loc[index, 'tso'] = 'AMPRION'
    if row['tso'] == 'TEL':
        df_grid.loc[index, 'tso'] = 'TRANSELECTRICA'

for eic in unique_eics:
    line_name = df_grid[df_grid.eic == eic].iloc[0]['name']
    print(line_name)
    line_id = df_grid[df_grid.eic == eic].index[0]
    df_ptdf_adj.loc[df_ptdf_adj.eic == eic, 'line_id'] = line_id
    df_ptdf_adj.loc[
        (df_ptdf_adj.eic == eic) &
        (line_name[:2] != df_ptdf_adj.name.str[:2])
    , hubs] = -1 * df_ptdf_adj.loc[
        (df_ptdf_adj.eic == eic) &
        (line_name[:2] != df_ptdf_adj.name.str[:2])
    , hubs]

df_ptdf_non_unique_eic = df_ptdf[df_ptdf.eic.isin(non_unique_eics)].groupby(['eic', 'direction', 'tso']).head(1).sort_values(by=['eic'])

identified_pair_eic = []

identified_tielines_eic = []
tielines = []
remainder_eics = []

for eic in non_unique_eics:
    df_ptdf_nu_eic = df_ptdf_non_unique_eic[df_ptdf_non_unique_eic.eic == eic]
    
    for tso in df_ptdf_nu_eic.tso.unique():
        df_pair = df_ptdf_nu_eic[(df_ptdf_nu_eic.tso == tso)]
        df_pair_direct = df_pair[df_pair.direction == 'DIRECT']
        df_pair_opposite = df_pair[df_pair.direction == 'OPPOSITE']
        
        df_line = df_grid[(df_grid.eic == eic) & (df_grid.tso == tso)]
        if len(df_line) == 2: # duplicate because of two directions
            identified_pair_eic.append(eic)
            if df_line.iloc[0]['name'][:2] == df_pair_direct.iloc[0]['name'][:2]:
                df_ptdf_adj.loc[
                    (df_ptdf_adj.eic == eic) & 
                    (df_ptdf_adj.tso == tso) & 
                    (df_ptdf_adj.direction == 'DIRECT'), 'line_id'] = df_line.index[0]
            else:
                df_ptdf_adj.loc[
                    (df_ptdf_adj.eic == eic) & 
                    (df_ptdf_adj.tso == tso) & 
                    (df_ptdf_adj.direction == 'OPPOSITE'), 'line_id'] = df_line.index[0] 

            if df_line.iloc[1]['name'][:2] == df_pair_direct.iloc[0]['name'][:2]:
                df_ptdf_adj.loc[
                    (df_ptdf_adj.eic == eic) & 
                    (df_ptdf_adj.tso == tso) & 
                    (df_ptdf_adj.direction == 'DIRECT'), 'line_id'] = df_line.index[1]
            else:
                df_ptdf_adj.loc[
                    (df_ptdf_adj.eic == eic) & 
                    (df_ptdf_adj.tso == tso) & 
                    (df_ptdf_adj.direction == 'OPPOSITE'), 'line_id'] = df_line.index[1] 
        
        elif len(df_line) == 1: # it was duplicate because of two TSOs
            identified_tielines_eic.append(eic)
            df_ptdf_adj.loc[(df_ptdf_adj.eic == eic) & (df_ptdf_adj.tso == tso), 'line_id'] = df_line.index[0]

        else:
            remainder_eics.append(eic)
            
print('Identified pair EICs: ', len(identified_pair_eic))
print('Identified tieline EICs: ', len(identified_tielines_eic))
df_ptdf_non_unique_eic = df_ptdf_non_unique_eic[df_ptdf_non_unique_eic.eic.isin(remainder_eics)]

display(df_ptdf_non_unique_eic)

#for index, eic in enumerate(remainder_eic):
#    df_ptdf_adj.loc[(df_ptdf_adj.eic == eic) & (df_ptdf_adj.tso == remainder_tso[index]) & (df_ptdf_adj.direction == remainder_direction[index]), 'line_id'] = remainder_line_ids[index]
    
display(df_ptdf_adj[df_ptdf_adj.line_id.isna()])
# Out:
# Total: 372
# Unique: 202
# Non-valid observed eics: 77
# C:\Users\balaz\AppData\Local\Temp\ipykernel_22156\3132903498.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ptdf_adj['line_id'] = None
# Ernsthofen - Hausruck 203C
# Sarasdorf - Zurndorf 439A
# ACHENE – GRAMME 380.10
# GRAMME – LIXHE 380.11
# LIXHE – VAN EYCK 380.91
# Y-Simbach (-St. Peter - Altheim) 233/230
# Mittelbexbach - Uchtelfangen BLIES S
# Schmölln - Dresden/Süd 555
# Vierraden - Pasewalk 306
# Gonyu - Gyor
# Gyor - Oroszlany
# Felsozsolca - Sajoivanka
# RZESZOW-KROSNO ISKRZYNIA
# Paroseni - Targiu Jiu Nord
# Gabcikovo - P. Biskupice
# H. Zdana - Sucany
# V. Dur - Krizovany
# V. Dur - Levice
# Y-Simbach (-St. Peter - Altheim) 234/230
# Paffendorf - Rommerskirchen PAFFEN S
# St.Peter - Altheim 233/230
# Westtirol - Silz 414
# Y-Oberzier (-Paffendorf - Sechtem) SECHTM S
# Liter - Martonvasar
# Krimpen a/d IJssel-Geertruidenberg 380 W
# V. Dur - Levice
# Resita - Timisoara c1
# Portile de Fier - Resita c1
# Pulgar - Vieselbach 589
# Dunamenti - Oroszlany
# Borssele-Rilland 380 G
# Diemen-Lelystad 380 W
# Krimpen a/d IJssel-Breukelen Kortrijk 380 W
# Oostzaan-Diemen 380 G
# Hessenberg - Weissenbach 223
# Altheim - Sittling 220
# Lelystad-Ens 380 W
# Ens-Zwolle 380 W
# LIT 400kV N0 1 AVELIN - MASTAING
# Graustein - Preilack 542
# Tauern - Weissenbach 221
# Salzburg Elixhausen - Tauern 231A
# Vill - Thaur - Silz 273C
# Altheim - Sittling 219
# Buerstadt - Lambsheim BUERST W
# Rosegg - Villach Süd 267B
# Grossgartach - Kupferzell ws
# Kledering - Wien Suedost 228A
# Y-Engstlatt (-Oberjettingen - Pulverdingen) rt
# Zwolle-Hengelo 380 W
# St. Peter - Salzburg Elixhausen 455
# Niederstedem - Rommersheim NIMSTA O
# Rilland-Geertruidenberg 380 W
# Y-Mengede (-Huellen - Kusenhorst) WESTFL W
# Remptendorf - Röhrsdorf 574
# Remptendorf - Weida 575
# Diemen-Lelystad 380 Z
# Baru Mare - Hasdat
# Eemshaven - Eemshaven het Hogeland 380 Zwart
# Y-Niederlangen (-Doerpen/W - Meppen) EOWS
# Kriftel - Frankfurt TAUNUS 2
# Y-Rhede (-Doerpen/W - Diele) schwarz
# Breukelen Kortrijk-Diemen 380 W
# Y-Oberzier (-Dahlem - Niederstedem) SELHN W
# Y-Simbach (-Altheim - St. Peter) 233/230
# Y-Simbach (-Altheim - St. Peter) 234/230
# Y-Gersteinwerk (-Hanekenfaehr - Uentrop) UENTRO N
# Y-Gersteinwerk (-Guetersloh - Uentrop) GERSTE O
# Pfungstadt - Urberach (NEU) GRIESH O
# Duernrohr - Etzersdorf 434B
# Y-Voehringen (-Dellmensingen - Hoheneck) DONAU O
# Y-Hoheneck (-Dellmensingen - Voehringen) DONAU O
# Y-Oberzier (-Paffendorf - Sechtem) SECHTM N
# Bisamberg - Wien Suedost 227
# Y-Buerstadt (-Bischofsheim - Pfungstadt) RIED W
# Waldlaubersheim - Weissenthurm SOONWD W
# Lambsheim - Weingarten LAMBSH W
# Zaya - Sokolnice 243
# Bertikow - Pasewalk 305
# Y-Pulverdingen (-Engstlatt - Oberjettingen) rt
# Graustein - Bärwalde 565
# Maasbracht-Eindhoven 380 W
# 220 kV Brinje - VE Padene
# Gruenkraut - Obermooweiler bl
# Graustein - Preilack 541
# BUJAKOW-BYCZYNA
# Resita - Timisoara c2
# Geertruidenberg-Eindhoven 380 W
# Opladen - Rommerskirchen OPLADN N
# Y-Niederstedem (-Dahlem - Oberzier) SELHN W
# Gruenkraut - Herbertingen rt
# Y-Huellen (-Kusenhorst - Mengede) WESTFL W
# Hessenberg - Ternitz 225A
# Sechtem - Weissenthurm MITREI
# Paffendorf - Rommerskirchen PAFFEN N
# Rommerskirchen - Sechtem VILLE O
# 400 kV Zerjavinec - Tumbri 477
# Zwolle-Hengelo 380 Z
# 400 kV Tumbri - Melina 456
# DOEL – ZANDVLIET 380.26
# Y-Bischofsheim (-Buerstadt - Pfungstadt) RIED W
# Vill - Thaur - Silz 274C
# Y-Ohlensehlen (-St. Huelfe - Wehrendorf) DUEMM S1
# Diele - Doerpen/W gelb
# St.Peter - Simbach 234/230
# POLANIEC-TARNOW
# Bertikow - Neuenhagen303
# Conneforde/O - Unterweser gelb
# Bärwalde - Schmölln 551
# Niederstedem - Osburg GILZEM O
# Grossgartach - Pulverdingen ws
# St. Peter - Rommerskirchen PETER S
# Conneforde - Diele rot
# Conneforde - Diele weiss
# Hessenberg - Weissenbach 224
# TARNOW-KROSNO ISKRZYNIA
# Gyor - Liter
# Röhrsdorf - Weida 573
# Osburg - Uchtelfangen UCHTLF O
# Knapsack - Sechtem WABERG W
# Bisamberg - Duernrohr 436A
# Y-Paffendorf (-Oberzier - Sechtem) SECHTM S
# Grossgartach - Pulverdingen rt
# Albertirsa - Martonvasar
# Albertirsa - Szigetcsep
# Obersielach - Zeltweg 285
# Zaya - Sokolnice 244
# Krizovany - P. Biskupice
# Lemesany - Vola
# DOEL – ZANDVLIET 380.25
# Prestice - Kocin
# Hessenberg - Zeltweg 287
# Eiberg - Huellen HUELLN W
# Hoepfingen - Hueffenhardt ge
# Bacharach - Weissenthurm SOONWD O
# Dodewaard-Doetinchem 380 Z
# Martonvasar - Szigetcsep
# Doetinchem-Hengelo 380 W
# Doetinchem-Hengelo 380 Z
# Dodewaard-Doetinchem 380 W
# Bleiswijk-Vijfhuizen 380 O
# Paks - Sandorfalva
# Rommerskirchen - Sechtem VILLE W
# Y-Paffendorf (-Oberzier - Sechtem) SECHTM N
# Feistritz - Obersielach 268
# God - Sajoszoged
# Borssele-Rilland 380 Z
# Oststeiermark - Wien Suedost 477
# Y-Sechtem (-Oberzier - Paffendorf) SECHTM N
# Y-Sechtem (-Oberzier - Paffendorf) SECHTM S
# Maasbracht-Eindhoven 380 Z
# Hoheneck - Rheinau KUGELB O
# Bicske Del - Gonyu
# Ernsthofen - Sattledt 204C
# Bicske Del - Martonvasar
# Y-Oberzier (-Dahlem - Rommersheim) SELHN O
# DOBRZEN-WROCLAW
# Bleiswijk-Vijfhuizen 380 P
# Neuenhagen - Vierraden 304
# Westtirol - Silz 413
# LIT 400kV N0 1 HOUDREVILLE - VINCEY
# Albertirsa - Kerepes
# Rilland-Geertruidenberg 380 Z
# Paks - Pecs 1
# KOPANINA-WIELOPOLE
# Vieselbach - Altenfeld 467
# Hagenwerder - Schmölln 553
# Lienz - Villach Süd 267A
# Kriftel - Limburg HESSEN O
# Streumen - Röhrsdorf 571
# Y-Mittelbexbach (-Lambsheim - Otterbach) KAILAU N
# Sarasdorf - Zurndorf 440A
# Wateringen-Bleiswijk 380 Z
# Bischofsheim - Kriftel TREBUR S
# Sajoszoged - Felsozsolca I.
# Schmölln - Dresden/Süd 556
# Hausruck - Sattledt 204B
# Y-Lambsheim (-Mittelbexbach - Otterbach) KAILAU N
# 220 kV Zakucac - Konjsko 274
# Suedburgenland - Wien Suedost 478
# Paks - Perkata
# Isar - Pleinting 451
# Meckenheim - Sechtem BGEIST W
# Gheorgheni - Stejaru
# Sarasdorf - Wien Suedost 443D
# Etzersdorf - Kronstorf 434A
# Etzenricht - Schwandorf 457
# Obersielach - Rosegg 267C
# Y-Opladen (-Eiberg - Ohligs) OERKHS O
# Eemshaven-Meeden 380 W
# DOEL – MERCATOR 380.54
# Ernsthofen - Klaus 201B
# Y-Plattling (-Schwandorf - Pleinting) 465
# Phyrn - Weissenbach 201A
# Oberbachern - Oberbrunn 269
# Oberbachern - Oberbrunn 270
# Y-Rommersheim (-Dahlem - Oberzier) SELHN O
# Lauchstädt - Vieselbach 471
# Salzburg Elixhausen - Tauern 232A
# Y-Wehrendorf (-Ohlensehlen - St. Huelfe) DUEMM S1
# Portile de Fier - Resita c2
# Hoheneck - Rheinau KUGELB W
# Identified pair EICs:  0
# Identified tieline EICs:  131
#                   DateTime                                         name  \
# 218013 2022-11-24 08:00:00           Y-Mercator (-Doel - Lillo) 380.51
# 373991 2023-01-24 03:00:00           Y-Doel (-Lillo - Mercator) 380.52
# 626    2022-09-01 05:00:00           Y-Mercator (-Doel - Lillo) 380.52
# 39026  2022-09-16 12:00:00     Y-Gramme (-Courcelles - Tergnee) 380.31
# 217694 2022-11-24 05:00:00    Y-Mercator (-Horta  - Rodenhuize) 380.73
# 210750 2022-11-21 14:00:00     Y-Horta (-Mercator - Rodenhuize) 380.73
# 198065 2022-11-16 20:00:00    Y-Mercator (-Horta  - Rodenhuize) 380.74
# 429540 2023-02-15 05:00:00    Y-Mercator (-Horta  - Rodenhuize) 380.74
# 267    2022-09-01 02:00:00  Y-Van Eyck (-Andre Dumont - Gramme) 380.12
# 18     2022-09-01 00:00:00  Y-Gramme (-Andre Dumont - Van Eyck) 380.12
#
#                      eic   tso direction substation_from substation_to  \
# 218013  22T-BE-IN-LI014Z  ELIA  OPPOSITE        Mercator  Liefkenshoek
# 373991  22T-BE-IN-LI015X  ELIA    DIRECT            Doel  Liefkenshoek
# 626     22T-BE-IN-LI015X  ELIA  OPPOSITE        Mercator         Kallo
# 39026   22T-BE-IN-LI019P  ELIA    DIRECT          Gramme   Saint Amand
# 217694  22T20161020---2C  ELIA  OPPOSITE        Mercator    Rodenhuize
# 210750  22T20161020---2C  ELIA    DIRECT           Horta    Rodenhuize
# 198065  22T20161020---3A  ELIA  OPPOSITE        Mercator    Rodenhuize
# 429540  22T20161020---3A  ELIA    DIRECT        Mercator    Rodenhuize
# 267     22T20161020---48  ELIA  OPPOSITE        Van Eyck    Zuttendaal
# 18      22T20161020---48  ELIA    DIRECT          Gramme    Zuttendaal
#
#                                             contingencies    fref    frm  \
# 218013  [{'number': 1, 'branchName': 'Doel - Zandvliet...  1039.0   68.0
# 373991  [{'number': 1, 'branchName': 'Doel - Zandvliet...  1468.0   73.0
# 626     [{'number': 1, 'branchName': 'Doel - Mercator ...  1350.0   73.0
# 39026                                                  []   361.0  139.0
# 217694  [{'number': 1, 'branchName': 'Y-Mercator (-Hor...   284.0  188.0
# 210750  [{'number': 1, 'branchName': 'Y-Mercator (-Hor...  1633.0  188.0
# 198065  [{'number': 1, 'branchName': 'Y-Mercator (-Hor...   657.0  188.0
# 429540                                                 []   400.0  188.0
# 267     [{'number': 1, 'branchName': 'Lixhe - Gramme 3...   558.0  150.0
# 18      [{'number': 1, 'branchName': 'Lixhe - Gramme 3...   558.0  150.0
#
#            ram     ALBE     ALDE       AT       BE       CZ    DE_LU       FR  \
# 218013  1015.0 -0.07687  0.04123 -0.00579 -0.17680  0.00750  0.02260 -0.08939
# 373991   951.0 -0.08411  0.02233 -0.01350 -0.16905 -0.00192  0.00997 -0.08757
# 626      651.0 -0.05140  0.01479 -0.00286 -0.14117  0.00384  0.00921 -0.03562
# 39026    308.0  0.08956 -0.00906  0.00203 -0.04200 -0.00146 -0.00447  0.02067
# 217694  1525.0 -0.08971 -0.05940  0.00608  0.02369 -0.00952 -0.02574  0.12815
# 210750  1428.0 -0.08927 -0.05794  0.00144 -0.04404 -0.00920 -0.02621  0.11675
# 198065  1512.0 -0.08414 -0.05675  0.00644  0.02745 -0.00991 -0.02016  0.12591
# 429540     3.0  0.15806  0.07222 -0.00759  0.03349  0.01144  0.03014 -0.14756
# 267     1004.0 -0.09548 -0.03370  0.00127  0.20473 -0.00572 -0.01158  0.04929
# 18       995.0 -0.11957 -0.03186  0.00123  0.19074 -0.00547 -0.01111  0.04717
#
#              HR       HU       NL       PL       RO       SI       SK  \
# 218013 -0.00402  0.00144  0.16344  0.00968  0.00047 -0.00740  0.00379
# 373991 -0.01150 -0.00705  0.17886  0.00027 -0.00785 -0.01418 -0.00489
# 626    -0.00177  0.00052  0.06122  0.00452  0.00016 -0.00307  0.00164
# 39026   0.00157  0.00010 -0.03743 -0.00205  0.00026  0.00226 -0.00050
# 217694  0.00480 -0.00169 -0.12351 -0.01183 -0.00037  0.00807 -0.00472
# 210750  0.00439 -0.00164 -0.11337 -0.01120 -0.00041  0.00760 -0.00474
# 198065  0.00469 -0.00183 -0.11558 -0.01201 -0.00055  0.00797 -0.00499
# 429540 -0.00625  0.00214  0.13855  0.01385  0.00043 -0.01006  0.00560
# 267     0.00286 -0.00100 -0.03735 -0.00645 -0.00023  0.00357 -0.00264
# 18      0.00272 -0.00096 -0.03748 -0.00620 -0.00022  0.00341 -0.00254
#
#        contingency_list
# 218013            [656]
# 373991            [656]
# 626               [657]
# 39026                []
# 217694  [667, 682, 701]
# 210750  [667, 682, 701]
# 198065  [725, 726, 727]
# 429540               []
# 267               [711]
# 18                [711]
#                   DateTime                                         name  \
# 18     2022-09-01 00:00:00  Y-Gramme (-Andre Dumont - Van Eyck) 380.12
# 139    2022-09-01 01:00:00  Y-Gramme (-Andre Dumont - Van Eyck) 380.12
# 267    2022-09-01 02:00:00  Y-Van Eyck (-Andre Dumont - Gramme) 380.12
# 384    2022-09-01 03:00:00  Y-Van Eyck (-Andre Dumont - Gramme) 380.12
# 508    2022-09-01 04:00:00  Y-Van Eyck (-Andre Dumont - Gramme) 380.12
# ...                    ...                                          ...
# 534679 2023-03-29 04:00:00  Y-Gramme (-Andre Dumont - Van Eyck) 380.12
# 534898 2023-03-29 06:00:00  Y-Gramme (-Andre Dumont - Van Eyck) 380.12
# 534899 2023-03-29 06:00:00  Y-Gramme (-Andre Dumont - Van Eyck) 380.12
# 535098 2023-03-29 08:00:00  Y-Gramme (-Andre Dumont - Van Eyck) 380.12
# 535886 2023-03-29 16:00:00  Y-Gramme (-Andre Dumont - Van Eyck) 380.12
#
#                      eic   tso direction substation_from substation_to  \
# 18      22T20161020---48  ELIA    DIRECT          Gramme    Zuttendaal
# 139     22T20161020---48  ELIA    DIRECT          Gramme    Zuttendaal
# 267     22T20161020---48  ELIA  OPPOSITE        Van Eyck    Zuttendaal
# 384     22T20161020---48  ELIA  OPPOSITE        Van Eyck    Zuttendaal
# 508     22T20161020---48  ELIA  OPPOSITE        Van Eyck    Zuttendaal
# ...                  ...   ...       ...             ...           ...
# 534679  22T20161020---48  ELIA    DIRECT          Gramme    Zuttendaal
# 534898  22T20161020---48  ELIA    DIRECT          Gramme    Zuttendaal
# 534899  22T20161020---48  ELIA    DIRECT          Gramme    Zuttendaal
# 535098  22T20161020---48  ELIA    DIRECT          Gramme    Zuttendaal
# 535886  22T20161020---48  ELIA    DIRECT          Gramme    Zuttendaal
#
#                                             contingencies   fref    frm  \
# 18      [{'number': 1, 'branchName': 'Lixhe - Gramme 3...  558.0  150.0
# 139     [{'number': 1, 'branchName': 'Lixhe - Gramme 3...  636.0  150.0
# 267     [{'number': 1, 'branchName': 'Lixhe - Gramme 3...  558.0  150.0
# 384     [{'number': 1, 'branchName': 'Lixhe - Gramme 3...  584.0  150.0
# 508     [{'number': 1, 'branchName': 'Lixhe - Gramme 3...  475.0  150.0
# ...                                                   ...    ...    ...
# 534679  [{'number': 1, 'branchName': 'Lixhe - Gramme 3...   61.0  150.0
# 534898  [{'number': 1, 'branchName': 'Lixhe - Gramme 3...   82.0  150.0
# 534899  [{'number': 1, 'branchName': 'Lixhe - Van Eyck...  116.0  150.0
# 535098  [{'number': 1, 'branchName': 'Lixhe - Gramme 3... -104.0  150.0
# 535886  [{'number': 1, 'branchName': 'Lixhe - Gramme 3...  516.0  150.0
#
#            ram     ALBE     ALDE       AT       BE       CZ    DE_LU       FR  \
# 18       995.0 -0.11957 -0.03186  0.00123  0.19074 -0.00547 -0.01111  0.04717
# 139      989.0 -0.11878 -0.03211  0.00125  0.19328 -0.00556 -0.01130  0.04783
# 267     1004.0 -0.09548 -0.03370  0.00127  0.20473 -0.00572 -0.01158  0.04929
# 384     1012.0 -0.09549 -0.03371  0.00127  0.20472 -0.00572 -0.01160  0.04914
# 508     1077.0 -0.09544 -0.03366  0.00128  0.20477 -0.00572 -0.01267  0.04945
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 534679  1035.0 -0.05135 -0.04097  0.00298  0.15441 -0.00502 -0.01543  0.05996
# 534898  1065.0 -0.05337 -0.04449  0.00368  0.15331 -0.00549 -0.01734  0.06111
# 534899  1085.0  0.22871 -0.04848  0.00402  0.17090 -0.00597 -0.01888  0.06619
# 535098  1078.0 -0.05211 -0.04490  0.00424  0.15821 -0.00555 -0.01760  0.06239
# 535886   973.0 -0.05161 -0.04114  0.00335  0.15374 -0.00503 -0.01563  0.06011
#
#              HR       HU       NL       PL       RO       SI       SK  \
# 18      0.00272 -0.00096 -0.03748 -0.00620 -0.00022  0.00341 -0.00254
# 139     0.00277 -0.00097 -0.03926 -0.00630 -0.00022  0.00347 -0.00259
# 267     0.00286 -0.00100 -0.03735 -0.00645 -0.00023  0.00357 -0.00264
# 384     0.00285 -0.00100 -0.03741 -0.00643 -0.00023  0.00356 -0.00251
# 508     0.00282 -0.00098 -0.03934 -0.00638 -0.00024  0.00358 -0.00251
# ...         ...      ...      ...      ...      ...      ...      ...
# 534679  0.00252 -0.00101 -0.04018 -0.00831 -0.00037  0.00468 -0.00266
# 534898  0.00315 -0.00127 -0.03530 -0.00885 -0.00044  0.00523 -0.00302
# 534899  0.00342 -0.00138 -0.03848 -0.00963 -0.00048  0.00569 -0.00329
# 535098  0.00336 -0.00130 -0.03684 -0.00894 -0.00045  0.00531 -0.00303
# 535886  0.00268 -0.00097 -0.03258 -0.00837 -0.00032  0.00477 -0.00267
#
#        contingency_list line_id
# 18                [711]    None
# 139               [711]    None
# 267               [711]    None
# 384               [711]    None
# 508               [711]    None
# ...                 ...     ...
# 534679            [711]    None
# 534898            [711]    None
# 534899            [712]    None
# 535098            [711]    None
# 535886            [711]    None
#
# [857 rows x 27 columns]

# %%
remainder_eic = [
    '22T-BE-IN-LI014Z', 
    '22T-BE-IN-LI015X', 
    '22T-BE-IN-LI019P',
    '22T20161020---2C',
    '22T20161020---3A', 
    '22T20161020---48',
]

#df_ptdf_remainder_combinations = df_ptdf[df_ptdf.eic.isin(remainder_eic)].groupby(['eic', 'direction', 'tso', 'substation_from', 'substation_to']).head(1).sort_values(by=['eic'])
#df_ptdf_remainder_combinations[['name', 'eic', 'tso', 'substation_from', 'substation_to']].to_excel('eic_manual_completion.xlsx')

# %%
df_ptdf_remainder_filled = pd.read_excel('eic_manual_completion.xlsx', index_col=0)

for index, row in df_ptdf_remainder_filled.iterrows():
    df_ptdf_adj.loc[
        (df_ptdf_adj.eic == row['eic']) & 
        (df_ptdf_adj.tso == row['tso']) & 
        (df_ptdf_adj.substation_from == row['substation_from']) &
        (df_ptdf_adj.substation_to == row['substation_to']), 'line_id'] = row['line_id']
    
df_ptdf_adj['direction'] = df_ptdf_adj['direction'].apply(lambda x: (1 if x == 'DIRECT' else -1))
df_ptdf_adj = df_ptdf_adj[['DateTime', 'line_id', 'direction', 'contingency_list', 'fref', 'frm', 'ram'] + hubs]

display(df_ptdf_adj)
#df_ptdf_adj.to_excel("ptdf_z.xlsx")
# Out:
# C:\Users\balaz\AppData\Local\Temp\ipykernel_22156\2877616142.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ptdf_adj['direction'] = df_ptdf_adj['direction'].apply(lambda x: (1 if x == 'DIRECT' else -1))
#                   DateTime line_id  direction contingency_list    fref    frm  \
# 0      2022-09-01 00:00:00     493          1               []    44.0   30.0
# 1      2022-09-01 00:00:00     493         -1               []   -44.0   30.0
# 2      2022-09-01 00:00:00    2710          1               []    27.0   23.0
# 3      2022-09-01 00:00:00    2699          1               []    13.0   23.0
# 4      2022-09-01 00:00:00    2699         -1               []   -13.0   23.0
# ...                    ...     ...        ...              ...     ...    ...
# 541475 2023-03-31 22:00:00    2036          1           [2039]  1113.0  138.0
# 541476 2023-03-31 22:00:00    2814          1     [2731, 2815]  -373.0  138.0
# 541477 2023-03-31 22:00:00    2815         -1     [2722, 2814]   450.0  138.0
# 541479 2023-03-31 22:00:00    2813         -1     [2722, 2814]   437.0  120.0
# 541480 2023-03-31 22:00:00    2813         -1     [2731, 2815]   446.0  120.0
#
#            ram     ALBE     ALDE       AT       BE       CZ    DE_LU       FR  \
# 0        439.0 -0.06186 -0.06238 -0.06499 -0.06181 -0.02490 -0.06303 -0.06025
# 1        341.0  0.06186  0.06238  0.06499  0.06181  0.02490  0.06303  0.06025
# 2        146.0  0.02502  0.02502  0.03672  0.02504  0.02301  0.02519  0.02522
# 3        155.0  0.02473  0.02472  0.03740  0.02476  0.02248  0.02487  0.02501
# 4        267.0 -0.02473 -0.02472 -0.03740 -0.02476 -0.02248 -0.02487 -0.02501
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 541475   410.0  0.16091  0.16134  0.16359  0.16079  0.18497  0.16210  0.15977
# 541476  1421.0 -0.12423 -0.12522 -0.10793 -0.12392 -0.18969 -0.12661 -0.12154
# 541477  1004.0  0.11961  0.12068  0.09994  0.11927  0.18129  0.12210  0.11665
# 541479  1179.0  0.15186  0.15387  0.09884  0.15112  0.15771  0.15581  0.14591
# 541480  1165.0  0.14659  0.14859  0.09318  0.14584  0.14929  0.15049  0.14065
#
#              HR       HU       NL       PL       RO       SI       SK
# 0      -0.00273  0.00340 -0.06144 -0.02183  0.00010 -0.00259 -0.00200
# 1       0.00273 -0.00340  0.06144  0.02183 -0.00010  0.00259  0.00200
# 2       0.01195 -0.01617  0.02482  0.01430 -0.00085  0.02081  0.00497
# 3       0.01253 -0.01655  0.02451  0.01386 -0.00089  0.02190  0.00451
# 4      -0.01253  0.01655 -0.02451 -0.01386  0.00089 -0.02190 -0.00451
# ...         ...      ...      ...      ...      ...      ...      ...
# 541475  0.08526  0.03712  0.16120  0.12676 -0.00840  0.13222  0.12419
# 541476 -0.03307  0.01876 -0.12507 -0.07989  0.00276 -0.06246  0.06681
# 541477  0.02803 -0.02225  0.12060  0.08492 -0.00214  0.05525 -0.07919
# 541479  0.03331 -0.00911  0.15457  0.19936 -0.00316  0.05968 -0.06298
# 541480  0.03086 -0.00946  0.14931  0.19816 -0.00290  0.05569 -0.06422
#
# [403271 rows x 21 columns]

# %%
df_ptdf_adj['contingencies_string'] = df_ptdf_adj.contingency_list.apply(lambda s: ','.join([str(elem) for elem in s]))
df_observed_contingencies = pd.DataFrame({
    "lines": [[]] + list(df_ptdf_adj[df_ptdf_adj.contingency_list.map(len) > 0].groupby('contingencies_string').head(1).contingency_list)
})

display(df_observed_contingencies)

df_observed_contingencies.to_excel('contingencies.xlsx')
# Out:
#                lines
# 0                 []
# 1              [539]
# 2              [711]
# 3    [698, 699, 702]
# 4              [577]
# ..               ...
# 325           [2160]
# 326     [2740, 2768]
# 327     [2703, 2834]
# 328            [306]
# 329     [2727, 2793]
#
# [330 rows x 1 columns]

# %%
df_observed_contingencies['lines_string'] = df_observed_contingencies.lines.apply(lambda s: ','.join([str(elem) for elem in s]))

for index, row in df_ptdf_adj.iterrows():
    if len(row['contingency_list']) > 0:
        df_ptdf_adj.loc[index, 'contingency'] = df_observed_contingencies[
            df_observed_contingencies.lines_string == row['contingencies_string']
        ].index[0]
    else:
        df_ptdf_adj.loc[index, 'contingency'] = -1
        
df_ptdf_adj['contingency'] = df_ptdf_adj['contingency'].astype(int)

display(df_ptdf_adj)
# Out:
#                   DateTime line_id  direction contingency_list    fref    frm  \
# 0      2022-09-01 00:00:00     493          1               []    44.0   30.0
# 1      2022-09-01 00:00:00     493         -1               []   -44.0   30.0
# 2      2022-09-01 00:00:00    2710          1               []    27.0   23.0
# 3      2022-09-01 00:00:00    2699          1               []    13.0   23.0
# 4      2022-09-01 00:00:00    2699         -1               []   -13.0   23.0
# ...                    ...     ...        ...              ...     ...    ...
# 541475 2023-03-31 22:00:00    2036          1           [2039]  1113.0  138.0
# 541476 2023-03-31 22:00:00    2814          1     [2731, 2815]  -373.0  138.0
# 541477 2023-03-31 22:00:00    2815         -1     [2722, 2814]   450.0  138.0
# 541479 2023-03-31 22:00:00    2813         -1     [2722, 2814]   437.0  120.0
# 541480 2023-03-31 22:00:00    2813         -1     [2731, 2815]   446.0  120.0
#
#            ram     ALBE     ALDE       AT       BE       CZ    DE_LU       FR  \
# 0        439.0 -0.06186 -0.06238 -0.06499 -0.06181 -0.02490 -0.06303 -0.06025
# 1        341.0  0.06186  0.06238  0.06499  0.06181  0.02490  0.06303  0.06025
# 2        146.0  0.02502  0.02502  0.03672  0.02504  0.02301  0.02519  0.02522
# 3        155.0  0.02473  0.02472  0.03740  0.02476  0.02248  0.02487  0.02501
# 4        267.0 -0.02473 -0.02472 -0.03740 -0.02476 -0.02248 -0.02487 -0.02501
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 541475   410.0  0.16091  0.16134  0.16359  0.16079  0.18497  0.16210  0.15977
# 541476  1421.0 -0.12423 -0.12522 -0.10793 -0.12392 -0.18969 -0.12661 -0.12154
# 541477  1004.0  0.11961  0.12068  0.09994  0.11927  0.18129  0.12210  0.11665
# 541479  1179.0  0.15186  0.15387  0.09884  0.15112  0.15771  0.15581  0.14591
# 541480  1165.0  0.14659  0.14859  0.09318  0.14584  0.14929  0.15049  0.14065
#
#              HR       HU       NL       PL       RO       SI       SK  \
# 0      -0.00273  0.00340 -0.06144 -0.02183  0.00010 -0.00259 -0.00200
# 1       0.00273 -0.00340  0.06144  0.02183 -0.00010  0.00259  0.00200
# 2       0.01195 -0.01617  0.02482  0.01430 -0.00085  0.02081  0.00497
# 3       0.01253 -0.01655  0.02451  0.01386 -0.00089  0.02190  0.00451
# 4      -0.01253  0.01655 -0.02451 -0.01386  0.00089 -0.02190 -0.00451
# ...         ...      ...      ...      ...      ...      ...      ...
# 541475  0.08526  0.03712  0.16120  0.12676 -0.00840  0.13222  0.12419
# 541476 -0.03307  0.01876 -0.12507 -0.07989  0.00276 -0.06246  0.06681
# 541477  0.02803 -0.02225  0.12060  0.08492 -0.00214  0.05525 -0.07919
# 541479  0.03331 -0.00911  0.15457  0.19936 -0.00316  0.05968 -0.06298
# 541480  0.03086 -0.00946  0.14931  0.19816 -0.00290  0.05569 -0.06422
#
#        contingencies_string  contingency
# 0                                     -1
# 1                                     -1
# 2                                     -1
# 3                                     -1
# 4                                     -1
# ...                     ...          ...
# 541475                 2039           27
# 541476            2731,2815          289
# 541477            2722,2814          288
# 541479            2722,2814          288
# 541480            2731,2815          289
#
# [403271 rows x 23 columns]

# %%
df_ptdf_adj.loc[df_ptdf_adj.contingency.isna(), 'contingency'] = 0
df_ptdf_adj['contingency'] = df_ptdf_adj['contingency'].astype(int)
display(df_ptdf_adj)
# Out:
#                   DateTime line_id  direction contingency_list    fref    frm  \
# 0      2022-09-01 00:00:00     493          1               []    44.0   30.0
# 1      2022-09-01 00:00:00     493         -1               []   -44.0   30.0
# 2      2022-09-01 00:00:00    2710          1               []    27.0   23.0
# 3      2022-09-01 00:00:00    2699          1               []    13.0   23.0
# 4      2022-09-01 00:00:00    2699         -1               []   -13.0   23.0
# ...                    ...     ...        ...              ...     ...    ...
# 541475 2023-03-31 22:00:00    2036          1           [2039]  1113.0  138.0
# 541476 2023-03-31 22:00:00    2814          1     [2731, 2815]  -373.0  138.0
# 541477 2023-03-31 22:00:00    2815         -1     [2722, 2814]   450.0  138.0
# 541479 2023-03-31 22:00:00    2813         -1     [2722, 2814]   437.0  120.0
# 541480 2023-03-31 22:00:00    2813         -1     [2731, 2815]   446.0  120.0
#
#            ram     ALBE     ALDE       AT       BE       CZ    DE_LU       FR  \
# 0        439.0 -0.06186 -0.06238 -0.06499 -0.06181 -0.02490 -0.06303 -0.06025
# 1        341.0  0.06186  0.06238  0.06499  0.06181  0.02490  0.06303  0.06025
# 2        146.0  0.02502  0.02502  0.03672  0.02504  0.02301  0.02519  0.02522
# 3        155.0  0.02473  0.02472  0.03740  0.02476  0.02248  0.02487  0.02501
# 4        267.0 -0.02473 -0.02472 -0.03740 -0.02476 -0.02248 -0.02487 -0.02501
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 541475   410.0  0.16091  0.16134  0.16359  0.16079  0.18497  0.16210  0.15977
# 541476  1421.0 -0.12423 -0.12522 -0.10793 -0.12392 -0.18969 -0.12661 -0.12154
# 541477  1004.0  0.11961  0.12068  0.09994  0.11927  0.18129  0.12210  0.11665
# 541479  1179.0  0.15186  0.15387  0.09884  0.15112  0.15771  0.15581  0.14591
# 541480  1165.0  0.14659  0.14859  0.09318  0.14584  0.14929  0.15049  0.14065
#
#              HR       HU       NL       PL       RO       SI       SK  \
# 0      -0.00273  0.00340 -0.06144 -0.02183  0.00010 -0.00259 -0.00200
# 1       0.00273 -0.00340  0.06144  0.02183 -0.00010  0.00259  0.00200
# 2       0.01195 -0.01617  0.02482  0.01430 -0.00085  0.02081  0.00497
# 3       0.01253 -0.01655  0.02451  0.01386 -0.00089  0.02190  0.00451
# 4      -0.01253  0.01655 -0.02451 -0.01386  0.00089 -0.02190 -0.00451
# ...         ...      ...      ...      ...      ...      ...      ...
# 541475  0.08526  0.03712  0.16120  0.12676 -0.00840  0.13222  0.12419
# 541476 -0.03307  0.01876 -0.12507 -0.07989  0.00276 -0.06246  0.06681
# 541477  0.02803 -0.02225  0.12060  0.08492 -0.00214  0.05525 -0.07919
# 541479  0.03331 -0.00911  0.15457  0.19936 -0.00316  0.05968 -0.06298
# 541480  0.03086 -0.00946  0.14931  0.19816 -0.00290  0.05569 -0.06422
#
#        contingencies_string  contingency
# 0                                     -1
# 1                                     -1
# 2                                     -1
# 3                                     -1
# 4                                     -1
# ...                     ...          ...
# 541475                 2039           27
# 541476            2731,2815          289
# 541477            2722,2814          288
# 541479            2722,2814          288
# 541480            2731,2815          289
#
# [403271 rows x 23 columns]

# %%
df_ptdf_adj_reduced = df_ptdf_adj.copy()
df_ptdf_adj_reduced.loc[df_ptdf_adj_reduced.direction == -1, hubs] = -1 * df_ptdf_adj_reduced.loc[df_ptdf_adj_reduced.direction == -1, hubs]


df_ptdf_adj_reduced = df_ptdf_adj_reduced[['DateTime', 'line_id', 'contingency', 'fref', 'frm', 'ram'] + hubs].groupby(['DateTime', 'line_id', 'contingency'], as_index=False).mean()
display(df_ptdf_adj_reduced)
# Out:
#                   DateTime  line_id  contingency    fref    frm     ram  \
# 0      2022-09-01 00:00:00       12           -1   177.0   42.0   153.0
# 1      2022-09-01 00:00:00       94            9   863.0  173.0   653.0
# 2      2022-09-01 00:00:00      152            8   491.0  206.0  1140.0
# 3      2022-09-01 00:00:00      223            7  1243.0  207.0   919.0
# 4      2022-09-01 00:00:00      333            6   692.0  149.0   887.0
# ...                    ...      ...          ...     ...    ...     ...
# 299551 2023-03-31 22:00:00     2833          267   130.0  140.0   983.0
# 299552 2023-03-31 22:00:00     2842          268   -68.0   45.0   262.0
# 299553 2023-03-31 22:00:00     2844          269   -68.0   45.0   262.0
# 299554 2023-03-31 22:00:00     2850           -1   764.0  251.0   908.0
# 299555 2023-03-31 22:00:00     2850          157   781.0  251.0   875.0
#
#            ALBE     ALDE       AT       BE       CZ    DE_LU       FR  \
# 0      -0.04836 -0.04861 -0.01764 -0.04791 -0.01287 -0.04590 -0.04244
# 1      -0.01960 -0.02016 -0.02146 -0.01994 -0.07237 -0.03774 -0.02340
# 2      -0.12361 -0.09008  0.00777 -0.13408  0.00672 -0.00222 -0.14070
# 3      -0.08881 -0.11644  0.01279 -0.08286 -0.02146 -0.00737  0.00638
# 4       0.08342  0.08146 -0.01833  0.08480 -0.00646  0.05803  0.09712
# ...         ...      ...      ...      ...      ...      ...      ...
# 299551  0.08168  0.08136  0.05098  0.08213 -0.07219  0.07571  0.08407
# 299552  0.04749  0.04863 -0.01230  0.04720  0.01530  0.04659  0.04495
# 299553  0.04748  0.04862 -0.01230  0.04720  0.01530  0.04658  0.04495
# 299554 -0.07457 -0.03530  0.00516 -0.08367  0.00179  0.00098 -0.09946
# 299555 -0.07158 -0.04018  0.00620 -0.07901  0.00151  0.00172 -0.09173
#
#              HR       HU       NL       PL       RO       SI       SK
# 0      -0.00756  0.00085 -0.05174  0.04220  0.00071 -0.01033  0.00715
# 1      -0.00799 -0.00063 -0.01585  0.08202  0.00082 -0.01122  0.00769
# 2      -0.00395  0.00176 -0.07122  0.00364  0.00030 -0.00444  0.00304
# 3       0.00944 -0.00309 -0.09761 -0.02508 -0.00078  0.01233 -0.00938
# 4       0.00762 -0.00440  0.07500  0.00517 -0.00053  0.00870 -0.00457
# ...         ...      ...      ...      ...      ...      ...      ...
# 299551  0.01285 -0.00404  0.07844 -0.00940 -0.00124  0.02356 -0.01421
# 299552 -0.00054 -0.00184  0.04800  0.01892  0.00011 -0.00013  0.00249
# 299553 -0.00054 -0.00184  0.04800  0.01892  0.00011 -0.00013  0.00249
# 299554 -0.00087  0.00050 -0.04448 -0.00075  0.00008 -0.00168  0.00058
# 299555 -0.00066  0.00047 -0.04621 -0.00159  0.00006 -0.00130  0.00037
#
# [299556 rows x 20 columns]

# %%
df_ptdf_adj_reduced.to_excel("ptdf_z_obs.xlsx")
