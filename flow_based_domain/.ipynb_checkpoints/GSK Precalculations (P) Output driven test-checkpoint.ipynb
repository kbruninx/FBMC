# %%
import pandas as pd
import numpy as np
from scipy import spatial
import networkx as nx

from entsoe import EntsoePandasClient
from entsoe.mappings import Area, NEIGHBOURS, lookup_area
from entsoe.parsers import parse_generation
from typing import Union, Optional, Dict, List, Literal

client = EntsoePandasClient(api_key="b18dfce9-f1e3-4d07-822f-4abd1438e602")

# %%
zones = ['ALBE', 'ALDE', 'AT', 'BE', 'CZ', 'DE_LU', 'FR', 'HR', 'HU', 'NL', 'PL', 'RO', 'SI', 'SK']

# %%
df_gen = pd.read_excel('../cost_curves/data/generation.xlsx', index_col=0)
df_substations = pd.read_excel('./substations.xlsx', index_col=0)
df_powerplants = pd.read_excel('./plants.xlsx', index_col=0)
df_grid = pd.read_excel('./grid.xlsx', index_col=0)
df_grid = df_grid[df_grid.susceptance != 0]
Grid = nx.from_pandas_edgelist(df_grid, 'substation_1', 'substation_2', edge_attr=["susceptance"])

substation_ids = []
substation_locs = []
for index, row in df_substations.iterrows():
    substation_ids.append(index)
    substation_locs.append((row.lon, row.lat))
    
substation_tree = spatial.KDTree(substation_locs)

for index, row in df_powerplants.iterrows():
    result = substation_tree.query([(row.lon,row.lat)])
    df_powerplants.loc[index, 'node'] = substation_ids[result[1][0]]
    
df_powerplants.node = df_powerplants.node.astype(int)
display(df_powerplants)
# Out:
#                             name               eic                  type zone
# 0                    GDK-Mellach  14W-WGM-KW-----J           natural_gas   AT  \
# 1           Ottensheim-Wilhering  14W-BOW-KW-----9    hydro_run_of_river   AT
# 2                FHKW Linz Mitte  14WLSG-MITTE---U           natural_gas   AT
# 3                Kraftwerk Theiß  14W-KW-THE-EVN-7           natural_gas   AT
# 4                  FHKW Linz Süd  14WLSG-1SUED---5           natural_gas   AT
# ..                           ...               ...                   ...  ...
# 636           Petrokemija Kutina               NaN           natural_gas   HR
# 637                    Dubrovnik               NaN       hydro_reservoir   HR
# 638                       Fuzine               NaN  hydro_pumped_storage   HR
# 639                    He Rijeka               NaN    hydro_run_of_river   HR
# 640  Hidroelektrana Velebit Pump               NaN  hydro_pumped_storage   HR
#
#      installed_capacity        lat        lon  node
# 0                 838.0  46.911700  15.488300  1091
# 1                 179.0  48.316500  14.151057  1280
# 2                 216.8  48.299219  14.322935   690
# 3                 485.0  48.394861  15.710147  1064
# 4                 158.0  48.267893  14.346898   690
# ..                  ...        ...        ...   ...
# 636                35.0  45.471290  16.792320  1171
# 637               216.0  42.603001  18.235001   187
# 638                 5.7  45.304985  14.714837   412
# 639                36.8  45.334999  14.452000   417
# 640               276.0  44.200733  15.681117    16
#
# [555 rows x 8 columns]

# %%
start = pd.Timestamp('20220901', tz='Europe/Amsterdam')
#end = pd.Timestamp('20220902', tz='Europe/Amsterdam')
end = pd.Timestamp('20230331', tz='Europe/Amsterdam')

df_actual_generation = {}

for (index, country_code) in enumerate([x for x in zones if x not in ['ALBE', 'ALDE', 'DE_LU', 'HR']]):
    print(country_code)
    df_actual_generation[country_code] = client.query_generation_per_plant(country_code, start=start, end=end)
# Out:
# AT
# BE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 9
#       7 for (index, country_code) in enumerate([x for x in zones if x not in ['DE_LU', 'HR']]):
#       8     print(country_code)
# ----> 9     df_actual_generation[country_code] = client.query_generation_per_plant(country_code, start=start, end=end)
#
# File ~\FBMC\fbmc_env\lib\site-packages\entsoe\decorators.py:125, in day_limited.<locals>.day_wrapper(start, end, *args, **kwargs)
#     123 for _start, _end in blocks:
#     124     try:
# --> 125         frame = func(*args, start=_start, end=_end, **kwargs)
#     126     except NoMatchingDataError:
#     127         print(f"NoMatchingDataError: between {_start} and {_end}", file=sys.stderr)
#
# File ~\FBMC\fbmc_env\lib\site-packages\entsoe\entsoe.py:1934, in EntsoePandasClient.query_generation_per_plant(self, country_code, start, end, psr_type, include_eic, nett, **kwargs)
#    1916 """
#    1917 Parameters
#    1918 ----------
#    (...)
#    1931 pd.DataFrame
#    1932 """
#    1933 area = lookup_area(country_code)
# -> 1934 text = super(EntsoePandasClient, self).query_generation_per_plant(
#    1935     country_code=area, start=start, end=end, psr_type=psr_type)
#    1936 df = parse_generation(text, per_plant=True, include_eic=include_eic)
#    1937 df.columns = df.columns.set_levels(df.columns.levels[0].str.encode('latin-1').str.decode('utf-8'), level=0)
#
# File ~\FBMC\fbmc_env\lib\site-packages\entsoe\entsoe.py:359, in EntsoeRawClient.query_generation_per_plant(self, country_code, start, end, psr_type, **kwargs)
#     357 if psr_type:
#     358     params.update({'psrType': psr_type})
# --> 359 response = self._base_request(params=params, start=start, end=end)
#     360 return response.text
#
# File ~\FBMC\fbmc_env\lib\site-packages\entsoe\decorators.py:22, in retry.<locals>.retry_wrapper(*args, **kwargs)
#      20 for _ in range(self.retry_count):
#      21     try:
# ---> 22         result = func(*args, **kwargs)
#      23     except (requests.ConnectionError, gaierror) as e:
#      24         error = e
#
# File ~\FBMC\fbmc_env\lib\site-packages\entsoe\entsoe.py:95, in EntsoeRawClient._base_request(self, params, start, end)
#      92 params.update(base_params)
#      94 logging.debug(f'Performing request to {URL} with params {params}')
# ---> 95 response = self.session.get(url=URL, params=params,
#      96                             proxies=self.proxies, timeout=self.timeout)
#      97 try:
#      98     response.raise_for_status()
#
# File ~\FBMC\fbmc_env\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~\FBMC\fbmc_env\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\FBMC\fbmc_env\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\FBMC\fbmc_env\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\FBMC\fbmc_env\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\FBMC\fbmc_env\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\FBMC\fbmc_env\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File C:\Program Files\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
display(df_actual_generation['AT'])
# Out:
#                                            Abwinden-Asten
#                           Hydro Run-of-river and poundage
# newlevel                                Actual Aggregated
# 2022-09-01 00:00:00+02:00                            93.0  \
# 2022-09-01 01:00:00+02:00                            94.0
# 2022-09-01 02:00:00+02:00                            97.0
# 2022-09-01 03:00:00+02:00                            98.0
# 2022-09-01 04:00:00+02:00                           101.0
# ...                                                   ...
# 2023-03-30 19:00:00+02:00                           108.0
# 2023-03-30 20:00:00+02:00                           110.0
# 2023-03-30 21:00:00+02:00                           111.0
# 2023-03-30 22:00:00+02:00                           113.0
# 2023-03-30 23:00:00+02:00                           115.0
#
#                                                Altenwörth
#                           Hydro Run-of-river and poundage
# newlevel                                Actual Aggregated
# 2022-09-01 00:00:00+02:00
# 2023-03-30 19:00:00+02:00              66.0               0.0
# 2023-03-30 20:00:00+02:00              59.0               0.0
# 2023-03-30 21:00:00+02:00              58.0               0.0
# 2023-03-30 22:00:00+02:00              59.0               0.0
# 2023-03-30 23:00:00+02:00              56.0               0.0
#
#                                   Sim1_GT42           Sim3_DT
#                                  Fossil Gas        Fossil Gas
# newlevel                  Actual Aggregated Actual Aggregated
# 2022-09-01 00:00:00+02:00               0.0               0.0  \
# 2022-09-01 01:00:00+02:00               0.0               0.0
# 2022-09-01 02:00:00+02:00               0.0               0.0
# 2022-09-01 03:00:00+02:00               0.0               0.0
# 2022-09-01 04:00:00+02:00               0.0               0.0
# ...                                     ...               ...
# 2023-03-30 19:00:00+02:00             260.0               0.0
# 2023-03-30 20:00:00+02:00             246.0               0.0
# 2023-03-30 21:00:00+02:00             251.0               0.0
# 2023-03-30 22:00:00+02:00             256.0               0.0
# 2023-03-30 23:00:00+02:00             249.0               0.0
#
#                                     Wallsee-Mitterkirchen
#                           Hydro Run-of-river and poundage
# newlevel                                Actual Aggregated
# 2022-09-01 00:00:00+02:00                           134.0  \
# 2022-09-01 01:00:00+02:00                           135.0
# 2022-09-01 02:00:00+02:00                           139.0
# 2022-09-01 03:00:00+02:00                           140.0
# 2022-09-01 04:00:00+02:00                           144.0
# ...                                                   ...
# 2023-03-30 19:00:00+02:00                           140.0
# 2023-03-30 20:00:00+02:00                           146.0
# 2023-03-30 21:00:00+02:00                           153.0
# 2023-03-30 22:00:00+02:00                           160.0
# 2023-03-30 23:00:00+02:00                           164.0
#
#                                           Ybbs-Persenbeug
#                           Hydro Run-of-river and poundage
# newlevel                                Actual Aggregated
# 2022-09-01 00:00:00+02:00                           131.0
# 2022-09-01 01:00:00+02:00                           135.0
# 2022-09-01 02:00:00+02:00                           136.0
# 2022-09-01 03:00:00+02:00                           136.0
# 2022-09-01 04:00:00+02:00                           136.0
# ...                                                   ...
# 2023-03-30 19:00:00+02:00                           141.0
# 2023-03-30 20:00:00+02:00                           138.0
# 2023-03-30 21:00:00+02:00                           139.0
# 2023-03-30 22:00:00+02:00                           146.0
# 2023-03-30 23:00:00+02:00                           153.0
#
# [5064 rows x 34 columns]

# %%
gsk5_matrix = np.zeros((len(df_gen), len(df_powerplants), len(zones)))

for p, (p_index, plant) in enumerate(df_powerplants.iterrows()):
    if plant['zone'] == 'AT':
        zone = plant['zone']
        if plant['name'] in df_actual_generation[zone].columns:
            print(p)
            for t, (t_index, gen) in enumerate(df_gen.iterrows()):
                gen_level = list(df_actual_generation[zone][plant['name']][df_actual_generation[zone][plant['name']].columns[0]])[t]
                total_zonal_generation = df_actual_generation[zone].iloc[t].sum()

                gsk5_matrix[t][p][zones.index(zone)] = gen_level/total_zonal_generation
# Out:
# 1
# 6
# 7
# 9
# 10
# 11
# 13
# 15
# 16
# 17
# 19
# 20
# 23
# 24
# 25
# 26
# 29
# 32
# 33
# 34
# 35

# %%
with open('gsk5_matrix_p.npy', 'wb') as f:
    np.save(f, gsk5_matrix)

# %%
gsk5_matrix[0]
