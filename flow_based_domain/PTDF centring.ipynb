# %%
import pandas as pd
import numpy as np

# %%
df_ptdf = pd.read_excel('./ptdfs.xlsx', index_col=0)
display(df_ptdf)
# Out:
#                                   eic   ram     ALBE     ALDE       AT  \
# DateTime
# 2022-09-01 00:00:00  14T-220-0-0203CD   439 -0.06186 -0.06238 -0.06499
# 2022-09-01 00:00:00  14T-220-0-0203CD   341  0.06186  0.06238  0.06499
# 2022-09-01 00:00:00  10T-AT-HU-00002U   146  0.02502  0.02502  0.03672
# 2022-09-01 00:00:00  10T-AT-HU-00001W   155  0.02473  0.02472  0.03740
# 2022-09-01 00:00:00  10T-AT-HU-00001W   267 -0.02473 -0.02472 -0.03740
# ...                               ...   ...      ...      ...      ...
# 2023-03-31 22:00:00  10T-CZ-SK-00003U  1421 -0.12423 -0.12522 -0.10793
# 2023-03-31 22:00:00  10T-CZ-SK-00005Q  1004  0.11961  0.12068  0.09994
# 2023-03-31 22:00:00  10T-SK-UA-00001W  1388 -0.21769 -0.21902 -0.19030
# 2023-03-31 22:00:00  10T-CZ-SK-00002W  1179  0.15186  0.15387  0.09884
# 2023-03-31 22:00:00  10T-CZ-SK-00002W  1165  0.14659  0.14859  0.09318
#
#                           BE       CZ    DE_LU       FR       HR       HU  \
# DateTime
# ...
