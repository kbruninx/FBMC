# %%
import pandas as pd

pd.set_option('display.max_rows', 450)

# %%
df_powerplants = pd.read_csv('./powerplants.csv')

# %%
df_pp_uk = df_powerplants[(df_powerplants.Country.isin(['Italy']))]
display(df_pp_uk)
# Out:
#         id                                               Name     Fueltype  \
# 4        4                                             Fusina    Hard Coal
# 6        6                                            Cassano  Natural Gas
# 7        7                                     Cte Del Mincio  Natural Gas
# 8        8                                  Enipower Brindisi  Natural Gas
# 9        9                                   Enipower Ravenna  Natural Gas
# 10      10                                              Gissi  Natural Gas
# 11      11                                               Jesi  Natural Gas
# 12      12                                              Leini  Natural Gas
# 13      13                                            Levante  Natural Gas
# 14      14                                         Moncalieri  Natural Gas
# 15      15                                             Napoli  Natural Gas
# ...

# %%
df_pp_uk.to_excel('powerplants_uk.xlsx')
