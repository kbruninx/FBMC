# %%
import pandas as pd

# %%
df_powerplants = pd.read_csv('./powerplants.csv')

# %%
df_pp_uk = df_powerplants[df_powerplants.Country.isin(['United Kingdom'])]
display(df_pp_uk)
# Out:
#         id                  Name     Fueltype      Technology    Set  \
# 54      54                  Crua        Hydro  Pumped Storage  Store
# 55      55                  Dino        Hydro    Run-Of-River  Store
# 56      56                  Ffes        Hydro    Run-Of-River  Store
# 57      57                  Foye        Hydro    Run-Of-River  Store
# 58      58                  Sloy        Hydro    Run-Of-River  Store
# ...    ...                   ...          ...             ...    ...
# 3493  3593              Meig Dam        Hydro             NaN     PP
# 3532  3659  Pilkington Greengate  Natural Gas            CCGT     PP
# 3556  3708                Selset        Hydro             NaN     PP
# 3558  3711    Shin Diversion Dam        Hydro             NaN     PP
# 3569  3728          Stanley Mill        Hydro             NaN     PP
#
#              Country  Capacity  Efficiency  DateIn  DateRetrofit  DateOut  \
# 54    United Kingdom     440.0         NaN  1965.0        1965.0      NaN
# 55    United Kingdom    2016.0         NaN  1984.0        1984.0      NaN
# 56    United Kingdom     384.0         NaN  1963.0        1963.0      NaN
# 57    United Kingdom     320.0         NaN  1968.0        1974.0      NaN
# 58    United Kingdom     153.0         NaN  1950.0        1950.0      NaN
# ...              ...       ...         ...     ...           ...      ...
# 3493  United Kingdom       0.1         NaN  1954.0        1954.0      NaN
# 3532  United Kingdom      10.0         NaN  1998.0        1998.0      NaN
# 3556  United Kingdom       0.8         NaN  2010.0        2010.0      NaN
# 3558  United Kingdom       0.1         NaN  1958.0        1958.0      NaN
# 3569  United Kingdom       0.8         NaN  2003.0        2003.0      NaN
#
#             lat       lon   Duration  Volume_Mm3  DamHeight_m  \
# 54    56.394104 -5.114319  15.909091         0.0          0.0
# 55    53.118744 -4.113624   5.777778         0.0          0.0
# 56    52.980785 -3.968708   4.805556         0.0          0.0
# 57    57.255362 -4.493152  20.655738         0.0          0.0
# 58    56.261512 -4.763588        NaN         0.0          0.0
# ...         ...       ...        ...         ...          ...
# 3493  57.565006 -4.717085        NaN         0.0          0.0
# 3532  53.442988 -2.739958        NaN         0.0          0.0
# 3556  54.585667 -2.124333        NaN         0.0          0.0
# 3558  58.012220 -4.402339        NaN         0.0          0.0
# 3569  56.479236 -3.437670        NaN         0.0          0.0
#
#       StorageCapacity_MWh                   EIC  \
# 54                    0.0  {'48WSTN00000CRUAC'}
# 55                    0.0  {'48WSTN10000DINOQ'}
# 56                    0.0  {'48WSTN00000FFESK'}
# 57                    0.0  {'48WSTN00000FOYEQ'}
# 58                    0.0  {'48WSTN00000SLOY0'}
# ...                   ...                   ...
# 3493                  0.0                 {nan}
# 3532                  0.0                 {nan}
# 3556                  0.0                 {nan}
# 3558                  0.0                 {nan}
# 3569                  0.0                 {nan}
#
#                                               projectID
# 54    {'ENTSOE': {'48WSTN00000CRUAC'}, 'OPSD': {'OEU...
# 55    {'ENTSOE': {'48WSTN10000DINOQ'}, 'OPSD': {'OEU...
# 56    {'ENTSOE': {'48WSTN00000FFESK'}, 'OPSD': {'OEU...
# 57    {'ENTSOE': {'48WSTN00000FOYEQ'}, 'OPSD': {'OEU...
# 58    {'ENTSOE': {'48WSTN00000SLOY0'}, 'OPSD': {'OEU...
# ...                                                 ...
# 3493                             {'OPSD': {'OEU-3033'}}
# 3532                             {'OPSD': {'OEU-3070'}}
# 3556                             {'OPSD': {'OEU-2955'}}
# 3558                             {'OPSD': {'OEU-3050'}}
# 3569                             {'OPSD': {'OEU-2956'}}
#
# [254 rows x 19 columns]

# %%
df_pp_uk.to_excel('powerplants_uk.xlsx')
