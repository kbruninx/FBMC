# %%
import pandas as pd
import networkx as nx
import numpy as np
import unicodedata
import pandas as pd
import requests
import geopandas as gpd
import osmnx as ox

pd.set_option('display.max_rows', 50)

# %%
df_grid = pd.read_excel('./jao_static_grid.xlsx', sheet_name='Lines', skiprows=[0])
df_grid = df_grid[[
    'NE_name', 'EIC_Code', 'TSO', 
    'Full_name', 'Full_name.1', 'Voltage_level(kV)', 
    'Resistance_R(Ω)', 'Reactance_X(Ω)', 'Susceptance_B(μS)', 'Length_(km)'
]]
df_grid = df_grid.rename(columns={
    'NE_name': 'name', 
    'EIC_Code': 'eic',
    'TSO': 'tso',
    'Voltage_level(kV)': 'voltage',
    'Resistance_R(Ω)': 'resistance',
    'Reactance_X(Ω)': 'reactance',
    'Susceptance_B(μS)': 'susceptance',
    'Length_(km)': 'length',
    'Full_name': 'substation_1',
    'Full_name.1': 'substation_2',
})

tso_zone_map = {
    '50HERTZ': 'DE', 
    'Amprion GmbH': 'DE', 
    'APG': 'AT', 
    'CEPS': 'CZ', 
    'Creos': 'DE', 
    'ELES': 'SI', 
    'ELIA': 'BE',
    'HOPS': 'HR', 
    'MAVIR': 'HU', 
    'PSE': 'PL', 
    'RTE': 'FR', 
    'SEPS': 'SK', 
    'TEL': 'RO', 
    'TENNET NL': 'NL',
    'TENNETGMBH': 'DE', 
    'TRANSNETBW': 'DE'
}

df_grid['zone'] = df_grid.apply(lambda row : tso_zone_map[row.tso], axis=1)

# %%
s1 = set(df_grid.substation_1.unique())
s1 = s1.union(df_grid.substation_2.unique())
substations = list(s1)

substation_zones = []
substation_tso = []
for s in substations:
    substation_zones.append(df_grid[(df_grid.substation_1 == s) | (df_grid.substation_2 == s)].iloc[0].zone)
    substation_tso.append(df_grid[(df_grid.substation_1 == s) | (df_grid.substation_2 == s)].iloc[0].tso)

df_jao_substations = pd.DataFrame(list(zip(substations.copy(), substation_zones, substation_tso)), columns =['name', 'zone', 'tso'])

substation_location_map = {}
for s in substations:
    substation_location_map[s] = None

# %%
df_scigrid_substations = pd.read_csv('vertices_eu_power_160718.csvdata', delimiter=',', quotechar="'")
df_scigrid_substations = df_scigrid_substations[df_scigrid_substations.typ == 'substation']
df_scigrid_substations = df_scigrid_substations.dropna(subset=['name'])
df_scigrid_substations = df_scigrid_substations[[
    'lon', 'lat', 'name', 'operator'
]]

# %%
scigrid_substations = df_scigrid_substations.name
scigrid_substations = list(map(str.lower, scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique de ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique du ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique des', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("poste électrique d'", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste de ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("poste d'", ''), scigrid_substations))

scigrid_substations = list(map(lambda s: s.replace("150 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("220 kv-umspannwerk ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("220-kv-umspannwerk ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("220kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("380 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("380-kv-umspannwerk ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("380kv-umspannwerk ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("380kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400/132 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400/132/50 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400/150 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400/150kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400kv/150kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ß", 'ss'), scigrid_substations))

scigrid_substations = list(map(lambda s: s.replace("á", 'a'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("é", 'e'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("í", 'i'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ó", 'o'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ö", 'o'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ő", 'o'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ú", 'u'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ü", 'u'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ű", 'u'), scigrid_substations))

scigrid_substations = list(map(lambda s: unicodedata.normalize('NFKD', s).encode('ascii','ignore').decode("utf-8"), scigrid_substations))

# %%
def replace_tail_space(s):
    if s[-1] == ' ':
        s = s[0:-1]
    if s[-1] == ' ':
        s = s[0:-1]
    if s[0] == ' ':
        s = s[1:]
    return s
        
substations = list(map(str.lower, substations))
substations = list(map(lambda s: s.replace(' (le)', ''), substations))
substations = list(map(lambda s: s.replace(' (la)', ''), substations))
substations = list(map(lambda s: s.replace(' (les)', ''), substations))
substations = list(map(lambda s: s.replace(' (les)', ''), substations))

substations = list(map(lambda s: s.replace(' (l )', ''), substations))
substations = list(map(lambda s: s.replace(' (poste)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste 400 kv)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste reseau)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste blinde)', ''), substations))
substations = list(map(lambda s: s.replace(' (abzweig)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste exterieur)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste evacuation)', ''), substations))

substations = list(map(lambda s: s.replace("ß", 'ss'), substations))
substations = list(map(lambda s: s.replace("á", 'a'), substations))
substations = list(map(lambda s: s.replace("é", 'e'), substations))
substations = list(map(lambda s: s.replace("í", 'i'), substations))
substations = list(map(lambda s: s.replace("ó", 'o'), substations))
substations = list(map(lambda s: s.replace("ö", 'o'), substations))
substations = list(map(lambda s: s.replace("ő", 'o'), substations))
substations = list(map(lambda s: s.replace("ú", 'u'), substations))
substations = list(map(lambda s: s.replace("ü", 'u'), substations))
substations = list(map(lambda s: s.replace("ű", 'u'), substations))

substations = list(map(lambda s: s.replace("aftakking ", ''), substations))
substations = list(map(lambda s: s.replace(" 380kv", ''), substations))
substations = list(map(lambda s: s.replace(" 220kv", ''), substations))
substations = list(map(lambda s: s.replace("y-", ''), substations))

substations = list(map(lambda s: s.replace("ue", 'u'), substations))
substations = list(map(lambda s: s.replace("oe", 'o'), substations))
substations = list(map(lambda s: s.replace("ae", 'a'), substations))
substations = list(map(lambda s: s.replace("/nord", ''), substations))
substations = list(map(lambda s: s.replace("/sud", ''), substations))
substations = list(map(lambda s: s.replace("/west", ''), substations))
substations = list(map(lambda s: s.replace("/n", ''), substations))
substations = list(map(lambda s: s.replace("/w", ''), substations))
substations = list(map(lambda s: s.replace("/sw", ''), substations))
substations = list(map(lambda s: s.replace("/s", ''), substations))
substations = list(map(lambda s: s.replace("/o", ''), substations))
substations = list(map(lambda s: s.replace("  2", ''), substations))
substations = list(map(lambda s: s.replace(" 1", ''), substations))
substations = list(map(lambda s: s.replace(" 2", ''), substations))
substations = list(map(lambda s: s.replace("st ", ''), substations))

substations = list(map(lambda s: s.replace("emden/borssum", 'borssum'), substations))
substations = list(map(lambda s: s.replace("hamburgst", 'hamburg'), substations))
substations = list(map(lambda s: s.replace("karlsruhewest", 'karlsruhe'), substations))
substations = list(map(lambda s: s.replace("bruchsal/kandelweg", 'bruchsal'), substations))
substations = list(map(lambda s: s.replace("perleberg - putlitz", 'perleberg'), substations))
substations = list(map(lambda s: s.replace("remptendorf - grossschwabhausen", 'remptendorf'), substations))
substations = list(map(lambda s: s.replace("(neu)", ''), substations))

substations = list(map(lambda s: replace_tail_space(s), substations))

substations = list(map(lambda s: unicodedata.normalize('NFKD', s).encode('ascii','ignore').decode("utf-8"), substations))

# %%
s2 = set(scigrid_substations)
s2 = s2.intersection(substations)
print(len(s2))
# Out:
# 229

# %%
set_scigrid = set(scigrid_substations)
set_jao = set(substations)
intersect = s2

scigrid_sub = set_scigrid.difference(intersect)
jao_sub = set_jao.difference(intersect)

matching_scigrid = []
matching_jao = []
for jao_s in jao_sub:
    match = [s for s in scigrid_sub if jao_s in s]
    if len(match) > 0:
        matching_scigrid.append(match[0])
        matching_jao.append(jao_s)
        
scigrid_sub = set(scigrid_sub).difference(matching_scigrid)
jao_sub = set(jao_sub).difference(matching_jao)

print(len(matching_scigrid))
# Out:
# 395

# %%
def exact_match_scigrid(row, column):
    match = df_scigrid_substations[df_scigrid_substations['name_norm'] == row['name_norm']]
    if len(match) > 0:
        return match.iloc[0][column]
    return None

def loose_match_scigrid(row, column):
    if np.isnan(row[column]):
        if row['name_norm'] in matching_jao:
            i = matching_jao.index(row['name_norm'])
            match = df_scigrid_substations[df_scigrid_substations['name_norm'] == matching_scigrid[i]]
            return match.iloc[0][column]
        else:
            return None
    return row[column]
    
    
df_scigrid_substations.loc[:, 'name_norm'] = scigrid_substations
df_jao_substations.loc[:, 'name_norm'] = substations

df_jao_substations['lat'] = df_jao_substations.apply(lambda row: exact_match_scigrid(row, 'lat'), axis=1)
df_jao_substations['lon'] = df_jao_substations.apply(lambda row: exact_match_scigrid(row, 'lon'), axis=1)

df_jao_substations['lat'] = df_jao_substations.apply(lambda row: loose_match_scigrid(row, 'lat'), axis=1)
df_jao_substations['lon'] = df_jao_substations.apply(lambda row: loose_match_scigrid(row, 'lon'), axis=1)

# %%
# France
# https://odre.opendatasoft.com/explore/dataset/enceintes-de-poste-rte/export/?disjunctive.etat
df_missing_jao = df_jao_substations[df_jao_substations.lat.isnull()]

def exact_match_rte(row, column):
    if np.isnan(row[column]):
        match = df_rte[df_rte['NOM POSTE'] == row['name']]
        if len(match) > 0:
            return match.iloc[0][column]
        return None
    return row[column]

df_jao_france = df_missing_jao[df_missing_jao.zone == 'FR']
df_rte = pd.read_excel('enceintes-de-poste-rte.xlsx')
df_rte = df_rte.dropna(subset=['geo_point_2d'])

# exact match
s_fr_intersect = set(df_jao_france.name)
s_fr_intersect = s_fr_intersect.intersection(df_rte['NOM POSTE'])

df_rte['lat'] = df_rte.apply(lambda row: float(str(row['geo_point_2d']).split(', ')[0]), axis=1)
df_rte['lon'] = df_rte.apply(lambda row: float(str(row['geo_point_2d']).split(',')[1]), axis=1)

df_jao_substations['lat'] = df_jao_substations.apply(lambda row: exact_match_rte(row, 'lat'), axis=1)
df_jao_substations['lon'] = df_jao_substations.apply(lambda row: exact_match_rte(row, 'lon'), axis=1)

# %%
df_missing_jao = df_jao_substations[df_jao_substations.lat.isnull()]
display(df_missing_jao.groupby(['zone'])['zone'].count())
# Out:
# zone
# AT    27
# BE    67
# CZ     3
# DE    87
# FR    13
# HR     9
# HU    13
# NL    34
# PL    35
# RO    99
# SI     5
# SK    25
# Name: zone, dtype: int64

# %%
substations_to_skip = ['gkmb', 'offshore windpark', 'romsee sncb', 'roman nord', 'gkn2', 'roo', 'rdk7', 'rdk8', ]
df_missing_jao_osm = df_missing_jao[~df_missing_jao.name_norm.isin(substations_to_skip)]
df_missing_jao_osm.loc[:, 'osm_find'] = ''

display(df_missing_jao_osm)
# Out:
# C:\Users\balazs.riskutia\AppData\Local\Temp\ipykernel_688\813298026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing_jao_osm.loc[:, 'osm_find'] = ''
#                                       name zone           tso  \
# 8                                    Varin   SK          SEPS
# 9                                  SERAING   BE          ELIA
# 18                           Cluj Floresti   RO           TEL
# 19                                 GEZELLE   BE          ELIA
# 20                                 Calafat   RO           TEL
# 24                              Szigetcsep   HU         MAVIR
# 30                AFTAKKING MEKINGEN 380kV   BE          ELIA
# 32                                Rosiori    RO           TEL
# 33                              Wengerrohr   DE  Amprion GmbH
# 35                               Velky Dur   SK          SEPS
# 40                                Boxmeer    NL     TENNET NL
# 42                           Schwarzenbach   AT           APG
# 44              AFTAKKING BUGGENHOUT 380kV   BE          ELIA
# 45                                 Stejaru   RO           TEL
# 52                                  V. Dur   SK          SEPS
# 61                                  Vojany   SK          SEPS
# 63                                  Zwolle   NL     TENNET NL
# 64                               Urechesti   RO           TEL
# 65                              Sajoivanka   HU         MAVIR
# 70                              Eindhoven    NL     TENNET NL
# 72                                  Iernut   RO           TEL
# 73                            Fedderwarden   DE    TENNETGMBH
# 76                      Breukelen Kortrijk   NL     TENNET NL
# 79                     Salzburg Elixhausen   AT           APG
# 80                                    Senj   HR          HOPS
# 83                              Lacu Sarat   RO           TEL
# 88                             OSTROW WLKP   PL           PSE
# 89                                 Pestis    RO           TEL
# 91                            Craiova Nord   RO           TEL
# 92                             H. Zivotice   CZ          CEPS
# 93                               Kledering   AT           APG
# 94                                   KALLO   BE          ELIA
# 97                               Doekegat    NL     TENNET NL
# 102                                Smardan   RO           TEL
# 104                         Constanta Nord   RO           TEL
# 107                                 Rosegg   AT           APG
# 109                               Isalnita   RO           TEL
# 113                                    FAI   RO           TEL
# 115                           GDANSK-BLONI   PL           PSE
# 118                               Schuby/W   DE    TENNETGMBH
# 122                 PIQUAGE A SAINT GERONS   FR           RTE
# 124                                ANIOLOW   PL           PSE
# 150                      Y-Waldlaubersheim   DE  Amprion GmbH
# 151                                Kerepes   HU         MAVIR
# 153                            MASSENHOVEN   BE          ELIA
# 154                                  Arefu   RO           TEL
# 157                  TRAN5 / GAVRE PERTA 1   FR           RTE
# 158                             Westerlee    NL     TENNET NL
# 161                           Y-Schwelgern   DE  Amprion GmbH
# 173                                    GKM   DE    TRANSNETBW
# 174                                 Kosice   SK          SEPS
# 177                               Ghizdaru   RO           TEL
# 179                            PORABKA-ZAR   PL           PSE
# 181                                JUPILLE   BE          ELIA
# 185                                Galceag   RO           TEL
# 187                                Zakucac   HR          HOPS
# 188                             RODENHUIZE   BE          ELIA
# 200                              Dettingen   DE  Amprion GmbH
# 201                             Elsfleth/W   DE    TENNETGMBH
# 207                             Neuenhagen   DE       50HERTZ
# 208            REPIQUAGE SENONCHAMPS 220kV   BE          ELIA
# 210                               Stuparei   RO           TEL
# 213                                   Detk   HU         MAVIR
# 225                                 Cetate   RO           TEL
# 228                                  Bradu   RO           TEL
# 231                            TORUN ELANA   PL           PSE
# 239                         Targu Jiu Nord   RO           TEL
# 241                                Ternitz   AT           APG
# 245                             Wateringen   NL     TENNET NL
# 247                              Hessenweg   NL     TENNET NL
# 248                            V. Kapusany   SK          SEPS
# 249                                  LIXHE   BE          ELIA
# 252                           Kottigerhook   DE  Amprion GmbH
# 253                              Mayrhofen   AT           APG
# 260                                 Levice   SK          SEPS
# 265                            Y-Plattling   DE    TENNETGMBH
# 270                                  BRUME   BE          ELIA
# 272                            Weissenbach   AT           APG
# 274                                  Bayer   DE  Amprion GmbH
# 275                              Cernavoda   RO           TEL
# 278                                  LILLO   BE          ELIA
# 279                              Baru Mare   RO           TEL
# 280                              Y-Waldeck   DE    TENNETGMBH
# 281                                 Siroka   SK          SEPS
# 283                               C. Stred   CZ          CEPS
# 290                                Oechtel   DE  Amprion GmbH
# 296                     Krimpen a/d IJssel   NL     TENNET NL
# 299                                 Stalpu   RO           TEL
# 300                                  Tihau   RO           TEL
# 301                               Domnesti   RO           TEL
# 310                                  Nadab   RO           TEL
# 312                                Wallsee   AT           APG
# 315                                   Vola   SK          SEPS
# 318                              Bacharach   DE  Amprion GmbH
# 322                               Diefflen   DE  Amprion GmbH
# 328                        GDANSK PRZYJAZN   PL           PSE
# 329                               MAERLANT   BE          ELIA
# 332                             H.Zivotice   CZ          CEPS
# 333                               Lelystad   NL     TENNET NL
# 339                            Heinersdorf   DE       50HERTZ
# 344                             Ernsthofen   AT           APG
# 345                            Robbenplaat   NL     TENNET NL
# 351                         Gura Ialomitei   RO           TEL
# 354                   Eemshaven Oude Schip   NL     TENNET NL
# 355                                Okroglo   SI          ELES
# 357                               Bericevo   SI          ELES
# 358                              Feistritz   AT           APG
# 363                    PIQUAGE A DUVIGNEAU   FR           RTE
# 366                              Westerlee   NL     TENNET NL
# 367                              Tariverde   RO           TEL
# 372                               Dumbrava   RO           TEL
# 375                               MEERHOUT   BE          ELIA
# 379           AFTAKKING LIEFKENSHOEK 380kV   BE          ELIA
# 383                                Husum/N   DE    TENNETGMBH
# 385                           Targoviste A   RO           TEL
# 388                           ST-MARD SNCB   BE          ELIA
# 389                           Y-Dauersberg   DE  Amprion GmbH
# 392                               BLOOREN    DE         Creos
# 394                              Bacau Sud   RO           TEL
# 396                                PELPLIN   PL           PSE
# 397                                 GORZOW   PL           PSE
# 398                            EEKLO NOORD   BE          ELIA
# 402                                Ungheni   RO           TEL
# 408                              Heilbronn   DE    TRANSNETBW
# 412                                 Melina   HR          HOPS
# 413                               Pelicanu   RO           TEL
# 417                                 Pehlin   HR          HOPS
# 419                                  FWH-S   DE  Amprion GmbH
# 425                            P. Bystrica   SK          SEPS
# 430                              OSTROLEKA   PL           PSE
# 434                                 Pestis   RO           TEL
# 444                               Gradiste   RO           TEL
# 447                           OLSZTYN-MATK   PL           PSE
# 450                            Baia Mare 3   RO           TEL
# 452                                OXYLUX    DE         Creos
# 453                              Medzibrod   SK          SEPS
# 456                                Huntorf   DE    TENNETGMBH
# 459                              Sarasdorf   AT           APG
# 461                                  Lotru   RO           TEL
# 462                                Sostanj   SI          ELES
# 465                            S. Nova Ves   SK          SEPS
# 472                                  Salaj   RO           TEL
# 474                                 Sucany   SK          SEPS
# 475                    OFFSHORE SWITCHYARD   BE          ELIA
# 477                           Y-Gelsenberg   DE  Amprion GmbH
# 478                                ELK BIS   PL           PSE
# 487                              BERTRANGE   DE         Creos
# 495                             Alba Iulia   RO           TEL
# 497                             BRUME SNCB   BE          ELIA
# 499                              LA TROQUE   BE          ELIA
# 502                                 Pecs 2   HU         MAVIR
# 511                          PILA KRZEWINA   PL           PSE
# 519                     Turnu Severin Est    RO           TEL
# 521                               Hausruck   AT           APG
# 522                                 Bosaca   SK          SEPS
# 524                                Rilland   NL     TENNET NL
# 525                             Timisoara    RO           TEL
# 526                                  Klece   SI          ELES
# 531                                 GRAMME   BE          ELIA
# 532                              Oudehaske   NL     TENNET NL
# 538                    PIQUAGE A PLUVIGNER   FR           RTE
# 546                                  CHELM   PL           PSE
# 563                             Goettingen   DE    TENNETGMBH
# 572                        Waldlaubersheim   DE  Amprion GmbH
# 573                                Munteni   RO           TEL
# 577                     PIQUAGE A FONCROSE   FR           RTE
# 587                               Tiszalok   HU         MAVIR
# 588                              R. Sobota   SK          SEPS
# 593                  T.SUP / PRION - TAVEL   FR           RTE
# 596                                Slatina   RO           TEL
# 602                              Y-Homburg   DE  Amprion GmbH
# 608                           FAUX FRENAIS   FR           RTE
# 613                                 LE VAL   BE          ELIA
# 615                           Niederlangen   DE    TENNETGMBH
# 616                            SART-TILMAN   BE          ELIA
# 617                                ROUVROY   BE          ELIA
# 620                                  Klaus   AT           APG
# 630                               TE Sisak   HR          HOPS
# 639                             Brazi Vest   RO           TEL
# 641                             Etzersdorf   AT           APG
# 644                            Pitesti Sud   RO           TEL
# 647                                ST-MARD   BE          ELIA
# 648                                 Hasdat   RO           TEL
# 655                              Fantanele   RO           TEL
# 658                        LOMZA SYSTEMOWA   PL           PSE
# 663                               MIKULOWA   PL           PSE
# 672                              Tantareni   RO           TEL
# 674                            ACHENE SNCB   BE          ELIA
# 676                             Maasvlakte   NL     TENNET NL
# 677                                 Resita   RO           TEL
# 678                             Doetinchem   NL     TENNET NL
# 680                                 Brasov   RO           TEL
# 685                               Woringen   DE  Amprion GmbH
# 688             REPIQUAGE HOUFFALIZE 220kV   BE          ELIA
# 690                              Kronstorf   AT           APG
# 693                       Portile de Fier    RO           TEL
# 694                            Villach Süd   AT           APG
# 696                              Doerpen/W   DE    TENNETGMBH
# 697                                   Silz   DE    TENNETGMBH
# 710                         Calea Aradului   RO           TEL
# 715                                Filesti   RO           TEL
# 719                         Turnu Magurele   RO           TEL
# 721                               VAN EYCK   BE          ELIA
# 723                               POLANIEC   PL           PSE
# 730                               Mariselu   RO           TEL
# 732                           Szabolcsbaka   HU         MAVIR
# 733                              Eemshaven   NL     TENNET NL
# 734                             BOGUCHWALA   PL           PSE
# 735                                HEINSCH   BE          ELIA
# 748                                Retezat   RO           TEL
# 752                            STANISLAWOW   PL           PSE
# 754                                Suceava   RO           TEL
# 759                           WLOCLAWEK AZ   PL           PSE
# 768                                Homburg   DE  Amprion GmbH
# 770                                 ACHENE   BE          ELIA
# 771                             Y-Diefflen   DE  Amprion GmbH
# 784                            Felsozsolca   HU         MAVIR
# 785                              Uerdingen   DE  Amprion GmbH
# 793                            Putlitz/Süd   DE       50HERTZ
# 795                              Zeyerveen   NL     TENNET NL
# 800                                 RECLAW   PL           PSE
# 808                             Sibiu Sud    RO           TEL
# 809                              Eindhoven   NL     TENNET NL
# 810                             Weingarten   DE  Amprion GmbH
# 811                                Gadalin   RO           TEL
# 814                                   LINT   BE          ELIA
# 818                 Eemshaven het Hogeland   NL     TENNET NL
# 822                                L. Mara   SK          SEPS
# 824                           Schwoerstadt   DE    TRANSNETBW
# 826                              Y-Bidngen   DE  Amprion GmbH
# 828                              Metzingen   DE    TRANSNETBW
# 831                                 Plomin   HR          HOPS
# 841                              Louwsmeer   NL     TENNET NL
# 842             AFTAKKING RODENHUIZE 380kV   BE          ELIA
# 843                                  PRAGA   PL           PSE
# 846                                Stupina   RO           TEL
# 847                                Zeltweg   AT           APG
# 859                             Eemshaven    NL     TENNET NL
# 860                             Gelsenberg   DE  Amprion GmbH
# 862                                WROCLAW   PL           PSE
# 864                              Bleiswijk   NL     TENNET NL
# 865                                   Arad   RO           TEL
# 873                             Otelarie H   RO           TEL
# 874                           Medgidia Sud   RO           TEL
# 879                               Kisvarda   HU         MAVIR
# 881                                 BELVAL   BE          ELIA
# 882                          Campia Turzii   RO           TEL
# 891               REPIQUAGE MARCOURT 220kV   BE          ELIA
# 893                                Gransee   DE       50HERTZ
# 897                        Targiu Jiu Nord   RO           TEL
# 905                                BERNEAU   BE          ELIA
# 906                              Dodewaard   NL     TENNET NL
# 912                                  Sugag   RO           TEL
# 914                             Guetersloh   DE  Amprion GmbH
# 915                               Cluj Est   RO           TEL
# 917                              Timisoara   RO           TEL
# 923             AFTAKKING ZUTTENDAAL 380kV   BE          ELIA
# 927                             Meckenheim   DE  Amprion GmbH
# 932                             Bystricany   SK          SEPS
# 933              PIQUAGE A VILLIERS-LE-BEL   FR           RTE
# 934               REPIQUAGE ST-AMAND 380kV   BE          ELIA
# 937                          Bucuresti Sud   RO           TEL
# 942                              T HAL-BYĆ   PL           PSE
# 944                           P. Biskupice   SK          SEPS
# 947                            J. Bohunice   SK          SEPS
# 962                                  Siems   DE    TENNETGMBH
# 965                             Sardanesti   RO           TEL
# 966                             Gheorgheni   RO           TEL
# 970                        Portile de Fier   RO           TEL
# 972                        Gura Ialomitei    RO           TEL
# 982                         Zell am Ziller   AT           APG
# 985                           d. Mostistea   RO           TEL
# 994                              Lambsheim   DE  Amprion GmbH
# 1006                                Darste   RO           TEL
# 1009                               Zwolle    NL     TENNET NL
# 1257                             Sibiu Sud   RO           TEL
# 1264                            Dauersberg   DE  Amprion GmbH
# 1265                            Cierny Vah   SK          SEPS
# 1266                                SLUPSK   PL           PSE
# 1269                               Isaccea   RO           TEL
# 1271                         GRILLE-AVOINE   FR           RTE
# 1280                              Sattledt   AT           APG
# 1282                                Mintia   RO           TEL
# 1283                                STEVIN   BE          ELIA
# 1287                              MARCOURT   BE          ELIA
# 1291                                 AWIRS   BE          ELIA
# 1301                               Marbach   DE    TRANSNETBW
# 1307                             TIHANGE 2   BE          ELIA
# 1308                                Pecs 1   HU         MAVIR
# 1313                                Asslar   DE  Amprion GmbH
# 1317                      ZYDOWO KIERZKOWO   PL           PSE
# 1320                          Y-Guetersloh   DE  Amprion GmbH
# 1322                            Hessenberg   AT           APG
# 1324                                Greuth   AT           APG
# 1334                                IZEGEM   BE          ELIA
# 1342                           Jessen/Nord   DE       50HERTZ
# 1343                           Simonshaven   NL     TENNET NL
# 1350                              BERCHEM    DE         Creos
# 1351                              Ungheni    RO           TEL
# 1353                                Tauern   AT           APG
# 1358                          STALOWA WOLA   PL           PSE
# 1362                                Divaca   SI          ELES
# 1363                           Crayestein    NL     TENNET NL
# 1364                 Heinersdorf (Abzweig)   DE       50HERTZ
# 1369                             Lelystad    NL     TENNET NL
# 1374                             Handewitt   DE    TENNETGMBH
# 1377                                 Phyrn   AT           APG
# 1386                            BERTRANGE    DE         Creos
# 1388                                  GOUY   BE          ELIA
# 1392                                Brinje   HR          HOPS
# 1395                            POZNAN PLD   PL           PSE
# 1396                           Parchim/Süd   DE       50HERTZ
# 1397                          Focsani Vest   RO           TEL
# 1399                               Sacalaz   RO           TEL
# 1402                              Fundeni    RO           TEL
# 1406                             DROGENBOS   BE          ELIA
# 1411                             VE Padene   HR          HOPS
# 1414                             Beverwijk   NL     TENNET NL
# 1419                               LAGISZA   PL           PSE
# 1420                            Bleiswijk    NL     TENNET NL
# 1425                        Altenkleusheim   DE  Amprion GmbH
# 1427                             Villingen   DE    TRANSNETBW
# 1428                               TERGNEE   BE          ELIA
# 1430                            Suederdonn   DE    TENNETGMBH
# 1433                                LATOUR   BE          ELIA
# 1436                                PULAWY   PL           PSE
# 1437                      SIEDLCE UJRZANOW   PL           PSE
# 1439                              Teleajen   RO           TEL
# 1446                              Smardan    RO           TEL
# 1450                           Vijfhuizen    NL     TENNET NL
# 1459                          Emscherbruch   DE  Amprion GmbH
# 1463                          Targoviste B   RO           TEL
# 1469                            Oradea Sud   RO           TEL
# 1473                               Moldava   SK          SEPS
# 1474                                   Iaz   RO           TEL
# 1475                              H. Zdana   SK          SEPS
# 1476                           TIHANGE BIS   BE          ELIA
# 1478                             Gabcikovo   SK          SEPS
# 1484                              Mettmann   DE  Amprion GmbH
# 1485                            Bekescsaba   HU         MAVIR
# 1488                             TIHANGE 3   BE          ELIA
# 1489                               Aschach   AT           APG
# 1491                              OLTARZEW   PL           PSE
# 1492                               Weiwerd   NL     TENNET NL
# 1495                               Barbosi   RO           TEL
#
#                              name_norm  lat  lon osm_find
# 8                                varin  NaN  NaN
# 9                              seraing  NaN  NaN
# 18                       cluj floresti  NaN  NaN
# 19                             gezelle  NaN  NaN
# 20                             calafat  NaN  NaN
# 24                          szigetcsep  NaN  NaN
# 30                            mekingen  NaN  NaN
# 32                             rosiori  NaN  NaN
# 33                          wengerrohr  NaN  NaN
# 35                           velky dur  NaN  NaN
# 40                             boxmeer  NaN  NaN
# 42                       schwarzenbach  NaN  NaN
# 44                          buggenhout  NaN  NaN
# 45                             stejaru  NaN  NaN
# 52                              v. dur  NaN  NaN
# 61                              vojany  NaN  NaN
# 63                              zwolle  NaN  NaN
# 64                           urechesti  NaN  NaN
# 65                          sajoivanka  NaN  NaN
# 70                           eindhoven  NaN  NaN
# 72                              iernut  NaN  NaN
# 73                        fedderwarden  NaN  NaN
# 76                  breukelen kortrijk  NaN  NaN
# 79                 salzburg elixhausen  NaN  NaN
# 80                                senj  NaN  NaN
# 83                          lacu sarat  NaN  NaN
# 88                         ostrow wlkp  NaN  NaN
# 89                              pestis  NaN  NaN
# 91                        craiova nord  NaN  NaN
# 92                         h. zivotice  NaN  NaN
# 93                           kledering  NaN  NaN
# 94                               kallo  NaN  NaN
# 97                             dokegat  NaN  NaN
# 102                            smardan  NaN  NaN
# 104                     constanta nord  NaN  NaN
# 107                             rosegg  NaN  NaN
# 109                           isalnita  NaN  NaN
# 113                                fai  NaN  NaN
# 115                       gdansk-bloni  NaN  NaN
# 118                             schuby  NaN  NaN
# 122             piquage a saint gerons  NaN  NaN
# 124                            aniolow  NaN  NaN
# 150                    waldlaubersheim  NaN  NaN
# 151                            kerepes  NaN  NaN
# 153                        massenhoven  NaN  NaN
# 154                              arefu  NaN  NaN
# 157                tran5 / gavre perta  NaN  NaN
# 158                          westerlee  NaN  NaN
# 161                         schwelgern  NaN  NaN
# 173                                gkm  NaN  NaN
# 174                             kosice  NaN  NaN
# 177                           ghizdaru  NaN  NaN
# 179                        porabka-zar  NaN  NaN
# 181                            jupille  NaN  NaN
# 185                            galceag  NaN  NaN
# 187                            zakucac  NaN  NaN
# 188                         rodenhuize  NaN  NaN
# 200                          dettingen  NaN  NaN
# 201                           elsfleth  NaN  NaN
# 207                          neunhagen  NaN  NaN
# 208              repiquage senonchamps  NaN  NaN
# 210                           stuparei  NaN  NaN
# 213                               detk  NaN  NaN
# 225                             cetate  NaN  NaN
# 228                              bradu  NaN  NaN
# 231                        torun elana  NaN  NaN
# 239                     targu jiu nord  NaN  NaN
# 241                            ternitz  NaN  NaN
# 245                         wateringen  NaN  NaN
# 247                          hessenweg  NaN  NaN
# 248                        v. kapusany  NaN  NaN
# 249                              lixhe  NaN  NaN
# 252                       kottigerhook  NaN  NaN
# 253                          mayrhofen  NaN  NaN
# 260                             levice  NaN  NaN
# 265                          plattling  NaN  NaN
# 270                              brume  NaN  NaN
# 272                        weissenbach  NaN  NaN
# 274                              bayer  NaN  NaN
# 275                          cernavoda  NaN  NaN
# 278                              lillo  NaN  NaN
# 572                    waldlaubersheim  NaN  NaN
# 573                            munteni  NaN  NaN
# 577                 piquage a foncrose  NaN  NaN
# 587                           tiszalok  NaN  NaN
# 588                          r. sobota  NaN  NaN
# 593              t.sup / prion - tavel  NaN  NaN
# 596                            slatina  NaN  NaN
# 602                            homburg  NaN  NaN
# 608                       faux frenais  NaN  NaN
# 613                             le val  NaN  NaN
# 615                       niederlangen  NaN  NaN
# 616                        sart-tilman  NaN  NaN
# 617                            rouvroy  NaN  NaN
# 620                              klaus  NaN  NaN
# 630                           te sisak  NaN  NaN
# 639                         brazi vest  NaN  NaN
# 641                         etzersdorf  NaN  NaN
# 644                        pitesti sud  NaN  NaN
# 647                            st-mard  NaN  NaN
# 648                             hasdat  NaN  NaN
# 655                          fantanele  NaN  NaN
# 658                    lomza systemowa  NaN  NaN
# 663                           mikulowa  NaN  NaN
# 672                          tantareni  NaN  NaN
# 674                        achene sncb  NaN  NaN
# 676                         maasvlakte  NaN  NaN
# 677                             resita  NaN  NaN
# 678                          dotinchem  NaN  NaN
# 680                             brasov  NaN  NaN
# 685                           woringen  NaN  NaN
# 688               repiquage houffalize  NaN  NaN
# 690                          kronstorf  NaN  NaN
# 693                    portile de fier  NaN  NaN
# 694                        villach sud  NaN  NaN
# 696                             dorpen  NaN  NaN
# 697                               silz  NaN  NaN
# 710                     calea aradului  NaN  NaN
# 715                            filesti  NaN  NaN
# 719                     turnu magurele  NaN  NaN
# 721                           van eyck  NaN  NaN
# 723                           polaniec  NaN  NaN
# 730                           mariselu  NaN  NaN
# 732                       szabolcsbaka  NaN  NaN
# 733                          eemshaven  NaN  NaN
# 734                         boguchwala  NaN  NaN
# 735                            heinsch  NaN  NaN
# 748                            retezat  NaN  NaN
# 752                        stanislawow  NaN  NaN
# 754                            suceava  NaN  NaN
# 759                       wloclawek az  NaN  NaN
# 768                            homburg  NaN  NaN
# 770                             achene  NaN  NaN
# 771                           diefflen  NaN  NaN
# 784                        felsozsolca  NaN  NaN
# 785                           urdingen  NaN  NaN
# 793                            putlitz  NaN  NaN
# 795                          zeyerveen  NaN  NaN
# 800                             reclaw  NaN  NaN
# 808                          sibiu sud  NaN  NaN
# 809                          eindhoven  NaN  NaN
# 810                         weingarten  NaN  NaN
# 811                            gadalin  NaN  NaN
# 814                               lint  NaN  NaN
# 818             eemshaven het hogeland  NaN  NaN
# 822                            l. mara  NaN  NaN
# 824                        schworstadt  NaN  NaN
# 826                            bidngen  NaN  NaN
# 828                          metzingen  NaN  NaN
# 831                             plomin  NaN  NaN
# 841                          louwsmeer  NaN  NaN
# 842                         rodenhuize  NaN  NaN
# 843                              praga  NaN  NaN
# 846                            stupina  NaN  NaN
# 847                            zeltweg  NaN  NaN
# 859                          eemshaven  NaN  NaN
# 860                         gelsenberg  NaN  NaN
# 862                            wroclaw  NaN  NaN
# 864                          bleiswijk  NaN  NaN
# 865                               arad  NaN  NaN
# 873                         otelarie h  NaN  NaN
# 874                       medgidia sud  NaN  NaN
# 879                           kisvarda  NaN  NaN
# 1484                          mettmann  NaN  NaN
# 1485                        bekescsaba  NaN  NaN
# 1488                         tihange 3  NaN  NaN
# 1489                           aschach  NaN  NaN
# 1491                          oltarzew  NaN  NaN
# 1492                           weiwerd  NaN  NaN
# 1495                           barbosi  NaN  NaN

# %%
for index, row in df_missing_jao_osm.iterrows():
    try:
        osm_find = ox.geocode_to_gdf(row['name_norm'] + ', ' + row['zone'])
        if len(osm_find) > 0:
            df_missing_jao_osm.loc[index, 'osm_find'] = osm_find.loc[0, 'display_name']
            df_missing_jao_osm.loc[index, 'lat'] = osm_find.loc[0, 'lat']
            df_missing_jao_osm.loc[index, 'lon'] = osm_find.loc[0, 'lon']
    except ValueError as ve:
        pass
    
display(df_missing_jao_osm)
# Out:
#                                       name zone           tso  \
# 8                                    Varin   SK          SEPS
# 9                                  SERAING   BE          ELIA
# 18                           Cluj Floresti   RO           TEL
# 19                                 GEZELLE   BE          ELIA
# 20                                 Calafat   RO           TEL
# 24                              Szigetcsep   HU         MAVIR
# 30                AFTAKKING MEKINGEN 380kV   BE          ELIA
# 32                                Rosiori    RO           TEL
# 33                              Wengerrohr   DE  Amprion GmbH
# 35                               Velky Dur   SK          SEPS
# 40                                Boxmeer    NL     TENNET NL
# 42                           Schwarzenbach   AT           APG
# 44              AFTAKKING BUGGENHOUT 380kV   BE          ELIA
# 45                                 Stejaru   RO           TEL
# 52                                  V. Dur   SK          SEPS
# 61                                  Vojany   SK          SEPS
# 63                                  Zwolle   NL     TENNET NL
# 64                               Urechesti   RO           TEL
# 65                              Sajoivanka   HU         MAVIR
# 70                              Eindhoven    NL     TENNET NL
# 72                                  Iernut   RO           TEL
# 73                            Fedderwarden   DE    TENNETGMBH
# 76                      Breukelen Kortrijk   NL     TENNET NL
# 79                     Salzburg Elixhausen   AT           APG
# 80                                    Senj   HR          HOPS
# 83                              Lacu Sarat   RO           TEL
# 88                             OSTROW WLKP   PL           PSE
# 89                                 Pestis    RO           TEL
# 91                            Craiova Nord   RO           TEL
# 92                             H. Zivotice   CZ          CEPS
# 93                               Kledering   AT           APG
# 94                                   KALLO   BE          ELIA
# 97                               Doekegat    NL     TENNET NL
# 102                                Smardan   RO           TEL
# 104                         Constanta Nord   RO           TEL
# 107                                 Rosegg   AT           APG
# 109                               Isalnita   RO           TEL
# 113                                    FAI   RO           TEL
# 115                           GDANSK-BLONI   PL           PSE
# 118                               Schuby/W   DE    TENNETGMBH
# 122                 PIQUAGE A SAINT GERONS   FR           RTE
# 124                                ANIOLOW   PL           PSE
# 150                      Y-Waldlaubersheim   DE  Amprion GmbH
# 151                                Kerepes   HU         MAVIR
# 153                            MASSENHOVEN   BE          ELIA
# 154                                  Arefu   RO           TEL
# 157                  TRAN5 / GAVRE PERTA 1   FR           RTE
# 158                             Westerlee    NL     TENNET NL
# 161                           Y-Schwelgern   DE  Amprion GmbH
# 173                                    GKM   DE    TRANSNETBW
# 174                                 Kosice   SK          SEPS
# 177                               Ghizdaru   RO           TEL
# 179                            PORABKA-ZAR   PL           PSE
# 181                                JUPILLE   BE          ELIA
# 185                                Galceag   RO           TEL
# 187                                Zakucac   HR          HOPS
# 188                             RODENHUIZE   BE          ELIA
# 200                              Dettingen   DE  Amprion GmbH
# 201                             Elsfleth/W   DE    TENNETGMBH
# 207                             Neuenhagen   DE       50HERTZ
# 208            REPIQUAGE SENONCHAMPS 220kV   BE          ELIA
# 210                               Stuparei   RO           TEL
# 213                                   Detk   HU         MAVIR
# 225                                 Cetate   RO           TEL
# 228                                  Bradu   RO           TEL
# 231                            TORUN ELANA   PL           PSE
# 239                         Targu Jiu Nord   RO           TEL
# 241                                Ternitz   AT           APG
# 245                             Wateringen   NL     TENNET NL
# 247                              Hessenweg   NL     TENNET NL
# 248                            V. Kapusany   SK          SEPS
# 249                                  LIXHE   BE          ELIA
# 252                           Kottigerhook   DE  Amprion GmbH
# 253                              Mayrhofen   AT           APG
# 260                                 Levice   SK          SEPS
# 265                            Y-Plattling   DE    TENNETGMBH
# 270                                  BRUME   BE          ELIA
# 272                            Weissenbach   AT           APG
# 274                                  Bayer   DE  Amprion GmbH
# 275                              Cernavoda   RO           TEL
# 278                                  LILLO   BE          ELIA
# 279                              Baru Mare   RO           TEL
# 280                              Y-Waldeck   DE    TENNETGMBH
# 281                                 Siroka   SK          SEPS
# 283                               C. Stred   CZ          CEPS
# 290                                Oechtel   DE  Amprion GmbH
# 296                     Krimpen a/d IJssel   NL     TENNET NL
# 299                                 Stalpu   RO           TEL
# 300                                  Tihau   RO           TEL
# 301                               Domnesti   RO           TEL
# 310                                  Nadab   RO           TEL
# 312                                Wallsee   AT           APG
# 315                                   Vola   SK          SEPS
# 318                              Bacharach   DE  Amprion GmbH
# 322                               Diefflen   DE  Amprion GmbH
# 328                        GDANSK PRZYJAZN   PL           PSE
# 329                               MAERLANT   BE          ELIA
# 332                             H.Zivotice   CZ          CEPS
# 333                               Lelystad   NL     TENNET NL
# 339                            Heinersdorf   DE       50HERTZ
# 344                             Ernsthofen   AT           APG
# 345                            Robbenplaat   NL     TENNET NL
# 351                         Gura Ialomitei   RO           TEL
# 354                   Eemshaven Oude Schip   NL     TENNET NL
# 355                                Okroglo   SI          ELES
# 357                               Bericevo   SI          ELES
# 358                              Feistritz   AT           APG
# 363                    PIQUAGE A DUVIGNEAU   FR           RTE
# 366                              Westerlee   NL     TENNET NL
# 367                              Tariverde   RO           TEL
# 372                               Dumbrava   RO           TEL
# 375                               MEERHOUT   BE          ELIA
# 379           AFTAKKING LIEFKENSHOEK 380kV   BE          ELIA
# 383                                Husum/N   DE    TENNETGMBH
# 385                           Targoviste A   RO           TEL
# 388                           ST-MARD SNCB   BE          ELIA
# 389                           Y-Dauersberg   DE  Amprion GmbH
# 392                               BLOOREN    DE         Creos
# 394                              Bacau Sud   RO           TEL
# 396                                PELPLIN   PL           PSE
# 397                                 GORZOW   PL           PSE
# 398                            EEKLO NOORD   BE          ELIA
# 402                                Ungheni   RO           TEL
# 408                              Heilbronn   DE    TRANSNETBW
# 412                                 Melina   HR          HOPS
# 413                               Pelicanu   RO           TEL
# 417                                 Pehlin   HR          HOPS
# 419                                  FWH-S   DE  Amprion GmbH
# 425                            P. Bystrica   SK          SEPS
# 430                              OSTROLEKA   PL           PSE
# 434                                 Pestis   RO           TEL
# 444                               Gradiste   RO           TEL
# 447                           OLSZTYN-MATK   PL           PSE
# 450                            Baia Mare 3   RO           TEL
# 452                                OXYLUX    DE         Creos
# 453                              Medzibrod   SK          SEPS
# 456                                Huntorf   DE    TENNETGMBH
# 459                              Sarasdorf   AT           APG
# 461                                  Lotru   RO           TEL
# 462                                Sostanj   SI          ELES
# 465                            S. Nova Ves   SK          SEPS
# 472                                  Salaj   RO           TEL
# 474                                 Sucany   SK          SEPS
# 475                    OFFSHORE SWITCHYARD   BE          ELIA
# 477                           Y-Gelsenberg   DE  Amprion GmbH
# 478                                ELK BIS   PL           PSE
# 487                              BERTRANGE   DE         Creos
# 495                             Alba Iulia   RO           TEL
# 497                             BRUME SNCB   BE          ELIA
# 499                              LA TROQUE   BE          ELIA
# 502                                 Pecs 2   HU         MAVIR
# 511                          PILA KRZEWINA   PL           PSE
# 519                     Turnu Severin Est    RO           TEL
# 521                               Hausruck   AT           APG
# 522                                 Bosaca   SK          SEPS
# 524                                Rilland   NL     TENNET NL
# 525                             Timisoara    RO           TEL
# 526                                  Klece   SI          ELES
# 531                                 GRAMME   BE          ELIA
# 532                              Oudehaske   NL     TENNET NL
# 538                    PIQUAGE A PLUVIGNER   FR           RTE
# 546                                  CHELM   PL           PSE
# 563                             Goettingen   DE    TENNETGMBH
# 572                        Waldlaubersheim   DE  Amprion GmbH
# 573                                Munteni   RO           TEL
# 577                     PIQUAGE A FONCROSE   FR           RTE
# 587                               Tiszalok   HU         MAVIR
# 588                              R. Sobota   SK          SEPS
# 593                  T.SUP / PRION - TAVEL   FR           RTE
# 596                                Slatina   RO           TEL
# 602                              Y-Homburg   DE  Amprion GmbH
# 608                           FAUX FRENAIS   FR           RTE
# 613                                 LE VAL   BE          ELIA
# 615                           Niederlangen   DE    TENNETGMBH
# 616                            SART-TILMAN   BE          ELIA
# 617                                ROUVROY   BE          ELIA
# 620                                  Klaus   AT           APG
# 630                               TE Sisak   HR          HOPS
# 639                             Brazi Vest   RO           TEL
# 641                             Etzersdorf   AT           APG
# 644                            Pitesti Sud   RO           TEL
# 647                                ST-MARD   BE          ELIA
# 648                                 Hasdat   RO           TEL
# 655                              Fantanele   RO           TEL
# 658                        LOMZA SYSTEMOWA   PL           PSE
# 663                               MIKULOWA   PL           PSE
# 672                              Tantareni   RO           TEL
# 674                            ACHENE SNCB   BE          ELIA
# 676                             Maasvlakte   NL     TENNET NL
# 677                                 Resita   RO           TEL
# 678                             Doetinchem   NL     TENNET NL
# 680                                 Brasov   RO           TEL
# 685                               Woringen   DE  Amprion GmbH
# 688             REPIQUAGE HOUFFALIZE 220kV   BE          ELIA
# 690                              Kronstorf   AT           APG
# 693                       Portile de Fier    RO           TEL
# 694                            Villach Süd   AT           APG
# 696                              Doerpen/W   DE    TENNETGMBH
# 697                                   Silz   DE    TENNETGMBH
# 710                         Calea Aradului   RO           TEL
# 715                                Filesti   RO           TEL
# 719                         Turnu Magurele   RO           TEL
# 721                               VAN EYCK   BE          ELIA
# 723                               POLANIEC   PL           PSE
# 730                               Mariselu   RO           TEL
# 732                           Szabolcsbaka   HU         MAVIR
# 733                              Eemshaven   NL     TENNET NL
# 734                             BOGUCHWALA   PL           PSE
# 735                                HEINSCH   BE          ELIA
# 748                                Retezat   RO           TEL
# 752                            STANISLAWOW   PL           PSE
# 754                                Suceava   RO           TEL
# 759                           WLOCLAWEK AZ   PL           PSE
# 768                                Homburg   DE  Amprion GmbH
# 770                                 ACHENE   BE          ELIA
# 771                             Y-Diefflen   DE  Amprion GmbH
# 784                            Felsozsolca   HU         MAVIR
# 785                              Uerdingen   DE  Amprion GmbH
# 793                            Putlitz/Süd   DE       50HERTZ
# 795                              Zeyerveen   NL     TENNET NL
# 800                                 RECLAW   PL           PSE
# 808                             Sibiu Sud    RO           TEL
# 809                              Eindhoven   NL     TENNET NL
# 810                             Weingarten   DE  Amprion GmbH
# 811                                Gadalin   RO           TEL
# 814                                   LINT   BE          ELIA
# 818                 Eemshaven het Hogeland   NL     TENNET NL
# 822                                L. Mara   SK          SEPS
# 824                           Schwoerstadt   DE    TRANSNETBW
# 826                              Y-Bidngen   DE  Amprion GmbH
# 828                              Metzingen   DE    TRANSNETBW
# 831                                 Plomin   HR          HOPS
# 841                              Louwsmeer   NL     TENNET NL
# 842             AFTAKKING RODENHUIZE 380kV   BE          ELIA
# 843                                  PRAGA   PL           PSE
# 846                                Stupina   RO           TEL
# 847                                Zeltweg   AT           APG
# 859                             Eemshaven    NL     TENNET NL
# 860                             Gelsenberg   DE  Amprion GmbH
# 862                                WROCLAW   PL           PSE
# 864                              Bleiswijk   NL     TENNET NL
# 865                                   Arad   RO           TEL
# 873                             Otelarie H   RO           TEL
# 874                           Medgidia Sud   RO           TEL
# 879                               Kisvarda   HU         MAVIR
# 881                                 BELVAL   BE          ELIA
# 882                          Campia Turzii   RO           TEL
# 891               REPIQUAGE MARCOURT 220kV   BE          ELIA
# 893                                Gransee   DE       50HERTZ
# 897                        Targiu Jiu Nord   RO           TEL
# 905                                BERNEAU   BE          ELIA
# 906                              Dodewaard   NL     TENNET NL
# 912                                  Sugag   RO           TEL
# 914                             Guetersloh   DE  Amprion GmbH
# 915                               Cluj Est   RO           TEL
# 917                              Timisoara   RO           TEL
# 923             AFTAKKING ZUTTENDAAL 380kV   BE          ELIA
# 927                             Meckenheim   DE  Amprion GmbH
# 932                             Bystricany   SK          SEPS
# 933              PIQUAGE A VILLIERS-LE-BEL   FR           RTE
# 934               REPIQUAGE ST-AMAND 380kV   BE          ELIA
# 937                          Bucuresti Sud   RO           TEL
# 942                              T HAL-BYĆ   PL           PSE
# 944                           P. Biskupice   SK          SEPS
# 947                            J. Bohunice   SK          SEPS
# 962                                  Siems   DE    TENNETGMBH
# 1478                             Gabcikovo   SK          SEPS
# 1484                              Mettmann   DE  Amprion GmbH
# 1485                            Bekescsaba   HU         MAVIR
# 1488                             TIHANGE 3   BE          ELIA
# 1489                               Aschach   AT           APG
# 1491                              OLTARZEW   PL           PSE
# 1492                               Weiwerd   NL     TENNET NL
# 1495                               Barbosi   RO           TEL
#
#                              name_norm        lat        lon  \
# 8                                varin  49.201440  18.870500
# 9                              seraing  50.615238   5.508944
# 18                       cluj floresti  46.734300  23.484684
# 19                             gezelle  50.981025   3.532871
# 20                             calafat  43.994298  22.933703
# 24                          szigetcsep  47.267148  18.967267
# 30                            mekingen        NaN        NaN
# 32                             rosiori  47.256772  21.952090
# 33                          wengerrohr        NaN        NaN
# 35                           velky dur  48.211488  18.446216
# 40                             boxmeer  51.648648   5.945097
# 42                       schwarzenbach  47.643077  16.345530
# 44                          buggenhout  51.011310   4.192796
# 45                             stejaru  44.837792  25.960621
# 52                              v. dur        NaN        NaN
# 61                              vojany  48.569612  21.989984
# 63                              zwolle  52.508976   6.094377
# 64                           urechesti  46.132502  27.086014
# 65                          sajoivanka  48.266106  20.579371
# 70                           eindhoven  51.439265   5.478633
# 72                              iernut  46.450190  24.230670
# 73                        fedderwarden  53.562879   8.044606
# 76                  breukelen kortrijk  52.164415   4.991268
# 79                 salzburg elixhausen  47.861606  13.062070
# 80                                senj        NaN        NaN
# 83                          lacu sarat  45.221858  28.180003
# 88                         ostrow wlkp  51.647186  17.803761
# 89                              pestis  47.073183  22.413666
# 91                        craiova nord        NaN        NaN
# 92                         h. zivotice        NaN        NaN
# 93                           kledering        NaN        NaN
# 94                               kallo  51.251951   4.278030
# 97                             dokegat        NaN        NaN
# 102                            smardan  45.472415  27.945631
# 104                     constanta nord        NaN        NaN
# 107                             rosegg  46.589813  14.020088
# 109                           isalnita  44.394651  23.733251
# 113                                fai        NaN        NaN
# 115                       gdansk-bloni        NaN        NaN
# 118                             schuby  54.515820   9.480011
# 122             piquage a saint gerons        NaN        NaN
# 124                            aniolow        NaN        NaN
# 150                    waldlaubersheim  49.928579   7.833602
# 151                            kerepes  47.561613  19.286907
# 153                        massenhoven  51.199020   4.634960
# 154                              arefu  45.329963  24.609821
# 157                tran5 / gavre perta        NaN        NaN
# 158                          westerlee  53.145140   6.987570
# 161                         schwelgern  51.512999   6.741340
# 173                                gkm  11.932303  79.807929
# 174                             kosice  48.717227  21.249677
# 177                           ghizdaru  43.931678  25.882699
# 179                        porabka-zar  49.787367  19.230216
# 181                            jupille        NaN        NaN
# 185                            galceag        NaN        NaN
# 187                            zakucac  43.457284  16.700039
# 188                         rodenhuize        NaN        NaN
# 200                          dettingen  47.735217   9.117262
# 201                           elsfleth  53.235703   8.457104
# 207                          neunhagen        NaN        NaN
# 208              repiquage senonchamps        NaN        NaN
# 210                           stuparei  45.017362  24.280039
# 213                               detk  47.747533  20.099297
# 225                             cetate  44.111426  23.047551
# 228                              bradu  45.721032  24.328952
# 231                        torun elana        NaN        NaN
# 239                     targu jiu nord        NaN        NaN
# 241                            ternitz  47.706601  16.019469
# 245                         wateringen  52.023510   4.274585
# 247                          hessenweg        NaN        NaN
# 248                        v. kapusany        NaN        NaN
# 249                              lixhe        NaN        NaN
# 252                       kottigerhook        NaN        NaN
# 253                          mayrhofen  47.167219  11.863866
# 260                             levice  48.216319  18.600087
# 265                          plattling  48.777256  12.875067
# 270                              brume        NaN        NaN
# 272                        weissenbach        NaN        NaN
# 274                              bayer  40.489296  -3.390595
# 275                          cernavoda  44.341635  28.031625
# 278                              lillo  51.314172   4.315093
# 279                          baru mare        NaN        NaN
# 280                            waldeck  51.242511   9.038121
# 281                             siroka  48.998998  20.942990
# 283                           c. stred  50.680336  14.021389
# 290                             ochtel        NaN        NaN
# 296                 krimpen a/d ijssel  51.914403   4.588789
# 299                             stalpu  45.085186  26.708386
# 300                              tihau  47.226562  23.329453
# 301                           domnesti  45.206701  24.839921
# 310                              nadab        NaN        NaN
# 312                            wallsee        NaN        NaN
# 315                               vola  48.841016  21.843886
# 318                          bacharach  50.059794   7.768400
# 322                           diefflen  49.378573   6.752723
# 328                    gdansk przyjazn        NaN        NaN
# 329                            marlant        NaN        NaN
# 332                         h.zivotice        NaN        NaN
# 333                           lelystad  52.515095   5.476891
# 339                        heinersdorf  52.572825  13.437015
# 344                         ernsthofen  48.138839  14.499729
# 345                        robbenplaat  52.839278   5.015358
# 351                     gura ialomitei  44.709597  27.756048
# 354               eemshaven oude schip        NaN        NaN
# 355                            okroglo        NaN        NaN
# 357                           bericevo        NaN        NaN
# 358                          feistritz  47.599908  16.054196
# 363                piquage a duvigneau        NaN        NaN
# 366                          westerlee  53.145140   6.987570
# 367                          tariverde  44.562932  28.601927
# 372                           dumbrava  46.825020  23.217628
# 375                           meerhout  51.131743   5.077239
# 379                        liefkenshok        NaN        NaN
# 383                              husum  54.485364   9.053816
# 385                       targoviste a  44.926771  25.462816
# 388                       st-mard sncb        NaN        NaN
# 389                          daursberg        NaN        NaN
# 392                            blooren  49.597148   6.179656
# 394                          bacau sud        NaN        NaN
# 396                            pelplin  53.928322  18.697849
# 397                             gorzow  51.028155  18.422268
# 398                        eeklo noord  51.034251   3.710259
# 402                            ungheni  46.483480  24.457419
# 408                          heilbronn  49.142291   9.218655
# 412                             melina        NaN        NaN
# 413                           pelicanu        NaN        NaN
# 417                             pehlin  45.353702  14.404340
# 419                              fwh-s        NaN        NaN
# 425                        p. bystrica  48.571736  19.191238
# 430                          ostroleka  53.078032  21.574869
# 434                             pestis  47.073183  22.413666
# 444                           gradiste        NaN        NaN
# 447                       olsztyn-matk        NaN        NaN
# 450                        baia mare 3  47.677543  23.620772
# 452                             oxylux        NaN        NaN
# 453                          medzibrod  48.793399  19.357108
# 456                            huntorf  53.190333   8.408952
# 459                          sarasdorf  48.028250  16.675017
# 461                              lotru  45.337653  24.251981
# 462                            sostanj  46.377393  15.045951
# 465                        s. nova ves        NaN        NaN
# 472                              salaj  47.156187  23.019192
# 474                             sucany  48.732646  18.468924
# 475                offshore switchyard        NaN        NaN
# 477                         gelsenberg  51.530226   7.038534
# 478                            elk bis        NaN        NaN
# 487                          bertrange        NaN        NaN
# 495                         alba iulia  46.071344  23.572079
# 497                         brume sncb        NaN        NaN
# 499                           la troqu        NaN        NaN
# 502                               pecs  46.076588  18.228040
# 511                      pila krzewina        NaN        NaN
# 519                    turnu severin e        NaN        NaN
# 521                           hausruck        NaN        NaN
# 522                             bosaca  48.826459  17.842651
# 524                            rilland  51.416475   4.181242
# 525                          timisoara  45.753836  21.225747
# 526                              klece        NaN        NaN
# 531                             gramme  50.294046   5.105242
# 532                          oudehaske  52.956109   5.872593
# 538                piquage a pluvigner        NaN        NaN
# 546                              chelm  51.135588  23.493936
# 563                          gottingen  51.532833   9.935181
# 572                    waldlaubersheim  49.928579   7.833602
# 573                            munteni  47.315302  27.138395
# 577                 piquage a foncrose        NaN        NaN
# 587                           tiszalok  48.017176  21.374966
# 588                          r. sobota  48.395701  20.000662
# 593              t.sup / prion - tavel        NaN        NaN
# 596                            slatina  44.429997  24.363184
# 602                            homburg  49.318167   7.334034
# 608                       faux frenais        NaN        NaN
# 613                             le val  50.604165   5.492740
# 615                       niederlangen  52.857217   7.280537
# 616                        sart-tilman        NaN        NaN
# 617                            rouvroy  49.539075   5.489710
# 620                              klaus  47.307759   9.647796
# 630                           te sisak  45.454009  16.413934
# 639                         brazi vest  44.955282  25.998502
# 641                         etzersdorf        NaN        NaN
# 644                        pitesti sud        NaN        NaN
# 647                            st-mard  49.541631   5.533392
# 648                             hasdat        NaN        NaN
# 655                          fantanele  47.414977  27.180664
# 658                    lomza systemowa        NaN        NaN
# 663                           mikulowa  51.080773  15.108735
# 672                          tantareni  44.593640  23.494135
# 674                        achene sncb        NaN        NaN
# 676                         maasvlakte  51.954352   4.019799
# 677                             resita  45.306083  21.885453
# 678                          dotinchem        NaN        NaN
# 680                             brasov  45.652309  25.610275
# 685                           woringen  47.923405  10.200843
# 688               repiquage houffalize        NaN        NaN
# 690                          kronstorf  48.142235  14.464465
# 693                    portile de fier  44.671252  22.529502
# 694                        villach sud  46.553823  13.828503
# 696                             dorpen  52.965332   7.331334
# 697                               silz  53.520291  12.441071
# 710                     calea aradului        NaN        NaN
# 715                            filesti        NaN        NaN
# 719                     turnu magurele  43.751831  24.869172
# 721                           van eyck  50.847959   3.110061
# 723                           polaniec  50.432907  21.281047
# 730                           mariselu  47.011928  24.508094
# 732                       szabolcsbaka  48.157223  22.139586
# 733                          eemshaven  53.448474   6.849963
# 734                         boguchwala  49.980688  21.939182
# 735                            heinsch  49.689336   5.758716
# 748                            retezat  45.324775  22.787799
# 752                        stanislawow  52.291113  21.549116
# 754                            suceava  47.532653  25.834594
# 759                       wloclawek az        NaN        NaN
# 768                            homburg  49.318167   7.334034
# 770                             achene        NaN        NaN
# 771                           diefflen  49.378573   6.752723
# 784                        felsozsolca  48.104100  20.860540
# 785                           urdingen        NaN        NaN
# 793                            putlitz  53.250672  12.040672
# 795                          zeyerveen        NaN        NaN
# 800                             reclaw        NaN        NaN
# 808                          sibiu sud        NaN        NaN
# 809                          eindhoven  51.439265   5.478633
# 810                         weingarten  47.807530   9.643114
# 811                            gadalin  46.840221  23.848517
# 814                               lint  51.126830   4.492219
# 818             eemshaven het hogeland  53.448474   6.849963
# 822                            l. mara        NaN        NaN
# 824                        schworstadt  47.592284   7.873819
# 826                            bidngen        NaN        NaN
# 828                          metzingen  48.539725   9.283120
# 831                             plomin        NaN        NaN
# 841                          louwsmeer        NaN        NaN
# 842                         rodenhuize        NaN        NaN
# 843                              praga  51.646230  20.946580
# 846                            stupina  44.565368  28.179262
# 847                            zeltweg  47.191204  14.754924
# 859                          eemshaven  53.448474   6.849963
# 860                         gelsenberg  51.530226   7.038534
# 862                            wroclaw  51.108978  17.032669
# 864                          bleiswijk  52.010958   4.531084
# 865                               arad  46.175379  21.319634
# 873                         otelarie h        NaN        NaN
# 874                       medgidia sud  44.259590  28.263270
# 879                           kisvarda  48.225759  22.078425
# 881                             belval  49.039940  -1.363712
# 882                      campia turzii  46.547181  23.886967
# 891                 repiquage marcourt        NaN        NaN
# 893                            gransee  53.007278  13.158869
# 897                    targiu jiu nord        NaN        NaN
# 905                            berneau        NaN        NaN
# 906                          dodewaard  51.914005   5.656939
# 912                              sugag  45.775693  23.626991
# 914                          gutersloh  51.906400   8.378208
# 915                           cluj est        NaN        NaN
# 917                          timisoara  45.753836  21.225747
# 923                         zuttendaal        NaN        NaN
# 927                         meckenheim  49.404621   8.239793
# 932                         bystricany  48.658944  18.517726
# 933          piquage a villiers-le-bel        NaN        NaN
# 934                 repiquage st-amand        NaN        NaN
# 937                      bucuresti sud  44.921164  26.032431
# 942                          t hal-byc        NaN        NaN
# 944                       p. biskupice  48.123789  17.209001
# 947                        j. bohunice  48.477879  17.635222
# 962                              siems        NaN        NaN
# 965                         sardanesti  44.770860  23.360874
# 966                         gheorgheni  46.721347  25.599891
# 970                    portile de fier  44.671252  22.529502
# 972                     gura ialomitei  44.709597  27.756048
# 982                     zell am ziller  47.226486  11.881920
# 985                       d. mostistea        NaN        NaN
# 994                          lambsheim  49.510326   8.286195
# 1006                            darste  45.618844  25.653600
# 1009                            zwolle  52.508976   6.094377
# 1013  beauregard (saint-laurent-nouan)  47.718404   1.701998
# 1017                           milosna  51.012457  15.510220
# 1025                      altentreptow  53.692903  13.251246
# 1028                            ochtel        NaN        NaN
# 1030                           gutinas  46.206674  26.820528
# 1036                        houffalize  50.132376   5.788693
# 1037                      altentreptow  53.692903  13.251246
# 1039                       ohlensehlen        NaN        NaN
# 1043                        schwelgern  51.512999   6.741340
# 1045                       rommersheim  50.193680   6.444693
# 1047                          mochovce  48.264748  18.438051
# 1048                            brugel        NaN        NaN
# 1057                            kuhtai        NaN        NaN
# 1069                         stalldorf        NaN        NaN
# 1070                              zaya  48.606149  16.799900
# 1071                           waldeck  51.242511   9.038121
# 1083                          isalnita  44.394651  23.733251
# 1089                  repiquage latour        NaN        NaN
# 1091                  dreibein mellach        NaN        NaN
# 1097                            rahman  44.799195  28.272857
# 1101                        bellendorf  51.669924   6.981617
# 1103                             plock  52.546452  19.700861
# 1105                            untrop        NaN        NaN
# 1111                             jozsa        NaN        NaN
# 1112                      centrale coo        NaN        NaN
# 1114                           aubange        NaN        NaN
# 1116                          bastogne  50.002310   5.717339
# 1122                      niederlangen  52.857217   7.280537
# 1126                      andre dumont  50.640860   5.575123
# 1129                         t joa-lag        NaN        NaN
# 1131                    draganesti olt  44.168473  24.521972
# 1133                          ybbsfeld  48.129702  14.953963
# 1135                          ruhrzink        NaN        NaN
# 1142                             horta  50.829761   5.113147
# 1143                           dresden  51.049329  13.738144
# 1145                       tulcea vest  45.181420  28.793183
# 1151                              sala  48.151379  17.874859
# 1154                            romsee        NaN        NaN
# 1157                            resita  45.306083  21.885453
# 1163                         villeroux  49.978180   5.656267
# 1164                           perkata  47.047973  18.790124
# 1168                      saint hubert  49.222747   6.333195
# 1171                           meduric  45.458311  16.927502
# 1178                           losnice        NaN        NaN
# 1182        piquage a la praz-st-andre        NaN        NaN
# 1184                         plattling  48.777256  12.875067
# 1188                       dorpen west  52.980959   7.256659
# 1190                       schifflange        NaN        NaN
# 1192          alegro convertor station        NaN        NaN
# 1198                           rosiori  47.256772  21.952090
# 1200                           rimiere  50.540359   5.471457
# 1202                           spellen  51.610451   6.614102
# 1203                          mercator  51.104933   2.594712
# 1209                         duvigneau        NaN        NaN
# 1211      poste de transition longu vu        NaN        NaN
# 1218                           tihange        NaN        NaN
# 1235                  champion (namur)  50.496387   4.901218
# ...
# 450                       Baia Mare, Maramureș, Romania
# 452
# 453   Medzibrod, District of Banská Bystrica, Region...
# 456   Huntorf, 65, Große Hellmer, Elsfleth, Landkrei...
# 459   Katastralgemeinde Sarasdorf, Sarasdorf, Gemein...
# 461                      Lotru, Brezoi, Vâlcea, Romania
# 462                             Šoštanj, 3326, Slovenia
# 465
# 472                                      Sălaj, Romania
# 474   Nitrianske Sučany, District of Prievidza, Regi...
# 475
# 477   Gelsenbergstraße, Horst, Gelsenkirchen-West, G...
# 478
# 487
# 495                           Alba Iulia, Alba, Romania
# 497
# 499
# 502   Pécs, Pécsi járás, Baranya, Southern Transdanu...
# 511
# 519
# 521
# 522   Bošáca, District of Nové Mesto nad Váhom, Regi...
# 524          Rilland, Reimerswaal, Zeeland, Netherlands
# 525                           Timișoara, Timiș, Romania
# 526
# 531   Gramme, Rue Saint-Hubert, Tienne à la Justice,...
# 532    Oudehaske, De Fryske Marren, Frisia, Netherlands
# 538
# 546                   Chełm, Lublin Voivodeship, Poland
# 563   Göttingen, Landkreis Göttingen, Lower Saxony, ...
# 572   Waldlaubersheim, Langenlonsheim-Stromberg, Lan...
# 573            Munteni, Belcești, Iași, 707047, Romania
# 577
# 587   Tiszalök, Tiszavasvári járás, Szabolcs-Szatmár...
# 588   Detox Environmental services s.r.o., Rimavská ...
# 593
# 596                               Slatina, Olt, Romania
# 602   Homburg, Saarpfalz-Kreis, Saarland, 66424, Ger...
# 608
# 613   Le Val, Jemeppe-Sur-Meuse, Seraing, Liège, Wal...
# 615   Niederlangen, Samtgemeinde Lathen, Landkreis E...
# 616
# 617            Rouvroy, Virton, Wallonia, 6767, Belgium
# 620   Gemeinde Klaus, Bezirk Feldkirch, Vorarlberg, ...
# 630   Termoelektrana-toplana Sisak, Gradska četvrt C...
# 639   Grădinița Step by Step Licurici (nr. 53 Brazi)...
# 641
# 644
# 647         Saint-Mard, Virton, Wallonia, 6762, Belgium
# 648
# 655                    Fântânele, Iași, 707196, Romania
# 658
# 663   Mikułowa, gmina Sulików, Zgorzelec County, Low...
# 672                    Țânțăreni, Gorj, 217535, Romania
# 674
# 676   Maasvlakte, Rotterdam, South Holland, Netherlands
# 677                      Reșița, Caraș-Severin, Romania
# 678
# 680   Brasov, Zona Metropolitană Brașov, Brașov, Rom...
# 685   Woringen, Bad Grönenbach, Landkreis Unterallgä...
# 688
# 690   Kronstorf, Bezirk Linz-Land, Upper Austria, 44...
# 693   Iron Gate I, Drobeta-Turnu Severin, Mehedinți,...
# 694   Villach Süd, Neufeld, Sankt Job, Finkenstein a...
# 696   Dörpen, Samtgemeinde Dörpen, Landkreis Emsland...
# 697   Silz, Malchow, Mecklenburgische Seenplatte, Me...
# 710
# 715
# 719          Turnu Măgurele, Teleorman, 145200, Romania
# 721   Van Eyck, Meensesteenweg, Dadizele, Moorslede,...
# 723   Połaniec, gmina Połaniec, Staszów County, Świę...
# 730                  Mărișelu, Bistrița-Năsăud, Romania
# 732   Szabolcsbáka, Kisvárdai járás, Szabolcs-Szatmá...
# 733     Eemshaven, Het Hogeland, Groningen, Netherlands
# 734   Boguchwała, gmina Boguchwała, Rzeszów County, ...
# 735                   Heinsch, Arlon, Wallonia, Belgium
# 748           Retezat National Park, Hunedoara, Romania
# 752   Stanisławów, gmina Stanisławów, Mińsk County, ...
# 754                                    Suceava, Romania
# 759
# 768   Homburg, Saarpfalz-Kreis, Saarland, 66424, Ger...
# 770
# 771   Diefflen, Dillingen/Saar, Landkreis Saarlouis,...
# 784   Felsőzsolca, Miskolci járás, Borsod-Abaúj-Zemp...
# 785
# 793   Putlitz, Putlitz-Berge, Prignitz, Brandenburg,...
# 795
# 800
# 808
# 809               Eindhoven, North Brabant, Netherlands
# 810   Weingarten, Verwaltungsverband Mittleres Schus...
# 811   Gădălin, Jucu, Cluj Metropolitan Area, Cluj, 4...
# 814              Lint, Antwerp, Flanders, 2547, Belgium
# 818     Eemshaven, Het Hogeland, Groningen, Netherlands
# 822
# 824   Schwörstadt, Verwaltungsgemeinschaft Rheinfeld...
# 826
# 828   Metzingen, Gemeindeverwaltungsverband Metzinge...
# 831
# 841
# 842
# 843   Praga, Białobrzegi, gmina Białobrzegi, Białobr...
# 846         Stupina, Crucea, Constanța, 907101, Romania
# 847       Zeltweg, Bezirk Murtal, Styria, 8740, Austria
# 859     Eemshaven, Het Hogeland, Groningen, Netherlands
# 860   Gelsenbergstraße, Horst, Gelsenkirchen-West, G...
# 1402          Fundeni, Zărnești, Buzău, 127717, Romania
# 1406  Drogenbos, Halle-Vilvoorde, Flemish Brabant, F...
# 1411
# 1414              Beverwijk, North Holland, Netherlands
# 1419  Łagisza, Będzin, Będzin County, Górnośląsko-Za...
# 1420  Bleiswijk, Lansingerland, South Holland, Nethe...
# 1425
# 1427  Villingen, Hungen, Landkreis Gießen, Hesse, Ge...
# 1428
# 1430
# 1433                  Latour, Virton, Wallonia, Belgium
# 1436  Puławy, Puławy County, Lublin Voivodeship, 24-...
# 1437
# 1439  Teleajen, Palanca, Râfov, Prahova, 107503, Rom...
# 1446                           Smârdan, Galați, Romania
# 1450  Vijfhuizen, Haarlemmermeer, North Holland, Net...
# 1459
# 1463                     Târgoviște, Dâmbovița, Romania
# 1469
# 1473
# 1474
# 1475
# 1476
# 1478  Gabčíkovo, District of Dunajská Streda, Region...
# 1484  Mettmann, Kreis Mettmann, North Rhine-Westphal...
# 1485  Békéscsaba, Békéscsabai járás, Békés, South Gr...
# 1488
# 1489
# 1491  Ołtarzew, gmina Ożarów Mazowiecki, Warsaw West...
# 1492
# 1495

# %%
# with google maps

"""
locations_to_double_check = [248, 347, 383, 390, 563]

df_missing_jao_osm.loc[248, 'lat'] = 51.3868123
df_missing_jao_osm.loc[248, 'lon'] = 6.6699285

df_missing_jao_osm.loc[347, 'lat'] = 52.2147341
df_missing_jao_osm.loc[347, 'lon'] = 19.1666693

df_missing_jao_osm.loc[383, 'lat'] = 50.1408201
df_missing_jao_osm.loc[383, 'lon'] = 14.779388

df_missing_jao_osm.loc[390, 'lat'] = 49.7795834
df_missing_jao_osm.loc[390, 'lon'] = 19.2098177

df_missing_jao_osm.loc[563, 'lat'] = 48.2456958
df_missing_jao_osm.loc[563, 'lon'] = 19.7546662

"""

for index, row in df_missing_jao_osm.iterrows():
        df_jao_substations.loc[index, 'lat'] = row['lat']
        df_jao_substations.loc[index, 'lon'] = row['lon']

# %%
# fill in skipped substations
# google maps
# https://www.4coffshore.com/windfarms/belgium/seamade-(mermaid)-belgium-be07.html
# https://www.transnetbw.de/en/energy-market/congestion-management/congestion

"""
df_jao_substations.loc[189, 'lat'] = 49.0150679
df_jao_substations.loc[189, 'lon'] = 8.3122858

df_jao_substations.loc[281, 'lat'] = 49.7696621
df_jao_substations.loc[281, 'lon'] = 6.1017144

df_jao_substations.loc[296, 'lat'] = 46.96116
df_jao_substations.loc[296, 'lon'] = 26.92647

df_jao_substations.loc[341, 'lat'] = 49.0157183
df_jao_substations.loc[341, 'lon'] = 8.1224769

df_jao_substations.loc[690, 'lat'] = 49.0157183
df_jao_substations.loc[690, 'lon'] = 8.1224769

df_jao_substations.loc[953, 'lat'] = 49.4445287
df_jao_substations.loc[953, 'lon'] = 8.4973346

df_jao_substations.loc[992, 'lat'] = 50.6106292
df_jao_substations.loc[992, 'lon'] = 5.6286262

df_jao_substations.loc[1346, 'lat'] = 51.680497
df_jao_substations.loc[1346, 'lon'] = 2.885694
"""
# Out:
# "\ndf_jao_substations.loc[189, 'lat'] = 49.0150679\ndf_jao_substations.loc[189, 'lon'] = 8.3122858\n\ndf_jao_substations.loc[281, 'lat'] = 49.7696621\ndf_jao_substations.loc[281, 'lon'] = 6.1017144\n\ndf_jao_substations.loc[296, 'lat'] = 46.96116\ndf_jao_substations.loc[296, 'lon'] = 26.92647\n\ndf_jao_substations.loc[341, 'lat'] = 49.0157183\ndf_jao_substations.loc[341, 'lon'] = 8.1224769\n\ndf_jao_substations.loc[690, 'lat'] = 49.0157183\ndf_jao_substations.loc[690, 'lon'] = 8.1224769\n\ndf_jao_substations.loc[953, 'lat'] = 49.4445287\ndf_jao_substations.loc[953, 'lon'] = 8.4973346\n\ndf_jao_substations.loc[992, 'lat'] = 50.6106292\ndf_jao_substations.loc[992, 'lon'] = 5.6286262\n\ndf_jao_substations.loc[1346, 'lat'] = 51.680497\ndf_jao_substations.loc[1346, 'lon'] = 2.885694\n"

# %%
df_missing_manual = df_jao_substations[df_jao_substations.lat.isnull()]
df_missing_manual.loc[:, 'osm_find'] = ''
df_missing_manual.loc[:, 'osmid'] = None
# Out:
# C:\Users\balazs.riskutia\AppData\Local\Temp\ipykernel_688\3754290101.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing_manual.loc[:, 'osm_find'] = ''
# C:\Users\balazs.riskutia\AppData\Local\Temp\ipykernel_688\3754290101.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing_manual.loc[:, 'osmid'] = None

# %%
ox.settings.timeout = 3

for index, row in df_missing_manual.iterrows():
    try:
        tags = {
            'power_source': True,
            'substation': True,
            'electricity': True,
        }
        osm_find = ox.geometries_from_address(row['name'] + ', ' + row['zone'], tags)
        #osm_find = ox.overpass_request(query_data, pause=3, error_pause=3)
        if len(osm_find) > 0:
            print(osm_find.iloc[0])
            if hasattr(osm_find, "name"):
                df_missing_manual.loc[index, 'osm_find'] = osm_find.name[0]
            elif hasattr(osm_find, "power"):
                df_missing_manual.loc[index, 'osm_find'] = osm_find.power[0]
            elif hasattr(osm_find, "substation"):
                df_missing_manual.loc[index, 'osm_find'] = osm_find.substation[0]
            df_missing_manual.loc[index, 'lat'] = osm_find.geometry[0].representative_point().y
            df_missing_manual.loc[index, 'lon'] = osm_find.geometry[0].representative_point().x
        else:
            print('Not found: ', row['name'], ', ', index)
    except ValueError as ve:
        print('Value error, ', row['name'], ', ', index)
    except requests.exceptions.RequestException as rt:
        print('Timeout, ', row['name'], ', ', index)
# Out:
# Value error,  AFTAKKING MEKINGEN 380kV ,  30
# Value error,  Wengerrohr ,  33
# Value error,  V. Dur ,  52
# Not found:  Senj ,  80
# Not found:  Craiova Nord ,  91
# Value error,  H. Zivotice ,  92
# barrier                                                           fence
# geometry              POLYGON ((16.4338728 48.1386898, 16.4330301 48...
# nodes                 [278339295, 1617884712, 10611371714, 106113717...
# capacity                                                          90 MW
# frequency                                                       50;16.7
# landuse                                                      industrial
# location                                                        outdoor
# name                                             Umformerwerk Kledering
# operator                                           ÖBB-Infrastruktur AG
# operator:short                                                ÖBB Infra
# operator:wikidata                                             Q56425426
# operator:wikipedia                                         de:ÖBB Infra
# power                                                        substation
# ref                                                                  Kl
# start_date                                                   1989-10-24
# substation                                                    converter
# voltage                                                          110000
# wikidata                                                            NaN
# wikipedia                                                           NaN
# building                                                            NaN
# Name: (way, 25539194), dtype: object
# Value error,  Doekegat  ,  97
# Not found:  Constanta Nord ,  104
# Not found:  FAI ,  113
# Value error,  GDANSK-BLONI ,  115
# Value error,  PIQUAGE A SAINT GERONS ,  122
# Not found:  ANIOLOW ,  124
# Value error,  TRAN5 / GAVRE PERTA 1 ,  157
# nodes                [1068913205, 1068913432, 1068913170, 106891318...
# name                                                          Marcourt
# operator                                                          Elia
# operator:wikidata                                             Q1131131
# power                                                       substation
# substation                                                transmission
# voltage                                                         220000
# geometry             POLYGON ((5.5492352 50.2097529, 5.5497266 50.2...
# Name: (way, 92015823), dtype: object
# Value error,  Galceag ,  185
# geometry             POLYGON ((3.772656 51.1320709, 3.7729302 51.13...
# nodes                [1020428227, 1020428177, 6242791080, 181000324...
# name                                                        Rodenhuize
# power                                                       substation
# substation                                                transmission
# voltage                                                  380000;150000
# operator                                                           NaN
# operator:wikidata                                                  NaN
# Name: (way, 87763325), dtype: object
# Value error,  OFFSHORE WINDPARK ,  206
# Not found:  Neuenhagen ,  207
# Value error,  REPIQUAGE SENONCHAMPS 220kV ,  208
# barrier                                                    fence
# geometry       POLYGON ((18.6720028 53.0435035, 18.6720376 53...
# nodes          [1570027493, 2970950032, 1570027523, 987427197...
# designation                            GPZ 220/110kV Toruń Elana
# frequency                                                     50
# name           Stacja elektroenergetyczna „Toruń - Elana” 220...
# operator                                              PSE/Energa
# power                                                 substation
# ref                                                          TEL
# source                                                    survey
# substation                                          transmission
# voltage                                            220000;110000
# Name: (way, 143484238), dtype: object
# Value error,  Targu Jiu Nord ,  239
# Not found:  Hessenweg ,  247
# Not found:  V. Kapusany ,  248
# nodes                  [249889350, 249889351, 4537438141, 249889352, ...
# name                                                        380 kV Lixhe
# power                                                         substation
# substation                                                  transmission
# voltage                                                    380000;220000
# geometry               POLYGON ((5.6667885 50.7550079, 5.6673561 50.7...
# frequency:primary                                                    NaN
# frequency:secondary                                                  NaN
# name:de                                                              NaN
# name:en                                                              NaN
# name:fr                                                              NaN
# operator                                                             NaN
# operator:wikidata                                                    NaN
# voltage:primary                                                      NaN
# voltage:secondary                                                    NaN
# Name: (way, 23141556), dtype: object
# barrier                                                          fence
# geometry             POLYGON ((7.0108025 52.1768857, 7.010299 52.17...
# nodes                [536730716, 536730718, 2903295873, 2903295875,...
# name                                                      Kottigerhook
# operator                                                      Westnetz
# power                                                       substation
# substation                                                  industrial
# voltage                                                         110000
# operator:wikidata                                                  NaN
# Name: (way, 42874315), dtype: object
# geometry             POLYGON ((5.8407517 50.3751326, 5.8412926 50.3...
# nodes                [1030504187, 3635053227, 1030504495, 363505322...
# name                                                             Brume
# operator                                                          Elia
# operator:wikidata                                             Q1131131
# power                                                       substation
# substation                                                transmission
# voltage                                                  380000;220000
# Name: (way, 88799384), dtype: object
# power                                                substation
# geometry      POLYGON ((13.2943317 48.0211516, 13.2943798 48...
# nodes         [6744065590, 6744065591, 6744065589, 674406559...
# building                                      transformer_tower
# substation                                   minor_distribution
# voltage                                                   30000
# Name: (way, 718129692), dtype: object
# nodes         [9790560385, 9790560386, 9790560387, 979056038...
# name                                                  Baru Mare
# operator                                                    TEL
# power                                                substation
# substation                                         transmission
# voltage                                                  220000
# geometry      POLYGON ((23.1428205 45.4793049, 23.1436466 45...
# Name: (way, 1066153075), dtype: object
# Not found:  Oechtel ,  290
# Not found:  Nadab ,  310
# Not found:  Wallsee ,  312
# Value error,  GDANSK PRZYJAZN ,  328
# Not found:  MAERLANT ,  329
# Value error,  H.Zivotice ,  332
# Value error,  Eemshaven Oude Schip ,  354
# Not found:  Okroglo ,  355
# Not found:  Bericevo ,  357
# Value error,  PIQUAGE A DUVIGNEAU ,  363
# Value error,  AFTAKKING LIEFKENSHOEK 380kV ,  379
# Value error,  ST-MARD SNCB ,  388
# Not found:  Y-Dauersberg ,  389
# Not found:  Bacau Sud ,  394
# Not found:  Melina ,  412
# Value error,  Pelicanu ,  413
# Not found:  FWH-S ,  419
# Not found:  Gradiste ,  444
# Value error,  OLSZTYN-MATK ,  447
# Value error,  GKN2 ,  449
# Value error,  OXYLUX  ,  452
# Not found:  S. Nova Ves ,  465
# Value error,  OFFSHORE SWITCHYARD ,  475
# barrier                                                           fence
# geometry              POLYGON ((22.3486491 53.8338935, 22.3496279 53...
# nodes                 [1723394562, 1723394675, 1747746125, 386130202...
# name                        Stacja elektroenergetyczna 110/15kV "Ełk 2"
# operator                                                PGE Dystrybucja
# operator:wikidata                                               Q787714
# operator:wikipedia                     pl:PGE Polska Grupa Energetyczna
# power                                                        substation
# ref                                                                 EL2
# substation                                                 transmission
# voltage                                                    110000;15000
# landuse                                                             NaN
# short_name                                                          NaN
# Name: (way, 160286265), dtype: object
# Value error,  GKMB ,  482
# Not found:  BERTRANGE ,  487
# Value error,  BRUME SNCB ,  497
# nodes                [1189830542, 1189830565, 1189830600, 118983058...
# landuse                                                     industrial
# name                                                            Le Val
# operator                                                          Elia
# operator:wikidata                                             Q1131131
# power                                                       substation
# substation                                                transmission
# voltage                                                         220000
# geometry             POLYGON ((5.492977 50.6035953, 5.4918535 50.60...
# building                                                           NaN
# Name: (way, 103041283), dtype: object
# barrier                                                   fence
# geometry      POLYGON ((16.873252 53.078578, 16.876461 53.07...
# nodes         [2464444116, 6189572478, 6189572479, 618957248...
# name          Stacja elektroenergetyczna "Piła Krzewina" 400...
# operator                                           PSE Operator
# power                                                substation
# ref                                                         PKW
# source                                                     Bing
# substation                                         transmission
# voltage                                    400000;220000;110000
# Name: (way, 238640596), dtype: object
# nodes              [2935698417, 2935698418, 2935698415, 293569841...
# building                                                         yes
# building:levels                                                    1
# power                                                     substation
# substation                                        minor_distribution
# geometry           POLYGON ((22.6731709 44.6276194, 22.6731091 44...
# Name: (way, 290035819), dtype: object
# Not found:  Hausruck ,  521
# nodes         [1784752166, 5292029329, 5292047820, 529204513...
# frequency                                                    50
# location                                                outdoor
# name                                                  RTP Kleče
# operator                                                   ELES
# power                                                substation
# source                                                     Bing
# substation                                         transmission
# voltage                                           220000;110000
# geometry      POLYGON ((14.4837517 46.1038936, 14.4838097 46...
# Name: (way, 167068843), dtype: object
# Value error,  PIQUAGE A PLUVIGNER ,  538
# Value error,  PIQUAGE A FONCROSE ,  577
# Value error,   T.SUP / PRION - TAVEL ,  593
# Value error,  FAUX FRENAIS ,  608
# nodes                [1094445348, 1094443076, 1094441803, 109444096...
# name                                                       Sart-Tilman
# operator                                                          Elia
# operator:wikidata                                             Q1131131
# power                                                       substation
# substation                                                transmission
# voltage                                                   220000;70000
# geometry             POLYGON ((5.5602298 50.5906772, 5.5604616 50.5...
# Name: (way, 94155586), dtype: object
# nodes         [9169719907, 9169719904, 9169719905, 916971990...
# building                                                service
# power                                                substation
# substation                                   minor_distribution
# geometry      POLYGON ((15.7556119 48.2624094, 15.755608 48....
# Name: (way, 992468632), dtype: object
# Not found:  Pitesti Sud ,  644
# nodes         [847703390, 847702712, 847702527, 847703417, 8...
# name                                                     Hășdat
# operator                                                    TEL
# power                                                substation
# substation                                         transmission
# voltage                                                  220000
# geometry      POLYGON ((22.9183978 45.7356261, 22.9140247 45...
# Name: (way, 71212865), dtype: object
# Value error,  LOMZA SYSTEMOWA ,  658
# Value error,  ACHENE SNCB ,  674
# Not found:  Doetinchem ,  678
# Value error,  REPIQUAGE HOUFFALIZE 220kV ,  688
# Not found:  Calea Aradului ,  710
# Not found:  Filesti ,  715
# Value error,  RDK8 ,  757
# Value error,  WLOCLAWEK AZ ,  759
# barrier                                                          fence
# geometry             POLYGON ((5.0571404 50.2610342, 5.0568873 50.2...
# nodes                [1026489348, 4460419499, 4460419461, 446041945...
# location                                                       outdoor
# name                                                            Achêne
# operator                                                          Elia
# operator:wikidata                                             Q1131131
# power                                                       substation
# ref:FR:RTE                                                       .ACHE
# substation                                                transmission
# voltage                                                   380000;70000
# building                                                           NaN
# Name: (way, 88373135), dtype: object
# Not found:  Uerdingen ,  785
# Value error,  Zeyerveen ,  795
# barrier                                                           fence
# geometry              POLYGON ((14.6337679 53.8456425, 14.6328548 53...
# nodes                 [2307932199, 2307932167, 3324433967, 230793219...
# landuse                                                         railway
# location                                                         indoor
# name                                       Podstacja trakcyjna "Recław"
# operator                                                 PKP Energetyka
# operator:wikidata                                              Q7119525
# operator:wikipedia                                    pl:PKP Energetyka
# power                                                        substation
# short_name                                                    PT Recław
# substation                                                     traction
# frequency                                                           NaN
# start_date                                                          NaN
# voltage                                                             NaN
# ref                                                                 NaN
# Name: (way, 221788405), dtype: object
# Not found:  Sibiu Sud  ,  808
# Not found:  L. Mara ,  822
# Value error,  Y-Bidngen ,  826
# Not found:  Plomin ,  831
# barrier                                                           fence
# geometry              POLYGON ((5.817796 53.2014143, 5.8187908 53.20...
# nodes                 [1800599120, 1800599119, 1800599106, 762672088...
# name                                                  110 kV Leeuwarden
# operator                                                         TenneT
# operator:wikidata                                              Q1127569
# operator:wikipedia                                            nl:TenneT
# power                                                        substation
# ref                                                                  LW
# substation                                                 transmission
# voltage                                                    110000;10000
# Name: (way, 168876867), dtype: object
# Value error,  AFTAKKING RODENHUIZE 380kV ,  842
# Value error,  Otelarie H ,  873
# Value error,  REPIQUAGE MARCOURT 220kV ,  891
# Value error,  Targiu Jiu Nord ,  897
# nodes         [9243755229, 9243755228, 9243755227, 924375522...
# name                                                 Longue Vue
# power                                                substation
# substation                                         transmission
# voltage                                                  220000
# geometry      POLYGON ((5.7167501 50.7432785, 5.7171624 50.7...
# Name: (way, 1001478336), dtype: object
# Not found:  Cluj Est ,  915
# Not found:  Roman Nord ,  920
# Value error,  AFTAKKING ZUTTENDAAL 380kV ,  923
# Value error,  PIQUAGE A VILLIERS-LE-BEL ,  933
# Value error,  REPIQUAGE ST-AMAND 380kV ,  934
# Value error,  T HAL-BYĆ ,  942
# Not found:  ROOST  ,  948
# barrier                                                   fence
# geometry      POLYGON ((11.2072775 52.490653, 11.2064942 52....
# power                                                substation
# nodes         [1255941920, 1255941930, 1255941915, 125594191...
# access                                                       no
# frequency                                                    50
# location                                                outdoor
# name                                         Umspannwerk Mieste
# operator                                                    HSN
# substation                                         distribution
# voltage                                                  110000
# building                                                    NaN
# Name: (way, 109795105), dtype: object
# Value error,  d. Mostistea ,  985
# Value error,  RDK7 ,  1014
# nodes         [3784955585, 3784955583, 3784955582, 131740271...
# barrier                                                   fence
# name                                                  Keienvenn
# operator                                               Westnetz
# power                                                substation
# substation                                         distribution
# geometry      POLYGON ((7.3187929 52.3242299, 7.3188738 52.3...
# Name: (way, 375106083), dtype: object
# geometry              POLYGON ((8.8955129 52.5650595, 8.8945463 52.5...
# nodes                 [8821048009, 2733373549, 2733373543, 553206847...
# name                                                        Ohlensehlen
# name:en                                          Substation Ohlensehlen
# operator                                                 Avacon Netz AG
# power                                                        substation
# substation                                                 distribution
# voltage                                                          110000
# operator:wikidata                                                   NaN
# operator:wikipedia                                                  NaN
# Name: (way, 267947573), dtype: object
# Not found:  BRUEGEL ,  1048
# Not found:  Kuehtai ,  1057
# Not found:  Stalldorf ,  1069
# Value error,  REPIQUAGE LATOUR 220kV ,  1089
# Value error,  Dreibein Mellach ,  1091
# Not found:  Uentrop ,  1105
# Not found:  Jozsa ,  1111
# Value error,  CENTRALE COO ,  1112
# geometry             POLYGON ((5.7930189 49.5680144, 5.7951712 49.5...
# nodes                [1024134108, 1024134119, 1356298614, 135629861...
# name                                                           Aubange
# operator                                                          Elia
# operator:wikidata                                             Q1131131
# power                                                       substation
# substation                                                transmission
# voltage                                                  380000;220000
# Name: (way, 121085952), dtype: object
# Value error,  T JOA-LAG ,  1129
# Value error,  Ruhrzink ,  1135
# Not found:  ROMSEE ,  1154
# barrier                                                          fence
# geometry             POLYGON ((19.4606173 50.4974135, 19.4606475 50...
# nodes                [8934082008, 8934082006, 8934082007, 166467484...
# gas_insulated                                                      yes
# location                                                       outdoor
# name                    Stacja elektroenergetyczna „Łośnice” 220/110kV
# operator                                                           PSE
# operator:wikidata                                             Q1749435
# power                                                       substation
# ref                                                                LOS
# start_date                                                        1975
# substation                                                transmission
# voltage                                                  220000;110000
# rating                                                             NaN
# Name: (way, 153838553), dtype: object
# Value error,  PIQUAGE A LA PRAZ-ST-ANDRE ,  1182
# barrier                                                           fence
# geometry              POLYGON ((6.0203817 49.5209478, 6.0195395 49.5...
# nodes                 [387279663, 5182963705, 387279664, 6114052203,...
# frequency                                                            50
# name                                                        Schifflange
# operator                                                          Creos
# operator:wikidata                                             Q21036415
# operator:wikipedia                                             fr:Creos
# power                                                        substation
# substation                                                 transmission
# voltage                                                    220000;65000
# wikidata                                                      Q52491611
# building                                                            NaN
# Name: (way, 33814365), dtype: object
# Value error,  ALEGRO CONVERTOR STATION ,  1192
# Not found:  DUVIGNEAU ,  1209
# Value error,  POSTE DE TRANSITION LONGUE VUE 220kV ,  1211
# nodes                [1205916880, 1205917393, 2562839686, 120591762...
# power                                                       substation
# substation                                                  industrial
# geometry             POLYGON ((5.2704213 50.5330404, 5.271988 50.53...
# name                                                               NaN
# operator                                                           NaN
# operator:wikidata                                                  NaN
# voltage                                                            NaN
# Name: (way, 104524880), dtype: object
# Not found:  Eemshaven Oost ,  1242
# Value error,  REPIQUAGE SART-TILMAN 220kV ,  1252
# Not found:  Sibiu Sud ,  1257
# Not found:  Dauersberg ,  1264
# Not found:  Cierny Vah ,  1265
# Value error,  GRILLE-AVOINE ,  1271
# Not found:  AWIRS ,  1291
# nodes                [1205916880, 1205917393, 2562839686, 120591762...
# power                                                       substation
# substation                                                  industrial
# geometry             POLYGON ((5.2704213 50.5330404, 5.271988 50.53...
# name                                                               NaN
# operator                                                           NaN
# operator:wikidata                                                  NaN
# voltage                                                            NaN
# Name: (way, 104524880), dtype: object
# Not found:  Hessenberg ,  1322
# power                                                               substation
# geometry                     POLYGON ((13.6861754 46.5386343, 13.6861717 46...
# nodes                        [1645286415, 1646200498, 1645286417, 573426698...
# building                                                     transformer_tower
# frequency                                                                   50
# location                                                                indoor
# operator                                                 KNG-Kärnten Netz GmbH
# substation                                                  minor_distribution
# voltage                                                                  20000
# industrial                                                                 NaN
# landuse                                                                    NaN
# name                                                                       NaN
# pipeline                                                                   NaN
# pipeline:inspection_gauge                                                  NaN
# substance                                                                  NaN
# source                                                                     NaN
# start_date                                                                 NaN
# Name: (way, 151688284), dtype: object
# Value error,  ROMSEE SNCB ,  1337
# Not found:  Tauern ,  1353
# Not found:  Phyrn ,  1377
# Not found:  BERTRANGE  ,  1386
# Not found:  GOUY ,  1388
# Value error,  POZNAN PLD ,  1395
# Value error,  Focsani Vest ,  1397
# Not found:  VE Padene ,  1411
# barrier                                                   fence
# geometry      POLYGON ((7.9378889 51.0122689, 7.9391236 51.0...
# nodes         [4107307993, 4107307994, 1461201358, 819859049...
# access                                                       no
# frequency                                                    50
# location                                                outdoor
# name                                 Umspannwerk Altenkleusheim
# operator                                       Amprion;Westnetz
# power                                                substation
# substation                                         transmission
# voltage                                           220000;110000
# wikidata                                              Q52528761
# Name: (way, 132814303), dtype: object
# nodes         [1138683369, 1138683367, 1138683343, 113868336...
# name                                              380kV Tergnée
# power                                                substation
# substation                                         transmission
# voltage                                           380000;150000
# geometry      POLYGON ((4.5667541 50.4370997, 4.566323 50.43...
# Name: (way, 98410713), dtype: object
# man_made                                 street_cabinet
# operator                     Schleswig-Holstein Netz AG
# power                                        substation
# ref               St. Michaelisdonn Heiddonn STST412175
# street_cabinet                                    power
# substation                           minor_distribution
# geometry                   POINT (9.1246343 53.9832091)
# nodes                                               NaN
# name                                                NaN
# short_name                                          NaN
# start_date                                          NaN
# voltage                                             NaN
# pipeline                                            NaN
# Name: (node, 885985169), dtype: object
# Not found:  SIEDLCE UJRZANOW ,  1437
# Not found:  Emscherbruch ,  1459
# Not found:  Oradea Sud ,  1469
# Not found:  Moldava ,  1473
# nodes         [2149622500, 2149622503, 2149622502, 214962250...
# name                                                        Iaz
# operator                                                    TEL
# power                                                substation
# source                                                     Bing
# substation                                         transmission
# voltage                                                  220000
# geometry      POLYGON ((22.224427 45.4621062, 22.2249857 45....
# Name: (way, 204983664), dtype: object
# Value error,  H. Zdana ,  1475
# Value error,  TIHANGE BIS ,  1476
# nodes                [1205916880, 1205917393, 2562839686, 120591762...
# power                                                       substation
# substation                                                  industrial
# geometry             POLYGON ((5.2704213 50.5330404, 5.271988 50.53...
# name                                                               NaN
# operator                                                           NaN
# operator:wikidata                                                  NaN
# voltage                                                            NaN
# Name: (way, 104524880), dtype: object
# power                                                substation
# geometry      POLYGON ((13.8543927 48.3333707, 13.8543484 48...
# operator                                                    NaN
# nodes         [1518106909, 1518106915, 5646258085, 151810691...
# building                                      transformer_tower
# fixme                                             name; voltage
# substation                                         distribution
# voltage                                                   30000
# frequency                                                   NaN
# location                                                    NaN
# Name: (way, 138459580), dtype: object
# barrier                                                           fence
# geometry              POLYGON ((6.9580836 53.308116, 6.9589743 53.30...
# nodes                 [1793474709, 1793474707, 7160345155, 179347467...
# name                                            110 kV Delfzijl Weiwerd
# operator                                                         TenneT
# operator:wikidata                                              Q1127569
# operator:wikipedia                                            nl:TenneT
# power                                                        substation
# ref                                                                 DZW
# substation                                                 transmission
# voltage                                                          110000
# wikidata                                                            NaN
# building                                                            NaN
# ref:bag                                                             NaN
# source                                                              NaN
# source:date                                                         NaN
# start_date                                                          NaN
# Name: (way, 168037481), dtype: object
# Not found:  Barbosi ,  1495

# %%
for index, row in df_missing_manual[(~df_missing_manual.lat.isnull()) & (~df_missing_manual.osm_find.isnull())].iterrows():
        df_jao_substations.loc[index, 'lat'] = row['lat']
        df_jao_substations.loc[index, 'lon'] = row['lon']

# %%
df_missing_manual = df_jao_substations[df_jao_substations.lat.isnull()]
display(df_missing_manual)
# Out:
#                                       name zone           tso  \
# 30                AFTAKKING MEKINGEN 380kV   BE          ELIA
# 33                              Wengerrohr   DE  Amprion GmbH
# 52                                  V. Dur   SK          SEPS
# 80                                    Senj   HR          HOPS
# 91                            Craiova Nord   RO           TEL
# 92                             H. Zivotice   CZ          CEPS
# 97                               Doekegat    NL     TENNET NL
# 104                         Constanta Nord   RO           TEL
# 113                                    FAI   RO           TEL
# 115                           GDANSK-BLONI   PL           PSE
# 122                 PIQUAGE A SAINT GERONS   FR           RTE
# 124                                ANIOLOW   PL           PSE
# 157                  TRAN5 / GAVRE PERTA 1   FR           RTE
# 185                                Galceag   RO           TEL
# 206                      OFFSHORE WINDPARK   BE          ELIA
# 207                             Neuenhagen   DE       50HERTZ
# 208            REPIQUAGE SENONCHAMPS 220kV   BE          ELIA
# 239                         Targu Jiu Nord   RO           TEL
# 247                              Hessenweg   NL     TENNET NL
# 248                            V. Kapusany   SK          SEPS
# 290                                Oechtel   DE  Amprion GmbH
# 310                                  Nadab   RO           TEL
# 312                                Wallsee   AT           APG
# 328                        GDANSK PRZYJAZN   PL           PSE
# 329                               MAERLANT   BE          ELIA
# 332                             H.Zivotice   CZ          CEPS
# 354                   Eemshaven Oude Schip   NL     TENNET NL
# 355                                Okroglo   SI          ELES
# 357                               Bericevo   SI          ELES
# 363                    PIQUAGE A DUVIGNEAU   FR           RTE
# 379           AFTAKKING LIEFKENSHOEK 380kV   BE          ELIA
# 388                           ST-MARD SNCB   BE          ELIA
# 389                           Y-Dauersberg   DE  Amprion GmbH
# 394                              Bacau Sud   RO           TEL
# 412                                 Melina   HR          HOPS
# 413                               Pelicanu   RO           TEL
# 419                                  FWH-S   DE  Amprion GmbH
# 444                               Gradiste   RO           TEL
# 447                           OLSZTYN-MATK   PL           PSE
# 449                                   GKN2   DE    TRANSNETBW
# 452                                OXYLUX    DE         Creos
# 465                            S. Nova Ves   SK          SEPS
# 475                    OFFSHORE SWITCHYARD   BE          ELIA
# 482                                   GKMB   DE    TRANSNETBW
# 487                              BERTRANGE   DE         Creos
# 497                             BRUME SNCB   BE          ELIA
# 521                               Hausruck   AT           APG
# 538                    PIQUAGE A PLUVIGNER   FR           RTE
# 577                     PIQUAGE A FONCROSE   FR           RTE
# 593                  T.SUP / PRION - TAVEL   FR           RTE
# 608                           FAUX FRENAIS   FR           RTE
# 644                            Pitesti Sud   RO           TEL
# 658                        LOMZA SYSTEMOWA   PL           PSE
# 674                            ACHENE SNCB   BE          ELIA
# 678                             Doetinchem   NL     TENNET NL
# 688             REPIQUAGE HOUFFALIZE 220kV   BE          ELIA
# 710                         Calea Aradului   RO           TEL
# 715                                Filesti   RO           TEL
# 757                                   RDK8   DE    TRANSNETBW
# 759                           WLOCLAWEK AZ   PL           PSE
# 785                              Uerdingen   DE  Amprion GmbH
# 795                              Zeyerveen   NL     TENNET NL
# 808                             Sibiu Sud    RO           TEL
# 822                                L. Mara   SK          SEPS
# 826                              Y-Bidngen   DE  Amprion GmbH
# 831                                 Plomin   HR          HOPS
# 842             AFTAKKING RODENHUIZE 380kV   BE          ELIA
# 873                             Otelarie H   RO           TEL
# 891               REPIQUAGE MARCOURT 220kV   BE          ELIA
# 897                        Targiu Jiu Nord   RO           TEL
# 915                               Cluj Est   RO           TEL
# 920                             Roman Nord   RO           TEL
# 923             AFTAKKING ZUTTENDAAL 380kV   BE          ELIA
# 933              PIQUAGE A VILLIERS-LE-BEL   FR           RTE
# 934               REPIQUAGE ST-AMAND 380kV   BE          ELIA
# 942                              T HAL-BYĆ   PL           PSE
# 948                                 ROOST    DE         Creos
# 985                           d. Mostistea   RO           TEL
# 1014                                  RDK7   DE    TRANSNETBW
# 1048                               BRUEGEL   BE          ELIA
# 1057                               Kuehtai   DE    TENNETGMBH
# 1069                             Stalldorf   DE    TENNETGMBH
# 1089                REPIQUAGE LATOUR 220kV   BE          ELIA
# 1091                      Dreibein Mellach   AT           APG
# 1105                               Uentrop   DE  Amprion GmbH
# 1111                                 Jozsa   HU         MAVIR
# 1112                          CENTRALE COO   BE          ELIA
# 1129                             T JOA-LAG   PL           PSE
# 1135                              Ruhrzink   DE  Amprion GmbH
# 1154                                ROMSEE   BE          ELIA
# 1182            PIQUAGE A LA PRAZ-ST-ANDRE   FR           RTE
# 1192              ALEGRO CONVERTOR STATION   BE          ELIA
# 1209                             DUVIGNEAU   FR           RTE
# 1211  POSTE DE TRANSITION LONGUE VUE 220kV   BE          ELIA
# 1218                             TIHANGE 1   BE          ELIA
# 1242                        Eemshaven Oost   NL     TENNET NL
# 1252           REPIQUAGE SART-TILMAN 220kV   BE          ELIA
# 1257                             Sibiu Sud   RO           TEL
# 1264                            Dauersberg   DE  Amprion GmbH
# 1265                            Cierny Vah   SK          SEPS
# 1271                         GRILLE-AVOINE   FR           RTE
# 1291                                 AWIRS   BE          ELIA
# 1307                             TIHANGE 2   BE          ELIA
# 1322                            Hessenberg   AT           APG
# 1324                                Greuth   AT           APG
# 1337                           ROMSEE SNCB   BE          ELIA
# 1353                                Tauern   AT           APG
# 1377                                 Phyrn   AT           APG
# 1386                            BERTRANGE    DE         Creos
# 1388                                  GOUY   BE          ELIA
# 1395                            POZNAN PLD   PL           PSE
# 1397                          Focsani Vest   RO           TEL
# 1411                             VE Padene   HR          HOPS
# 1430                            Suederdonn   DE    TENNETGMBH
# 1437                      SIEDLCE UJRZANOW   PL           PSE
# 1459                          Emscherbruch   DE  Amprion GmbH
# 1469                            Oradea Sud   RO           TEL
# 1473                               Moldava   SK          SEPS
# 1475                              H. Zdana   SK          SEPS
# 1476                           TIHANGE BIS   BE          ELIA
# 1488                             TIHANGE 3   BE          ELIA
# 1495                               Barbosi   RO           TEL
#
#                          name_norm  lat  lon
# 30                        mekingen  NaN  NaN
# 33                      wengerrohr  NaN  NaN
# 52                          v. dur  NaN  NaN
# 80                            senj  NaN  NaN
# 91                    craiova nord  NaN  NaN
# 92                     h. zivotice  NaN  NaN
# 97                         dokegat  NaN  NaN
# 104                 constanta nord  NaN  NaN
# 113                            fai  NaN  NaN
# 115                   gdansk-bloni  NaN  NaN
# 122         piquage a saint gerons  NaN  NaN
# 124                        aniolow  NaN  NaN
# 157            tran5 / gavre perta  NaN  NaN
# 1192      alegro convertor station  NaN  NaN
# 1209                     duvigneau  NaN  NaN
# 1211  poste de transition longu vu  NaN  NaN
# 1218                       tihange  NaN  NaN
# 1242                eemshaven oost  NaN  NaN
# 1252         repiquage sart-tilman  NaN  NaN
# 1257                     sibiu sud  NaN  NaN
# 1264                     daursberg  NaN  NaN
# 1265                    cierny vah  NaN  NaN
# 1271                 grille-avoine  NaN  NaN
# 1291                         awirs  NaN  NaN
# 1307                       tihange  NaN  NaN
# 1322                    hessenberg  NaN  NaN
# 1324                        greuth  NaN  NaN
# 1337                   romsee sncb  NaN  NaN
# 1353                         taurn  NaN  NaN
# 1377                         phyrn  NaN  NaN
# 1386                     bertrange  NaN  NaN
# 1388                          gouy  NaN  NaN
# 1395                    poznan pld  NaN  NaN
# 1397                  focsani vest  NaN  NaN
# 1411                     ve padene  NaN  NaN
# 1430                     suderdonn  NaN  NaN
# 1437              siedlce ujrzanow  NaN  NaN
# 1459                  emscherbruch  NaN  NaN
# 1469                    oradea sud  NaN  NaN
# 1473                       moldava  NaN  NaN
# 1475                      h. zdana  NaN  NaN
# 1476                   tihange bis  NaN  NaN
# 1488                     tihange 3  NaN  NaN
# 1495                       barbosi  NaN  NaN

# %%
# https://mapcarta.com/
# OSM
#df_missing_manual.to_excel("missing_substations.xlsx")

# %%
df_missing_manual_completed = pd.read_excel('./missing_substations_completed.xlsx', index_col=0)

for index, row in df_missing_manual_completed.iterrows():
        i = df_jao_substations.index[df_jao_substations.name_norm == row.name_norm].tolist()[0]
        df_jao_substations.loc[i, 'lat'] = row['lat']
        df_jao_substations.loc[i, 'lon'] = row['lon']

# %%
df_jao_substations.loc[33, 'lat'] = 49.97324
df_jao_substations.loc[33, 'lon'] = 6.93627

df_jao_substations.loc[842, 'lat'] = 51.13206
df_jao_substations.loc[842, 'lon'] = 3.77557

df_jao_substations.loc[1257, 'lat'] = 45.78598
df_jao_substations.loc[1257, 'lon'] = 24.19511

df_jao_substations.loc[1264, 'lat'] = 50.76838
df_jao_substations.loc[1264, 'lon'] = 7.86346

df_jao_substations.loc[1307, 'lat'] = 50.53475
df_jao_substations.loc[1307, 'lon'] = 5.26893

df_jao_substations.loc[1386, 'lat'] = 49.60456
df_jao_substations.loc[1386, 'lon'] = 6.03523

# %%
#df_jao_substations = df_jao_substations.drop(columns=['name_norm'])
df_jao_substations.to_excel("substations.xlsx")

# %%
for index, row in df_grid.iterrows():
    s1 = df_jao_substations.index[df_jao_substations.name == row.substation_1].tolist()[0]
    s2 = df_jao_substations.index[df_jao_substations.name == row.substation_2].tolist()[0]
    df_grid.loc[index, 'substation_1'] = s1
    df_grid.loc[index, 'substation_2'] = s2
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 2
#       1 for index, row in df_grid.iterrows():
# ----> 2     s1 = df_jao_substations.index[df_jao_substations.name == row.substation_1].tolist()[0]
#       3     s2 = df_jao_substations.index[df_jao_substations.name == row.substation_2].tolist()[0]
#       4     df_grid.loc[index, 'substation_1'] = s1
#
# IndexError: list index out of range

# %%
df_grid.to_excel("grid.xlsx")
