# %%
import pandas as pd
import networkx as nx
import numpy as np
import unicodedata
import pandas as pd
import requests
import geopandas as gpd
import osmnx as ox

pd.set_option('display.max_rows', 200)

# %%
df_grid = pd.read_excel('./jao_static_grid.xlsx', sheet_name='Lines', skiprows=[0])
df_grid = df_grid[[
    'NE_name', 'EIC_Code', 'TSO', 
    'Full_name', 'Full_name.1', 'Voltage_level(kV)', 
    'Resistance_R(Ω)', 'Reactance_X(Ω)', 'Susceptance_B(μS)', 'Length_(km)'
]]
df_grid = df_grid.rename(columns={
    'NE_name': 'name', 
    'EIC_Code': 'eic',
    'TSO': 'tso',
    'Voltage_level(kV)': 'voltage',
    'Resistance_R(Ω)': 'resistance',
    'Reactance_X(Ω)': 'reactance',
    'Susceptance_B(μS)': 'susceptance',
    'Length_(km)': 'length',
    'Full_name': 'substation_1',
    'Full_name.1': 'substation_2',
})

tso_zone_map = {
    '50HERTZ': 'DE', 
    'Amprion GmbH': 'DE', 
    'APG': 'AT', 
    'CEPS': 'CZ', 
    'Creos': 'DE', 
    'ELES': 'SI', 
    'ELIA': 'BE',
    'HOPS': 'HR', 
    'MAVIR': 'HU', 
    'PSE': 'PL', 
    'RTE': 'FR', 
    'SEPS': 'SK', 
    'TEL': 'RO', 
    'TENNET NL': 'NL',
    'TENNETGMBH': 'DE', 
    'TRANSNETBW': 'DE'
}

df_grid['zone'] = df_grid.apply(lambda row : tso_zone_map[row.tso], axis=1)

# %%
s1 = set(df_grid.substation_1.unique())
s1 = s1.union(df_grid.substation_2.unique())
substations = list(s1)

substation_zones = []
substation_tso = []
for s in substations:
    substation_zones.append(df_grid[(df_grid.substation_1 == s) | (df_grid.substation_2 == s)].iloc[0].zone)
    substation_tso.append(df_grid[(df_grid.substation_1 == s) | (df_grid.substation_2 == s)].iloc[0].tso)

df_jao_substations = pd.DataFrame(list(zip(substations.copy(), substation_zones, substation_tso)), columns =['name', 'zone', 'tso'])

substation_location_map = {}
for s in substations:
    substation_location_map[s] = None

# %%
df_scigrid_substations = pd.read_csv('vertices_eu_power_160718.csvdata', delimiter=',', quotechar="'")
df_scigrid_substations = df_scigrid_substations[df_scigrid_substations.typ == 'substation']
df_scigrid_substations = df_scigrid_substations.dropna(subset=['name'])
df_scigrid_substations = df_scigrid_substations[[
    'lon', 'lat', 'name', 'operator'
]]

# %%
scigrid_substations = df_scigrid_substations.name
scigrid_substations = list(map(str.lower, scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique de ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique du ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique des', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("poste électrique d'", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste de ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("poste d'", ''), scigrid_substations))

scigrid_substations = list(map(lambda s: s.replace("150 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("220 kv-umspannwerk ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("220-kv-umspannwerk ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("220kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("380 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("380-kv-umspannwerk ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("380kv-umspannwerk ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("380kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400/132 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400/132/50 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400/150 kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400/150kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("400kv/150kv ", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ß", 'ss'), scigrid_substations))

scigrid_substations = list(map(lambda s: s.replace("á", 'a'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("é", 'e'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("í", 'i'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ó", 'o'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ö", 'o'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ő", 'o'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ú", 'u'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ü", 'u'), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("ű", 'u'), scigrid_substations))

scigrid_substations = list(map(lambda s: unicodedata.normalize('NFKD', s).encode('ascii','ignore').decode("utf-8"), scigrid_substations))

# %%
def replace_tail_space(s):
    if s[-1] == ' ':
        s = s[0:-1]
    if s[-1] == ' ':
        s = s[0:-1]
    if s[0] == ' ':
        s = s[1:]
    return s
        
substations = list(map(str.lower, substations))
substations = list(map(lambda s: s.replace(' (le)', ''), substations))
substations = list(map(lambda s: s.replace(' (la)', ''), substations))
substations = list(map(lambda s: s.replace(' (les)', ''), substations))
substations = list(map(lambda s: s.replace(' (les)', ''), substations))

substations = list(map(lambda s: s.replace(' (l )', ''), substations))
substations = list(map(lambda s: s.replace(' (poste)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste 400 kv)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste reseau)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste blinde)', ''), substations))
substations = list(map(lambda s: s.replace(' (abzweig)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste exterieur)', ''), substations))
substations = list(map(lambda s: s.replace(' (poste evacuation)', ''), substations))

substations = list(map(lambda s: s.replace("ß", 'ss'), substations))
substations = list(map(lambda s: s.replace("á", 'a'), substations))
substations = list(map(lambda s: s.replace("é", 'e'), substations))
substations = list(map(lambda s: s.replace("í", 'i'), substations))
substations = list(map(lambda s: s.replace("ó", 'o'), substations))
substations = list(map(lambda s: s.replace("ö", 'o'), substations))
substations = list(map(lambda s: s.replace("ő", 'o'), substations))
substations = list(map(lambda s: s.replace("ú", 'u'), substations))
substations = list(map(lambda s: s.replace("ü", 'u'), substations))
substations = list(map(lambda s: s.replace("ű", 'u'), substations))

substations = list(map(lambda s: s.replace("aftakking ", ''), substations))
substations = list(map(lambda s: s.replace(" 380kv", ''), substations))
substations = list(map(lambda s: s.replace(" 220kv", ''), substations))
substations = list(map(lambda s: s.replace("y-", ''), substations))

substations = list(map(lambda s: s.replace("ue", 'u'), substations))
substations = list(map(lambda s: s.replace("oe", 'o'), substations))
substations = list(map(lambda s: s.replace("ae", 'a'), substations))
substations = list(map(lambda s: s.replace("/nord", ''), substations))
substations = list(map(lambda s: s.replace("/sud", ''), substations))
substations = list(map(lambda s: s.replace("/west", ''), substations))
substations = list(map(lambda s: s.replace("/n", ''), substations))
substations = list(map(lambda s: s.replace("/w", ''), substations))
substations = list(map(lambda s: s.replace("/sw", ''), substations))
substations = list(map(lambda s: s.replace("/s", ''), substations))
substations = list(map(lambda s: s.replace("/o", ''), substations))
substations = list(map(lambda s: s.replace("  2", ''), substations))
substations = list(map(lambda s: s.replace(" 1", ''), substations))
substations = list(map(lambda s: s.replace(" 2", ''), substations))
substations = list(map(lambda s: s.replace("st ", ''), substations))

substations = list(map(lambda s: s.replace("emden/borssum", 'borssum'), substations))
substations = list(map(lambda s: s.replace("hamburgst", 'hamburg'), substations))
substations = list(map(lambda s: s.replace("karlsruhewest", 'karlsruhe'), substations))
substations = list(map(lambda s: s.replace("bruchsal/kandelweg", 'bruchsal'), substations))
substations = list(map(lambda s: s.replace("perleberg - putlitz", 'perleberg'), substations))
substations = list(map(lambda s: s.replace("remptendorf - grossschwabhausen", 'remptendorf'), substations))
substations = list(map(lambda s: s.replace("(neu)", ''), substations))

substations = list(map(lambda s: replace_tail_space(s), substations))

substations = list(map(lambda s: unicodedata.normalize('NFKD', s).encode('ascii','ignore').decode("utf-8"), substations))

# %%
s2 = set(scigrid_substations)
s2 = s2.intersection(substations)
print(len(s2))
# Out:
# 229

# %%
set_scigrid = set(scigrid_substations)
set_jao = set(substations)
intersect = s2

scigrid_sub = set_scigrid.difference(intersect)
jao_sub = set_jao.difference(intersect)

matching_scigrid = []
matching_jao = []
for jao_s in jao_sub:
    match = [s for s in scigrid_sub if jao_s in s]
    if len(match) > 0:
        matching_scigrid.append(match[0])
        matching_jao.append(jao_s)
        
scigrid_sub = set(scigrid_sub).difference(matching_scigrid)
jao_sub = set(jao_sub).difference(matching_jao)

print(len(matching_scigrid))
# Out:
# 395

# %%
def exact_match_scigrid(row, column):
    match = df_scigrid_substations[df_scigrid_substations['name_norm'] == row['name_norm']]
    if len(match) > 0:
        return match.iloc[0][column]
    return None

def loose_match_scigrid(row, column):
    if np.isnan(row[column]):
        if row['name_norm'] in matching_jao:
            i = matching_jao.index(row['name_norm'])
            match = df_scigrid_substations[df_scigrid_substations['name_norm'] == matching_scigrid[i]]
            return match.iloc[0][column]
        else:
            return None
    return row[column]
    
    
df_scigrid_substations.loc[:, 'name_norm'] = scigrid_substations
df_jao_substations.loc[:, 'name_norm'] = substations

df_jao_substations['lat'] = df_jao_substations.apply(lambda row: exact_match_scigrid(row, 'lat'), axis=1)
df_jao_substations['lon'] = df_jao_substations.apply(lambda row: exact_match_scigrid(row, 'lon'), axis=1)

df_jao_substations['lat'] = df_jao_substations.apply(lambda row: loose_match_scigrid(row, 'lat'), axis=1)
df_jao_substations['lon'] = df_jao_substations.apply(lambda row: loose_match_scigrid(row, 'lon'), axis=1)

# %%
# France
# https://odre.opendatasoft.com/explore/dataset/enceintes-de-poste-rte/export/?disjunctive.etat
df_missing_jao = df_jao_substations[df_jao_substations.lat.isnull()]

def exact_match_rte(row, column):
    if np.isnan(row[column]):
        match = df_rte[df_rte['NOM POSTE'] == row['name']]
        if len(match) > 0:
            return match.iloc[0][column]
        return None
    return row[column]

df_jao_france = df_missing_jao[df_missing_jao.zone == 'FR']
df_rte = pd.read_excel('enceintes-de-poste-rte.xlsx')
df_rte = df_rte.dropna(subset=['geo_point_2d'])

# exact match
s_fr_intersect = set(df_jao_france.name)
s_fr_intersect = s_fr_intersect.intersection(df_rte['NOM POSTE'])

df_rte['lat'] = df_rte.apply(lambda row: float(str(row['geo_point_2d']).split(', ')[0]), axis=1)
df_rte['lon'] = df_rte.apply(lambda row: float(str(row['geo_point_2d']).split(',')[1]), axis=1)

df_jao_substations['lat'] = df_jao_substations.apply(lambda row: exact_match_rte(row, 'lat'), axis=1)
df_jao_substations['lon'] = df_jao_substations.apply(lambda row: exact_match_rte(row, 'lon'), axis=1)

# %%
df_missing_jao = df_jao_substations[df_jao_substations.lat.isnull()]
display(df_missing_jao.groupby(['zone'])['zone'].count())
# Out:
# zone
# AT    27
# BE    67
# CZ     3
# DE    87
# FR    13
# HR     9
# HU    13
# NL    34
# PL    35
# RO    99
# SI     5
# SK    25
# Name: zone, dtype: int64

# %%
substations_to_skip = ['gkmb', 'offshore windpark', 'romsee sncb', 'roman nord', 'gkn2', 'roo', 'rdk7', 'rdk8', ]
df_missing_jao_osm = df_missing_jao[~df_missing_jao.name_norm.isin(substations_to_skip)]
df_missing_jao_osm.loc[:, 'osm_find'] = ''

display(df_missing_jao_osm)
# Out:
# C:\Users\balazs.riskutia\AppData\Local\Temp\ipykernel_15152\813298026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing_jao_osm.loc[:, 'osm_find'] = ''
#               name zone         tso     name_norm  lat  lon osm_find
# 2     OLSZTYN-MATK   PL         PSE  olsztyn-matk  NaN  NaN
# 3       Eindhoven    NL   TENNET NL     eindhoven  NaN  NaN
# 4          Slatina   RO         TEL       slatina  NaN  NaN
# 7       Cierny Vah   SK        SEPS    cierny vah  NaN  NaN
# 13         JUPILLE   BE        ELIA       jupille  NaN  NaN
# ...            ...  ...         ...           ...  ...  ...      ...
# 1480     BERTRANGE   DE       Creos     bertrange  NaN  NaN
# 1483  Schwoerstadt   DE  TRANSNETBW   schworstadt  NaN  NaN
# 1490     Fantanele   RO         TEL     fantanele  NaN  NaN
# 1491     DUVIGNEAU   FR         RTE     duvigneau  NaN  NaN
# 1496        Pecs 1   HU       MAVIR          pecs  NaN  NaN
#
# [409 rows x 7 columns]

# %%
for index, row in df_missing_jao_osm.iterrows():
    try:
        osm_find = ox.geocode_to_gdf(row['name_norm'] + ', ' + row['zone'])
        if len(osm_find) > 0:
            df_missing_jao_osm.loc[index, 'osm_find'] = osm_find.loc[0, 'display_name']
            df_missing_jao_osm.loc[index, 'lat'] = osm_find.loc[0, 'lat']
            df_missing_jao_osm.loc[index, 'lon'] = osm_find.loc[0, 'lon']
    except ValueError as ve:
        pass
    
display(df_missing_jao_osm)
# Out:
#                                       name zone           tso  \
# 2                             OLSZTYN-MATK   PL           PSE
# 3                               Eindhoven    NL     TENNET NL
# 4                                  Slatina   RO           TEL
# 7                               Cierny Vah   SK          SEPS
# 13                                 JUPILLE   BE          ELIA
# 20                ALEGRO CONVERTOR STATION   BE          ELIA
# 27                     Salzburg Elixhausen   AT           APG
# 28                              Lacu Sarat   RO           TEL
# 32                                MAERLANT   BE          ELIA
# 35                  Eemshaven het Hogeland   NL     TENNET NL
# 47                             Tulcea Vest   RO           TEL
# 54                                 Husum/N   DE    TENNETGMBH
# 58                             Dresden/Süd   DE       50HERTZ
# 59                                  Bosaca   SK          SEPS
# 62                                    Sala   SK          SEPS
# 64                            Targoviste A   RO           TEL
# 65                                  Resita   RO           TEL
# 66                                Boxmeer    NL     TENNET NL
# 67                             MASSENHOVEN   BE          ELIA
# 68                                 SERAING   BE          ELIA
# 69                                VAN EYCK   BE          ELIA
# 71                                 LOSNICE   PL           PSE
# 75                                MARCOURT   BE          ELIA
# 76                                 Marbach   DE    TRANSNETBW
# 81                                  Divaca   SI          ELES
# 83                                 ROUVROY   BE          ELIA
# 85                                 Moldava   SK          SEPS
# 90                            Szabolcsbaka   HU         MAVIR
# 91                                Schuby/W   DE    TENNETGMBH
# 93                    Eemshaven Oude Schip   NL     TENNET NL
# 95                                 Calafat   RO           TEL
# 107                               Stuparei   RO           TEL
# 113                           WLOCLAWEK AZ   PL           PSE
# 114                                 Brasov   RO           TEL
# 129                                 GRAMME   BE          ELIA
# 132                              Medzibrod   SK          SEPS
# 134                         VERBRANDE BRUG   BE          ELIA
# 135                             Gheorgheni   RO           TEL
# 143                                GEZELLE   BE          ELIA
# 150                                  Vetis   RO           TEL
# 155                        Gura Ialomitei    RO           TEL
# 157                           d. Mostistea   RO           TEL
# 158                                Ungheni   RO           TEL
# 160                                Resita    RO           TEL
# 164                             Maasvlakte   NL     TENNET NL
# 166                               Domnesti   RO           TEL
# 169                                 RECLAW   PL           PSE
# 172                                Gutinas   RO           TEL
# 174                            Parchim/Süd   DE       50HERTZ
# 175                                  Lotru   RO           TEL
# 177                                RIMIERE   BE          ELIA
# 187                           Doerpen West   DE  Amprion GmbH
# 192                            SART-TILMAN   BE          ELIA
# 200                       SIEDLCE UJRZANOW   PL           PSE
# 201              PIQUAGE A VILLIERS-LE-BEL   FR           RTE
# 208                 PIQUAGE A SAINT GERONS   FR           RTE
# 211                                Zeltweg   AT           APG
# 214                                  Tihau   RO           TEL
# 216                                   Zaya   AT           APG
# 229                              Heilbronn   DE    TRANSNETBW
# 232                                Filesti   RO           TEL
# 234               REPIQUAGE MARCOURT 220kV   BE          ELIA
# 235                                   Senj   HR          HOPS
# 237                           ST-MARD SNCB   BE          ELIA
# 242                              Sarasdorf   AT           APG
# 244                    PIQUAGE A DUVIGNEAU   FR           RTE
# 248                                  Bayer   DE  Amprion GmbH
# 250                                Homburg   DE  Amprion GmbH
# 254                            Crayestein    NL     TENNET NL
# 265                                 Zwolle   NL     TENNET NL
# 266                                    FAI   RO           TEL
# 269                              Bleiswijk   NL     TENNET NL
# 273                     Krimpen a/d IJssel   NL     TENNET NL
# 279                            J. Bohunice   SK          SEPS
# 288                                  Salaj   RO           TEL
# 290                           Emscherbruch   DE  Amprion GmbH
# 292                             Ernsthofen   AT           APG
# 293                              OSTROLEKA   PL           PSE
# 295                  TRAN5 / GAVRE PERTA 1   FR           RTE
# 297                            OSTROW WLKP   PL           PSE
# 304                            TIHANGE BIS   BE          ELIA
# 306                               Tiszalok   HU         MAVIR
# 314                            STANISLAWOW   PL           PSE
# 318                               Isalnita   RO           TEL
# 321                            Ohlensehlen   DE  Amprion GmbH
# 322                             Bystricany   SK          SEPS
# 325                               Smardan    RO           TEL
# 328             AFTAKKING ZUTTENDAAL 380kV   BE          ELIA
# 329                        Waldlaubersheim   DE  Amprion GmbH
# 332                               Kisvarda   HU         MAVIR
# 333                                Isaccea   RO           TEL
# 337                                BRUEGEL   BE          ELIA
# 339                              Westerlee   NL     TENNET NL
# 344                                ELK BIS   PL           PSE
# 345                     PIQUAGE A FONCROSE   FR           RTE
# 347                                MILOSNA   PL           PSE
# 350                            Baia Mare 3   RO           TEL
# 351                                TERGNEE   BE          ELIA
# 352             REPIQUAGE HOUFFALIZE 220kV   BE          ELIA
# 355                       ZYDOWO KIERZKOWO   PL           PSE
# 357                             Goettingen   DE    TENNETGMBH
# 358                             Oradea Sud   RO           TEL
# 360                      Altentreptow/Nord   DE       50HERTZ
# 363                                Rilland   NL     TENNET NL
# 364                              Hessenweg   NL     TENNET NL
# 365                             BRUME SNCB   BE          ELIA
# 366                                Perkata   HU         MAVIR
# 367                             Sibiu Sud    RO           TEL
# 370                             Weingarten   DE  Amprion GmbH
# 372                              Gabcikovo   SK          SEPS
# 373                             Etzersdorf   AT           APG
# 375                  Heinersdorf (Abzweig)   DE       50HERTZ
# 377                          Bucuresti Sud   RO           TEL
# 378                             Otelarie H   RO           TEL
# 383                               C. Stred   CZ          CEPS
# 385                               Diefflen   DE  Amprion GmbH
# 390                            PORABKA-ZAR   PL           PSE
# 399                 REPIQUAGE LATOUR 220kV   BE          ELIA
# 403                                ANIOLOW   PL           PSE
# 408                              Oudehaske   NL     TENNET NL
# 411                                 Kosice   SK          SEPS
# 416                              VE Padene   HR          HOPS
# 419                        Targiu Jiu Nord   RO           TEL
# 420                             Eemshaven    NL     TENNET NL
# 429                                  Bradu   RO           TEL
# 432                               Woringen   DE  Amprion GmbH
# 439                       Altentreptow/Süd   DE       50HERTZ
# 440                             BERTRANGE    DE         Creos
# 445                             Gelsenberg   DE  Amprion GmbH
# 448                              Plattling   DE    TENNETGMBH
# 450                      Y-Waldlaubersheim   DE  Amprion GmbH
# 451                                 IZEGEM   BE          ELIA
# 454                                 Iernut   RO           TEL
# 456                              Timisoara   RO           TEL
# 458                                  Arefu   RO           TEL
# 468                               BERCHEM    DE         Creos
# 471                               Fundeni    RO           TEL
# 476                          Campia Turzii   RO           TEL
# 483                                Sacalaz   RO           TEL
# 495                                Retezat   RO           TEL
# 496                              Bacau Sud   RO           TEL
# 503                        GDANSK PRZYJAZN   PL           PSE
# 505                            ACHENE SNCB   BE          ELIA
# 513                                Suceava   RO           TEL
# 514                         Turnu Magurele   RO           TEL
# 516                            Heinersdorf   DE       50HERTZ
# 518                                 SLUPSK   PL           PSE
# 520                                  FWH-S   DE  Amprion GmbH
# 530                         Gura Ialomitei   RO           TEL
# 536                              DROGENBOS   BE          ELIA
# 537                                   GOUY   BE          ELIA
# 544                             Bleiswijk    NL     TENNET NL
# 546                                  Varin   SK          SEPS
# 551                           Fedderwarden   DE    TENNETGMBH
# 552                               Rosiori    RO           TEL
# 556                              Metzingen   DE    TRANSNETBW
# 561                               H. Zdana   SK          SEPS
# 563                           P. Biskupice   SK          SEPS
# 577                                 Plomin   HR          HOPS
# 579                               Pelicanu   RO           TEL
# 581                                Munteni   RO           TEL
# 582                                Huntorf   DE    TENNETGMBH
# 589                              Mayrhofen   AT           APG
# 591                           Medgidia Sud   RO           TEL
# 598                                Raureni   RO           TEL
# 601                               Ruhrzink   DE  Amprion GmbH
# 602                             Y-Diefflen   DE  Amprion GmbH
# 603                                Meduric   HR          HOPS
# 606                                LAGISZA   PL           PSE
# 607                                 Pehlin   HR          HOPS
# 619                             Bekescsaba   HU         MAVIR
# 621                                Okroglo   SI          ELES
# 625                                Zakucac   HR          HOPS
# 629                           Y-Bellendorf   DE  Amprion GmbH
# 631                              Feistritz   AT           APG
# 632                        LOMZA SYSTEMOWA   PL           PSE
# 636                               Teleajen   RO           TEL
# 647                              Y-Homburg   DE  Amprion GmbH
# 652                                Gransee   DE       50HERTZ
# 655                                WROCLAW   PL           PSE
# 656                            Villach Süd   AT           APG
# 660                       CHAMPION (NAMUR)   BE          ELIA
# 662                           SAINT HUBERT   FR           RTE
# 663                              Uerdingen   DE  Amprion GmbH
# 670                            EEKLO NOORD   BE          ELIA
# 674                               POLANIEC   PL           PSE
# 684                                Barbosi   RO           TEL
# 688                              Y-Bidngen   DE  Amprion GmbH
# 691               REPIQUAGE ST-AMAND 380kV   BE          ELIA
# 693                             Doetinchem   NL     TENNET NL
# 694                            Simonshaven   NL     TENNET NL
# 696                             Neuenhagen   DE       50HERTZ
# 699                                Weiwerd   NL     TENNET NL
# 703                            Robbenplaat   NL     TENNET NL
# 718                                 Melina   HR          HOPS
# 725                             RODENHUIZE   BE          ELIA
# 726                             POZNAN PLD   PL           PSE
# 727                               Mochovce   SK          SEPS
# 729                              Eemshaven   NL     TENNET NL
# 736                                 LATOUR   BE          ELIA
# 740                                  PRAGA   PL           PSE
# 742                                 Brinje   HR          HOPS
# 743                                 PULAWY   PL           PSE
# 745                             Elsfleth/W   DE    TENNETGMBH
# 746                               Sattledt   AT           APG
# 752                                 Stalpu   RO           TEL
# 753                              Louwsmeer   NL     TENNET NL
# 756                              T JOA-LAG   PL           PSE
# 759                               Bericevo   SI          ELES
# 761                             Brazi Vest   RO           TEL
# 762                              Beverwijk   NL     TENNET NL
# 765                                ST-MARD   BE          ELIA
# 768                              Velky Dur   SK          SEPS
# 769                            Felsozsolca   HU         MAVIR
# 772                              Isalnita    RO           TEL
# 773                                  LILLO   BE          ELIA
# 775                                 STEVIN   BE          ELIA
# 779                              Zeyerveen   NL     TENNET NL
# 781                                Wallsee   AT           APG
# 785                                   Detk   HU         MAVIR
# 791                              TIHANGE 1   BE          ELIA
# 792                            Putlitz/Süd   DE       50HERTZ
# 794                              Lelystad    NL     TENNET NL
# 795                               Mettmann   DE  Amprion GmbH
# 797                              Villingen   DE    TRANSNETBW
# 801                             Szigetcsep   HU         MAVIR
# 807                                 Rahman   RO           TEL
# 811                               BLOOREN    DE         Creos
# 816                                  Nadab   RO           TEL
# 828                                OXYLUX    DE         Creos
# 830                                Uentrop   DE  Amprion GmbH
# 831                             Sardanesti   RO           TEL
# 839                                Oechtel   DE  Amprion GmbH
# 846                            TORUN ELANA   PL           PSE
# 851                              Tantareni   RO           TEL
# 854                           Y-Gelsenberg   DE  Amprion GmbH
# 855                                 Mintia   RO           TEL
# 857                         Constanta Nord   RO           TEL
# 859                             Meckenheim   DE  Amprion GmbH
# 860   POSTE DE TRANSITION LONGUE VUE 220kV   BE          ELIA
# 861                               Gradiste   RO           TEL
# 862                              Y-Waldeck   DE    TENNETGMBH
# 872                              Cernavoda   RO           TEL
# 880                                BERNEAU   BE          ELIA
# 883                                Smardan   RO           TEL
# 894                               TE Sisak   HR          HOPS
# 897                         Altenkleusheim   DE  Amprion GmbH
# 900             AFTAKKING RODENHUIZE 380kV   BE          ELIA
# 905                                  Klaus   AT           APG
# 908                              Kledering   AT           APG
# 909                                HEINSCH   BE          ELIA
# 911                                 BELVAL   BE          ELIA
# 913                                 GORZOW   PL           PSE
# 920                           Kottigerhook   DE  Amprion GmbH
# 930                           Y-Guetersloh   DE  Amprion GmbH
# 931                                  BRUME   BE          ELIA
# 936                             Guetersloh   DE  Amprion GmbH
# 939                               MEERHOUT   BE          ELIA
# 941                               MIKULOWA   PL           PSE
# 945                            S. Nova Ves   SK          SEPS
# 948                         Draganesti Olt   RO           TEL
# 949                             Sajoivanka   HU         MAVIR
# 951                        Portile de Fier   RO           TEL
# 960                              Y-Huntorf   DE    TENNETGMBH
# 966                         Eemshaven Oost   NL     TENNET NL
# 968            REPIQUAGE SENONCHAMPS 220kV   BE          ELIA
# 971                              Tariverde   RO           TEL
# 977                                 Hasdat   RO           TEL
# 979                                  Klece   SI          ELES
# 981                             H.Zivotice   CZ          CEPS
# 986                                 ACHENE   BE          ELIA
# 987                                Waldeck   DE    TENNETGMBH
# 993                                Stupina   RO           TEL
# 996                              TIHANGE 3   BE          ELIA
# 997                  T.SUP / PRION - TAVEL   FR           RTE
# 1016                               Pestis    RO           TEL
# 1031                      Dreibein Mellach   AT           APG
# 1032                           Vijfhuizen    NL     TENNET NL
# 1034                               Gadalin   RO           TEL
# 1046                            Wengerrohr   DE  Amprion GmbH
# 1050                             T HAL-BYĆ   PL           PSE
# 1051                           Jessen/Nord   DE       50HERTZ
# 1053                                Levice   SK          SEPS
# 1054                              Cluj Est   RO           TEL
# 1057                                LE VAL   BE          ELIA
# 1058                             Dettingen   DE  Amprion GmbH
# 1060                             LA TROQUE   BE          ELIA
# 1063                                   GKM   DE    TRANSNETBW
# 1068                             Bacharach   DE  Amprion GmbH
# 1070                                  Arad   RO           TEL
# 1076                          CENTRALE COO   BE          ELIA
# 1078                          Niederlangen   DE    TENNETGMBH
# 1082                              Mariselu   RO           TEL
# 1087                                 CHELM   PL           PSE
# 1091                               L. Mara   SK          SEPS
# 1094            AFTAKKING BUGGENHOUT 380kV   BE          ELIA
# 1100                                 Sugag   RO           TEL
# 1101                                 AWIRS   BE          ELIA
# 1103                              OLTARZEW   PL           PSE
# 1109                                Sucany   SK          SEPS
# 1112                                  Silz   DE    TENNETGMBH
# 1115                   OFFSHORE SWITCHYARD   BE          ELIA
# 1116                           Weissenbach   AT           APG
# 1117                                 KALLO   BE          ELIA
# 1121                                Asslar   DE  Amprion GmbH
# 1127                                  Vola   SK          SEPS
# 1128                               Sostanj   SI          ELES
# 1129                                 Siems   DE    TENNETGMBH
# 1132                                Siroka   SK          SEPS
# 1136                         GRILLE-AVOINE   FR           RTE
# 1137                              Ungheni    RO           TEL
# 1145                        Zell am Ziller   AT           APG
# 1146                          FAUX FRENAIS   FR           RTE
# 1154                               Galceag   RO           TEL
# 1157                            Suederdonn   DE    TENNETGMBH
# 1158                              Ybbsfeld   AT           APG
# 1159                               Kerepes   HU         MAVIR
# 1166           REPIQUAGE SART-TILMAN 220kV   BE          ELIA
# 1177                               Rosiori   RO           TEL
# 1187                             VILLEROUX   BE          ELIA
# 1190                          Y-Dauersberg   DE  Amprion GmbH
# 1195                        Y-Niederlangen   DE  Amprion GmbH
# 1198                           Y-Plattling   DE    TENNETGMBH
# 1203                                 HORTA   BE          ELIA
# 1204                                V. Dur   SK          SEPS
# 1205                                Darste   RO           TEL
# 1207                         Cluj Floresti   RO           TEL
# 1208                          GDANSK-BLONI   PL           PSE
# 1209                             Eindhoven   NL     TENNET NL
# 1211                           P. Bystrica   SK          SEPS
# 1217                                Tauern   AT           APG
# 1221                             Y-Oechtel   DE  Amprion GmbH
# 1222                             Urechesti   RO           TEL
# 1224                    Turnu Severin Est    RO           TEL
# 1227                          ANDRE DUMONT   BE          ELIA
# 1231                               PELPLIN   PL           PSE
# 1235                             R. Sobota   SK          SEPS
# 1237                              Lelystad   NL     TENNET NL
# 1238                           Pitesti Sud   RO           TEL
# 1255                          SCHIFFLANGE    DE         Creos
# 1256                              Hausruck   AT           APG
# 1257                             Kronstorf   AT           APG
# 1259                    Breukelen Kortrijk   NL     TENNET NL
# 1262                          Y-Schwelgern   DE  Amprion GmbH
# 1268                                 Jozsa   HU         MAVIR
# 1274                              Ghizdaru   RO           TEL
# 1276                              Paroseni   RO           TEL
# 1277                                 Phyrn   AT           APG
# 1280                            Wateringen   NL     TENNET NL
# 1283                            Hessenberg   AT           APG
# 1285                            Dauersberg   DE  Amprion GmbH
# 1287                               Ternitz   AT           APG
# 1288                              Dumbrava   RO           TEL
# 1289                        Calea Aradului   RO           TEL
# 1291                                Rosegg   AT           APG
# 1295                      Portile de Fier    RO           TEL
# 1304                                Pecs 2   HU         MAVIR
# 1314                                 LIXHE   BE          ELIA
# 1320                               Kuehtai   DE    TENNETGMBH
# 1327                        Targu Jiu Nord   RO           TEL
# 1328                               Zwolle    NL     TENNET NL
# 1329                            Schwelgern   DE  Amprion GmbH
# 1332                             Baru Mare   RO           TEL
# 1333                               Spellen   DE  Amprion GmbH
# 1334                          Targoviste B   RO           TEL
# 1337                          Focsani Vest   RO           TEL
# 1347                         Schwarzenbach   AT           APG
# 1351                               AUBANGE   DE         Creos
# 1352                             Sibiu Sud   RO           TEL
# 1353                               Stejaru   RO           TEL
# 1354                             Doerpen/W   DE    TENNETGMBH
# 1355                                  LINT   BE          ELIA
# 1357                                ROMSEE   BE          ELIA
# 1360                                Pestis   RO           TEL
# 1361                             TIHANGE 2   BE          ELIA
# 1363                            Timisoara    RO           TEL
# 1372                             Lambsheim   DE  Amprion GmbH
# 1375                                 PLOCK   PL           PSE
# 1382                                Greuth   AT           APG
# 1385                              MERCATOR   BE          ELIA
# 1388                          STALOWA WOLA   PL           PSE
# 1389                             Stalldorf   DE    TENNETGMBH
# 1390                             Doekegat    NL     TENNET NL
# 1394                            Alba Iulia   RO           TEL
# 1396                                   Iaz   RO           TEL
# 1401                               Aschach   AT           APG
# 1408                             Dodewaard   NL     TENNET NL
# 1411            PIQUAGE A LA PRAZ-ST-ANDRE   FR           RTE
# 1414                                Cetate   RO           TEL
# 1417                           H. Zivotice   CZ          CEPS
# 1419                         PILA KRZEWINA   PL           PSE
# 1420          AFTAKKING LIEFKENSHOEK 380kV   BE          ELIA
# 1421              AFTAKKING MEKINGEN 380kV   BE          ELIA
# 1430                              BASTOGNE   BE          ELIA
# 1433                            HOUFFALIZE   BE          ELIA
# 1444                           V. Kapusany   SK          SEPS
# 1445                                Vojany   SK          SEPS
# 1447                            Westerlee    NL     TENNET NL
# 1450                           Rommersheim   DE  Amprion GmbH
# 1464      BEAUREGARD (SAINT-LAURENT-NOUAN)   FR           RTE
# 1466                             Handewitt   DE    TENNETGMBH
# 1469                   PIQUAGE A PLUVIGNER   FR           RTE
# 1470                          Craiova Nord   RO           TEL
# 1479                            BOGUCHWALA   PL           PSE
# 1480                             BERTRANGE   DE         Creos
# 1483                          Schwoerstadt   DE    TRANSNETBW
# 1490                             Fantanele   RO           TEL
# 1491                             DUVIGNEAU   FR           RTE
# 1496                                Pecs 1   HU         MAVIR
#
#                              name_norm        lat        lon  \
# 2                         olsztyn-matk        NaN        NaN
# 3                            eindhoven  51.439265   5.478633
# 4                              slatina  44.429997  24.363184
# 7                           cierny vah        NaN        NaN
# 13                             jupille        NaN        NaN
# 20            alegro convertor station        NaN        NaN
# 27                 salzburg elixhausen  47.861606  13.062070
# 28                          lacu sarat  45.221858  28.180003
# 32                             marlant        NaN        NaN
# 35              eemshaven het hogeland  53.448474   6.849963
# 47                         tulcea vest  45.181420  28.793183
# 54                               husum  54.485364   9.053816
# 58                             dresden  51.049329  13.738144
# 59                              bosaca  48.826459  17.842651
# 62                                sala  48.151379  17.874859
# 64                        targoviste a  44.926771  25.462816
# 65                              resita  45.306083  21.885453
# 66                             boxmeer  51.648648   5.945097
# 67                         massenhoven  51.199020   4.634960
# 68                             seraing  50.615238   5.508944
# 69                            van eyck  50.847959   3.110061
# 71                             losnice        NaN        NaN
# 75                            marcourt  50.214540   5.526817
# 76                             marbach  50.815706   8.749535
# 81                              divaca  45.682525  13.968969
# 83                             rouvroy  49.539075   5.489710
# 85                             moldava        NaN        NaN
# 90                        szabolcsbaka  48.157223  22.139586
# 91                              schuby  54.515820   9.480011
# 93                eemshaven oude schip        NaN        NaN
# 95                             calafat  43.994298  22.933703
# 107                           stuparei  45.017362  24.280039
# 113                       wloclawek az        NaN        NaN
# 114                             brasov  45.652309  25.610275
# 129                             gramme  50.294046   5.105242
# 132                          medzibrod  48.793399  19.357108
# 134                     verbrande brug  50.947856   4.413331
# 135                         gheorgheni  46.721347  25.599891
# 143                            gezelle  50.981025   3.532871
# 150                              vetis  47.800216  22.777895
# 155                     gura ialomitei  44.709597  27.756048
# 157                       d. mostistea        NaN        NaN
# 158                            ungheni  46.483480  24.457419
# 160                             resita  45.306083  21.885453
# 164                         maasvlakte  51.954352   4.019799
# 166                           domnesti  45.206701  24.839921
# 169                             reclaw        NaN        NaN
# 172                            gutinas  46.206674  26.820528
# 174                            parchim  53.425846  11.847524
# 175                              lotru  45.337653  24.251981
# 177                            rimiere  50.540359   5.471457
# 187                        dorpen west  52.980959   7.256659
# 192                        sart-tilman        NaN        NaN
# 200                   siedlce ujrzanow        NaN        NaN
# 201          piquage a villiers-le-bel        NaN        NaN
# 208             piquage a saint gerons        NaN        NaN
# 211                            zeltweg  47.191204  14.754924
# 214                              tihau  47.226562  23.329453
# 216                               zaya  48.606149  16.799900
# 229                          heilbronn  49.142291   9.218655
# 232                            filesti        NaN        NaN
# 234                 repiquage marcourt        NaN        NaN
# 235                               senj        NaN        NaN
# 237                       st-mard sncb        NaN        NaN
# 242                          sarasdorf  48.028250  16.675017
# 244                piquage a duvigneau        NaN        NaN
# 248                              bayer  40.489296  -3.390595
# 250                            homburg  49.318167   7.334034
# 254                         crayestein  51.818377   4.745680
# 265                             zwolle  52.508976   6.094377
# 266                                fai        NaN        NaN
# 269                          bleiswijk  52.010958   4.531084
# 273                 krimpen a/d ijssel  51.914403   4.588789
# 279                        j. bohunice  48.477879  17.635222
# 288                              salaj  47.156187  23.019192
# 290                       emscherbruch        NaN        NaN
# 292                         ernsthofen  48.138839  14.499729
# 293                          ostroleka  53.078032  21.574869
# 295                tran5 / gavre perta        NaN        NaN
# 297                        ostrow wlkp  51.647186  17.803761
# 304                        tihange bis        NaN        NaN
# 306                           tiszalok  48.017176  21.374966
# 314                        stanislawow  52.291113  21.549116
# 318                           isalnita  44.394651  23.733251
# 321                        ohlensehlen        NaN        NaN
# 322                         bystricany  48.658944  18.517726
# 325                            smardan  45.472415  27.945631
# 328                         zuttendaal        NaN        NaN
# 329                    waldlaubersheim  49.928579   7.833602
# 332                           kisvarda  48.225759  22.078425
# 333                            isaccea  45.272189  28.457146
# 337                             brugel        NaN        NaN
# 339                          westerlee  53.145140   6.987570
# 344                            elk bis        NaN        NaN
# 345                 piquage a foncrose        NaN        NaN
# 347                            milosna  51.012457  15.510220
# 350                        baia mare 3  47.677543  23.620772
# 351                            tergnee        NaN        NaN
# 352               repiquage houffalize        NaN        NaN
# 355                   zydowo kierzkowo  54.025145  16.707052
# 357                          gottingen  51.532833   9.935181
# 358                         oradea sud        NaN        NaN
# 360                       altentreptow  53.692903  13.251246
# 363                            rilland  51.416475   4.181242
# 364                          hessenweg        NaN        NaN
# 365                         brume sncb        NaN        NaN
# 366                            perkata  47.047973  18.790124
# 367                          sibiu sud        NaN        NaN
# 370                         weingarten  47.807530   9.643114
# 372                          gabcikovo  47.895106  17.578125
# 373                         etzersdorf        NaN        NaN
# 375                        heinersdorf  52.572825  13.437015
# 377                      bucuresti sud  44.921164  26.032431
# 378                         otelarie h        NaN        NaN
# 383                           c. stred  50.680336  14.021389
# 385                           diefflen  49.378573   6.752723
# 390                        porabka-zar  49.787367  19.230216
# 399                   repiquage latour        NaN        NaN
# 403                            aniolow        NaN        NaN
# 408                          oudehaske  52.956109   5.872593
# 411                             kosice  48.717227  21.249677
# 416                          ve padene        NaN        NaN
# 419                    targiu jiu nord        NaN        NaN
# 420                          eemshaven  53.448474   6.849963
# 429                              bradu  45.721032  24.328952
# 432                           woringen  47.923405  10.200843
# 439                       altentreptow  53.692903  13.251246
# 440                          bertrange        NaN        NaN
# 445                         gelsenberg  51.530226   7.038534
# 448                          plattling  48.777256  12.875067
# 450                    waldlaubersheim  49.928579   7.833602
# 451                             izegem  50.913774   3.209107
# 454                             iernut  46.450190  24.230670
# 456                          timisoara  45.753836  21.225747
# 458                              arefu  45.329963  24.609821
# 468                            berchem  51.194352   4.432997
# 471                            fundeni  45.291411  26.880282
# 476                      campia turzii  46.547181  23.886967
# 483                            sacalaz  45.760383  21.111025
# 495                            retezat  45.324775  22.787799
# 496                          bacau sud        NaN        NaN
# 503                    gdansk przyjazn        NaN        NaN
# 505                        achene sncb        NaN        NaN
# 513                            suceava  47.532653  25.834594
# 514                     turnu magurele  43.751831  24.869172
# 516                        heinersdorf  52.572825  13.437015
# 518                             slupsk  54.463577  17.020948
# 520                              fwh-s        NaN        NaN
# 530                     gura ialomitei  44.709597  27.756048
# 536                          drogenbos  50.786532   4.317354
# 537                               gouy        NaN        NaN
# 544                          bleiswijk  52.010958   4.531084
# 546                              varin  49.201440  18.870500
# 551                       fedderwarden  53.562879   8.044606
# 552                            rosiori  47.256772  21.952090
# 556                          metzingen  48.539725   9.283120
# 561                           h. zdana        NaN        NaN
# 563                       p. biskupice  48.123789  17.209001
# 577                             plomin        NaN        NaN
# 579                           pelicanu        NaN        NaN
# 581                            munteni  47.315302  27.138395
# 582                            huntorf  53.190333   8.408952
# 589                          mayrhofen  47.167219  11.863866
# 591                       medgidia sud  44.259590  28.263270
# 598                            raureni  45.055448  24.331249
# 601                           ruhrzink        NaN        NaN
# 602                           diefflen  49.378573   6.752723
# 603                            meduric  45.458311  16.927502
# 606                            lagisza  50.354127  19.135691
# 607                             pehlin  45.353702  14.404340
# 619                         bekescsaba  46.679800  21.098543
# 621                            okroglo        NaN        NaN
# 625                            zakucac  43.457284  16.700039
# 629                         bellendorf  51.669924   6.981617
# 631                          feistritz  47.599908  16.054196
# 632                    lomza systemowa        NaN        NaN
# 636                           teleajen  44.813915  26.215942
# 647                            homburg  49.318167   7.334034
# 652                            gransee  53.007278  13.158869
# 655                            wroclaw  51.108978  17.032669
# 656                        villach sud  46.553823  13.828503
# 660                   champion (namur)  50.496387   4.901218
# 662                       saint hubert  49.222747   6.333195
# 663                           urdingen        NaN        NaN
# 670                        eeklo noord  51.034251   3.710259
# 674                           polaniec  50.432907  21.281047
# 684                            barbosi        NaN        NaN
# 688                            bidngen        NaN        NaN
# 691                 repiquage st-amand        NaN        NaN
# 693                          dotinchem        NaN        NaN
# 694                        simonshaven  51.821920   4.289647
# 696                          neunhagen        NaN        NaN
# 699                            weiwerd        NaN        NaN
# 703                        robbenplaat  52.839278   5.015358
# 718                             melina        NaN        NaN
# 725                         rodenhuize        NaN        NaN
# 726                         poznan pld        NaN        NaN
# 727                           mochovce  48.264748  18.438051
# 729                          eemshaven  53.448474   6.849963
# 736                             latour  49.557884   5.568294
# 740                              praga  51.646230  20.946580
# 742                             brinje  44.998278  15.131687
# 743                             pulawy  51.426260  21.985301
# 745                           elsfleth  53.235703   8.457104
# 746                           sattledt  48.070299  14.058129
# 752                             stalpu  45.085186  26.708386
# 753                          louwsmeer        NaN        NaN
# 756                          t joa-lag        NaN        NaN
# 759                           bericevo        NaN        NaN
# 761                         brazi vest  44.955282  25.998502
# 762                          beverwijk  52.487637   4.660350
# 765                            st-mard  49.541631   5.533392
# 768                          velky dur  48.211488  18.446216
# 769                        felsozsolca  48.104100  20.860540
# 772                           isalnita  44.394651  23.733251
# 773                              lillo  51.314172   4.315093
# 775                             stevin  50.866669   4.675688
# 779                          zeyerveen        NaN        NaN
# 781                            wallsee        NaN        NaN
# 785                               detk  47.747533  20.099297
# 791                            tihange        NaN        NaN
# 792                            putlitz  53.250672  12.040672
# 794                           lelystad  52.515095   5.476891
# 795                           mettmann  51.252778   6.977778
# 797                          villingen  50.500067   8.956022
# 801                         szigetcsep  47.267148  18.967267
# 807                             rahman  44.799195  28.272857
# 811                            blooren  49.597148   6.179656
# 816                              nadab        NaN        NaN
# 828                             oxylux        NaN        NaN
# 830                             untrop        NaN        NaN
# 831                         sardanesti  44.770860  23.360874
# 839                             ochtel        NaN        NaN
# 846                        torun elana        NaN        NaN
# 851                          tantareni  44.593640  23.494135
# 854                         gelsenberg  51.530226   7.038534
# 855                             mintia  45.923360  22.848289
# 857                     constanta nord        NaN        NaN
# 859                         meckenheim  49.404621   8.239793
# 860       poste de transition longu vu        NaN        NaN
# 861                           gradiste        NaN        NaN
# 862                            waldeck  51.242511   9.038121
# 872                          cernavoda  44.341635  28.031625
# 880                            berneau        NaN        NaN
# 883                            smardan  45.472415  27.945631
# 894                           te sisak  45.454009  16.413934
# 897                     altenkleusheim        NaN        NaN
# 900                         rodenhuize        NaN        NaN
# 905                              klaus  47.307759   9.647796
# 908                          kledering        NaN        NaN
# 909                            heinsch  49.689336   5.758716
# 911                             belval  49.039940  -1.363712
# 913                             gorzow  51.028155  18.422268
# 920                       kottigerhook        NaN        NaN
# 930                          gutersloh  51.906400   8.378208
# 931                              brume        NaN        NaN
# 936                          gutersloh  51.906400   8.378208
# 939                           meerhout  51.131743   5.077239
# 941                           mikulowa  51.080773  15.108735
# 945                        s. nova ves        NaN        NaN
# 948                     draganesti olt  44.168473  24.521972
# 949                         sajoivanka  48.266106  20.579371
# 951                    portile de fier  44.671252  22.529502
# 960                            huntorf  53.190333   8.408952
# 966                     eemshaven oost        NaN        NaN
# 968              repiquage senonchamps        NaN        NaN
# 971                          tariverde  44.562932  28.601927
# 977                             hasdat        NaN        NaN
# 979                              klece        NaN        NaN
# 981                         h.zivotice        NaN        NaN
# 986                             achene        NaN        NaN
# 987                            waldeck  51.242511   9.038121
# 993                            stupina  44.565368  28.179262
# 996                          tihange 3        NaN        NaN
# 997              t.sup / prion - tavel        NaN        NaN
# 1016                            pestis  47.073183  22.413666
# 1031                  dreibein mellach        NaN        NaN
# 1032                        vijfhuizen  52.350779   4.678232
# 1034                           gadalin  46.840221  23.848517
# 1046                        wengerrohr        NaN        NaN
# 1050                         t hal-byc        NaN        NaN
# 1051                            jessen  51.793116  12.959074
# 1053                            levice  48.216319  18.600087
# 1054                          cluj est        NaN        NaN
# 1057                            le val  50.604165   5.492740
# 1058                         dettingen  47.735217   9.117262
# 1060                          la troqu        NaN        NaN
# 1063                               gkm  11.932303  79.807929
# 1068                         bacharach  50.059794   7.768400
# 1070                              arad  46.175379  21.319634
# 1076                      centrale coo        NaN        NaN
# 1078                      niederlangen  52.857217   7.280537
# 1082                          mariselu  47.011928  24.508094
# 1087                             chelm  51.135588  23.493936
# 1091                           l. mara        NaN        NaN
# 1094                        buggenhout  51.011310   4.192796
# 1100                             sugag  45.775693  23.626991
# 1101                             awirs        NaN        NaN
# 1103                          oltarzew  52.211775  20.764200
# 1109                            sucany  48.732646  18.468924
# 1112                              silz  53.520291  12.441071
# 1115               offshore switchyard        NaN        NaN
# 1116                       weissenbach        NaN        NaN
# 1117                             kallo  51.251951   4.278030
# 1121                            asslar  50.592795   8.464908
# 1127                              vola  48.841016  21.843886
# 1128                           sostanj  46.377393  15.045951
# 1129                             siems        NaN        NaN
# 1132                            siroka  48.998998  20.942990
# 1136                     grille-avoine        NaN        NaN
# 1137                           ungheni  46.483480  24.457419
# 1145                    zell am ziller  47.226486  11.881920
# 1146                      faux frenais        NaN        NaN
# 1154                           galceag        NaN        NaN
# 1157                         suderdonn        NaN        NaN
# 1158                          ybbsfeld  48.129702  14.953963
# 1159                           kerepes  47.561613  19.286907
# 1166             repiquage sart-tilman        NaN        NaN
# 1177                           rosiori  47.256772  21.952090
# 1187                         villeroux  49.978180   5.656267
# 1190                         daursberg        NaN        NaN
# 1195                      niederlangen  52.857217   7.280537
# 1198                         plattling  48.777256  12.875067
# 1203                             horta  50.829761   5.113147
# 1204                            v. dur        NaN        NaN
# 1205                            darste  45.618844  25.653600
# 1207                     cluj floresti  46.734300  23.484684
# 1208                      gdansk-bloni        NaN        NaN
# 1209                         eindhoven  51.439265   5.478633
# 1211                       p. bystrica  48.571736  19.191238
# 1217                             taurn        NaN        NaN
# 1221                            ochtel        NaN        NaN
# ...
# 458                               Arefu, Argeș, Romania
# 468           Berchem, Antwerp, Flanders, 2600, Belgium
# 471           Fundeni, Zărnești, Buzău, 127717, Romania
# 476                Câmpia Turzii, Cluj, 405100, Romania
# 483                             Săcălaz, Timiș, Romania
# 495           Retezat National Park, Hunedoara, Romania
# 496
# 503
# 505
# 513                                    Suceava, Romania
# 514          Turnu Măgurele, Teleorman, 145200, Romania
# 516         Heinersdorf, Pankow, Berlin, 13089, Germany
# 518      Słupsk, Pomeranian Voivodeship, 76-200, Poland
# 520
# 530                   Gura Ialomiței, Ialomița, Romania
# 536   Drogenbos, Halle-Vilvoorde, Flemish Brabant, F...
# 537
# 544   Bleiswijk, Lansingerland, South Holland, Nethe...
# 546   Varín, District of Žilina, Region of Žilina, C...
# 551   Fedderwarden, Wilhelmshaven, Lower Saxony, Ger...
# 552                             Roșiori, Bihor, Romania
# 556   Metzingen, Gemeindeverwaltungsverband Metzinge...
# 561
# 563   P - Klinika funkčnej diagnostiky, oddelenie pľ...
# 577
# 579
# 581            Munteni, Belcești, Iași, 707047, Romania
# 582   Huntorf, 65, Große Hellmer, Elsfleth, Landkrei...
# 589   Marktgemeinde Mayrhofen, Bezirk Schwaz, Tyrol,...
# 591   Tribunalul Medgidia, Bulevardul Independenței,...
# 598    Râureni, Râmnicu Vâlcea, Vâlcea, 240475, Romania
# 601
# 602   Diefflen, Dillingen/Saar, Landkreis Saarlouis,...
# 603   Međurić, Grad Kutina, Sisak-Moslavina County, ...
# 606   Łagisza, Będzin, Będzin County, Górnośląsko-Za...
# 607   Mjesni odbor Pehlin, Grad Rijeka, Primorje-Gor...
# 619   Békéscsaba, Békéscsabai járás, Békés, South Gr...
# 621
# 625   Zakučac, Grad Omiš, Split-Dalmatia County, Cro...
# 629   Bellendorf, 9, Im Harsewinkel, Hervest Dorsten...
# 631   Feistritz am Wechsel, Bezirk Neunkirchen, Lowe...
# 632
# 636   Teleajen, Palanca, Râfov, Prahova, 107503, Rom...
# 647   Homburg, Saarpfalz-Kreis, Saarland, 66424, Ger...
# 652   Gransee, Gransee und Gemeinden, Oberhavel, Bra...
# 655         Wrocław, Lower Silesian Voivodeship, Poland
# 656   Villach Süd, Neufeld, Sankt Job, Finkenstein a...
# 660            Champion, Namur, Wallonia, 5020, Belgium
# 662   Saint-Hubert, Metz, Moselle, Grand Est, Metrop...
# 663
# 670   Vorming Plus Gent-Eeklo, 8, Reigerstraat, Stat...
# 674   Połaniec, gmina Połaniec, Staszów County, Świę...
# 684
# 688
# 691
# 693
# 694   Simonshaven, Nissewaard, South Holland, Nether...
# 696
# 699
# 703   Robbenplaat, Wieringerwerf, Hollands Kroon, No...
# 718
# 725
# 726
# 727   Mochovce, Kalná nad Hronom, District of Levice...
# 729     Eemshaven, Het Hogeland, Groningen, Netherlands
# 736                   Latour, Virton, Wallonia, Belgium
# 740   Praga, Białobrzegi, gmina Białobrzegi, Białobr...
# 742   Sokolac, Zadgrad, Brinje, Općina Brinje, Lika-...
# 743   Puławy, Puławy County, Lublin Voivodeship, 24-...
# 745   Elsfleth, Landkreis Wesermarsch, Lower Saxony,...
# 746   Sattledt, Bezirk Wels-Land, Upper Austria, 464...
# 752                      Stâlpu, Buzău, 127605, Romania
# 753
# 756
# 759
# 761   Grădinița Step by Step Licurici (nr. 53 Brazi)...
# 762               Beverwijk, North Holland, Netherlands
# 765         Saint-Mard, Virton, Wallonia, 6762, Belgium
# 768   Veľký Ďur, District of Levice, Region of Nitra...
# 769   Felsőzsolca, Miskolci járás, Borsod-Abaúj-Zemp...
# 772   Ișalnița, Craiova Metropolitan Area, Dolj, 207...
# 773   Lillo, Berendrecht-Zandvliet-Lillo, Antwerp, F...
# 775   470-14, 82, Remisebosweg, Heverlee, Leuven, Fl...
# 779
# 781
# 785   Detk, Gyöngyösi járás, Heves, North Hungary, G...
# 791
# 792   Putlitz, Putlitz-Berge, Prignitz, Brandenburg,...
# 794                    Lelystad, Flevoland, Netherlands
# 795   Mettmann, Kreis Mettmann, North Rhine-Westphal...
# 797   Villingen, Hungen, Landkreis Gießen, Hesse, Ge...
# 801   Szigetcsép, Ráckevei járás, Pest, Central Hung...
# 807           Rahman, Casimcea, Tulcea, 827029, Romania
# 811   Poste blindé d'Itzig/Blooren, Itzig, Hesperang...
# 816
# 828
# 830
# 831         Sărdănești, Plopșoru, Gorj, 217356, Romania
# 839
# 846
# 851                    Țânțăreni, Gorj, 217535, Romania
# 854   Gelsenbergstraße, Horst, Gelsenkirchen-West, G...
# 855           Mintia, Vețel, Hunedoara, 337532, Romania
# 857
# 859   Meckenheim, Deidesheim, Landkreis Bad Dürkheim...
# 860
# 861
# 862   Waldeck, Landkreis Waldeck-Frankenberg, Hesse,...
# 872               Cernavoda, Constanța, 905200, Romania
# 880
# 883                            Smârdan, Galați, Romania
# 894   Termoelektrana-toplana Sisak, Gradska četvrt C...
# 897
# 900
# 905   Gemeinde Klaus, Bezirk Feldkirch, Vorarlberg, ...
# 908
# 909                   Heinsch, Arlon, Wallonia, Belgium
# 911   Belval, Coutances, Manche, Normandy, Metropoli...
# 913   Gorzów Śląski, gmina Gorzów Śląski, Olesno Cou...
# 920
# 930   Gütersloh, Kreis Gütersloh, North Rhine-Westph...
# 931
# 936   Gütersloh, Kreis Gütersloh, North Rhine-Westph...
# 939   Meerhout, Turnhout, Antwerp, Flanders, 2450, B...
# 941   Mikułowa, gmina Sulików, Zgorzelec County, Low...
# 945
# 948                        Drăgănești-Olt, Olt, Romania
# 949   Sajóivánka, Kazincbarcikai járás, Borsod-Abaúj...
# 951   Iron Gate I, Drobeta-Turnu Severin, Mehedinți,...
# 960   Huntorf, 65, Große Hellmer, Elsfleth, Landkrei...
# 966
# 968
# 971     Tariverde, Cogealac, Constanța, 907076, Romania
# 977
# 979
# 981
# 986
# 987   Waldeck, Landkreis Waldeck-Frankenberg, Hesse,...
# 993         Stupina, Crucea, Constanța, 907101, Romania
# 996
# 997
# 1016              Peștiș, Alesd, Bihor, 415102, Romania
# 1031
# 1032  Vijfhuizen, Haarlemmermeer, North Holland, Net...
# 1034  Gădălin, Jucu, Cluj Metropolitan Area, Cluj, 4...
# 1046
# 1050
# 1051  Jessen (Elster), Wittenberg, Saxony-Anhalt, Ge...
# 1053  Levice, District of Levice, Region of Nitra, W...
# 1054
# 1057  Le Val, Jemeppe-Sur-Meuse, Seraing, Liège, Wal...
# 1058  Konstanz-Dettingen, Dettingen-Wallhausen, Cons...
# 1060
# 1063  GKM, Ellapillaichavady Road, Periyar Nagar, Th...
# 1068  Bacharach, Rhein-Nahe, Landkreis Mainz-Bingen,...
# 1070                                      Arad, Romania
# 1076
# 1078  Niederlangen, Samtgemeinde Lathen, Landkreis E...
# 1082                 Mărișelu, Bistrița-Năsăud, Romania
# 1087                  Chełm, Lublin Voivodeship, Poland
# 1091
# 1094  Buggenhout, Dendermonde, East Flanders, Flande...
# 1100                               Șugag, Alba, Romania
# 1101
# 1103  Ołtarzew, gmina Ożarów Mazowiecki, Warsaw West...
# 1109  Nitrianske Sučany, District of Prievidza, Regi...
# 1112  Silz, Malchow, Mecklenburgische Seenplatte, Me...
# 1115
# 1116
# 1117  Kallo, Beveren, Sint-Niklaas, East Flanders, F...
# 1121      Aßlar, Lahn-Dill-Kreis, Hesse, 35614, Germany
# 1127  Voľa, District of Michalovce, Region of Košice...
# 1128                            Šoštanj, 3326, Slovenia
# 1129
# 1132  Široké, District of Prešov, Region of Prešov, ...
# 1136
# 1137  Ungheni, Targu Mures Metropolitan Area, Mureș,...
# 1145  Marktgemeinde Zell am Ziller, Bezirk Schwaz, T...
# 1146
# 1154
# 1157
# 1158  Pfarrkirche St. Georgen am Ybbsfeld, Am Kirche...
# 1159  Kerepes, Gödöllő Regional Unit, Pest, Central ...
# 1166
# 1177                            Roșiori, Bihor, Romania
# 1187  Villeroux, Sibret, Vaux-sur-Sûre, Bastogne, Wa...
# 1190
# 1195  Niederlangen, Samtgemeinde Lathen, Landkreis E...
# 1198  Plattling, Landkreis Deggendorf, Bavaria, 9444...
# 1203  HORTA, 2, Lewastraat, Zoutleeuw, Leuven, Flemi...
# 1204
# 1205  Dârste, Strada Timișul Sec (Centura Brașovului...
# 1207  Metrou Cluj - Teilor, Cetatea Fetei, Florești,...
# 1208
# 1209              Eindhoven, North Brabant, Netherlands
# 1211  Lesy SR š.p., Môťová, Zvolen, District of Zvol...
# 1217
# 1221
# 1222                          Urechești, Bacău, Romania
# 1224
# 1227  André Dumont, Place du XX Août, Centre, Griveg...
# 1231  Pelplin, gmina Pelplin, Tczew County, Pomerani...
# 1235  Detox Environmental services s.r.o., Rimavská ...
# 1237                   Lelystad, Flevoland, Netherlands
# 1238
# 1255
# 1256
# 1257  Kronstorf, Bezirk Linz-Land, Upper Austria, 44...
# 1259  Fly-over Breukelen, Keulschevaart, Kortrijk, B...
# 1262  Schwelgern, Walsumer Straße, Aldenrade, Walsum...
# 1268
# 1274               Ghizdaru, Stănești, Giurgiu, Romania
# 1276  Paroșeni Power Station, Jiu-Paroșeni, Vulcan, ...
# 1277
# 1280   Wateringen, Westland, South Holland, Netherlands
# 1283
# 1285
# 1287  Gemeinde Ternitz, Bezirk Neunkirchen, Lower Au...
# 1288       Dumbrava, Căpușu Mare, Cluj, 407152, Romania
# 1289
# 1291  Rosegg, Bezirk Villach-Land, Carinthia, 9232, ...
# 1295  Iron Gate I, Drobeta-Turnu Severin, Mehedinți,...
# 1304  Pécs, Pécsi járás, Baranya, Southern Transdanu...
# 1314
# 1320
# 1327
# 1328                    Zwolle, Overijssel, Netherlands
# 1329  Schwelgern, Walsumer Straße, Aldenrade, Walsum...
# 1332
# 1333  Spellen, Voerde (Niederrhein), Kreis Wesel, No...
# 1334                     Târgoviște, Dâmbovița, Romania
# 1337
# 1347  Gemeinde Schwarzenbach, Bezirk Wiener Neustadt...
# 1351
# 1352
# 1353           Stejaru, Brazi, Prahova, 107088, Romania
# 1354  Dörpen, Samtgemeinde Dörpen, Landkreis Emsland...
# 1355             Lint, Antwerp, Flanders, 2547, Belgium
# 1357
# 1360              Peștiș, Alesd, Bihor, 415102, Romania
# 1361
# 1363                          Timișoara, Timiș, Romania
# 1372  Lambsheim, Lambsheim-Heßheim, Rhein-Pfalz-Krei...
# 1375                Płock, Masovian Voivodeship, Poland
# 1382
# 1385  Mercator, 84, Zeedijk, De Panne, Veurne, West ...
# 1388  Stalowa Wola, Stalowa Wola County, Subcarpathi...
# 1389
# 1390
# 1394                          Alba Iulia, Alba, Romania
# 1396
# 1401
# 1408   Dodewaard, Neder-Betuwe, Gelderland, Netherlands
# 1411
# 1414                              Cetate, Dolj, Romania
# 1417
# 1419
# 1420
# 1421
# 1430                  Bastogne, Wallonia, 6600, Belgium
# 1433            Houffalize, Bastogne, Wallonia, Belgium
# 1444
# 1445  Vojany, District of Michalovce, Region of Koši...
# 1447         Westerlee, Oldambt, Groningen, Netherlands
# 1450  Rommersheim, Prüm, Eifelkreis Bitburg-Prüm, Rh...
# 1464  Étang de Beauregard, Riennai, Saint-Laurent-No...
# 1466  Handewitt, Schleswig-Flensburg, Schleswig-Hols...
# 1469
# 1470
# 1479  Boguchwała, gmina Boguchwała, Rzeszów County, ...
# 1480
# 1483  Schwörstadt, Verwaltungsgemeinschaft Rheinfeld...
# 1490                   Fântânele, Iași, 707196, Romania
# 1491
# 1496  Pécs, Pécsi járás, Baranya, Southern Transdanu...

# %%
#backup
df_missing_jao_osm.to_excel("osm_backup_1.xlsx")

# %%
# with google maps
locations_to_double_check = [248, 347, 383, 390, 563]

df_missing_jao_osm.loc[248, 'lat'] = 51.3868123
df_missing_jao_osm.loc[248, 'lon'] = 6.6699285

df_missing_jao_osm.loc[347, 'lat'] = 52.2147341
df_missing_jao_osm.loc[347, 'lon'] = 19.1666693

df_missing_jao_osm.loc[383, 'lat'] = 50.1408201
df_missing_jao_osm.loc[383, 'lon'] = 14.779388

df_missing_jao_osm.loc[390, 'lat'] = 49.7795834
df_missing_jao_osm.loc[390, 'lon'] = 19.2098177

df_missing_jao_osm.loc[563, 'lat'] = 48.2456958
df_missing_jao_osm.loc[563, 'lon'] = 19.7546662

for index, row in df_missing_jao_osm.iterrows():
        df_jao_substations.loc[index, 'lat'] = row['lat']
        df_jao_substations.loc[index, 'lon'] = row['lon']

# %%
# fill in skipped substations
# google maps
# https://www.4coffshore.com/windfarms/belgium/seamade-(mermaid)-belgium-be07.html
# https://www.transnetbw.de/en/energy-market/congestion-management/congestion

df_jao_substations.loc[189, 'lat'] = 49.0150679
df_jao_substations.loc[189, 'lon'] = 8.3122858

df_jao_substations.loc[281, 'lat'] = 49.7696621
df_jao_substations.loc[281, 'lon'] = 6.1017144

df_jao_substations.loc[296, 'lat'] = 46.96116
df_jao_substations.loc[296, 'lon'] = 26.92647

df_jao_substations.loc[341, 'lat'] = 49.0157183
df_jao_substations.loc[341, 'lon'] = 8.1224769

df_jao_substations.loc[690, 'lat'] = 49.0157183
df_jao_substations.loc[690, 'lon'] = 8.1224769

df_jao_substations.loc[953, 'lat'] = 49.4445287
df_jao_substations.loc[953, 'lon'] = 8.4973346

df_jao_substations.loc[992, 'lat'] = 50.6106292
df_jao_substations.loc[992, 'lon'] = 5.6286262

df_jao_substations.loc[1346, 'lat'] = 51.680497
df_jao_substations.loc[1346, 'lon'] = 2.885694

# %%
df_missing_manual = df_jao_substations[df_jao_substations.lat.isnull()]

display(df_missing_manual)
# Out:
#                           name zone    tso                 name_norm  lat  lon
# 2                 OLSZTYN-MATK   PL    PSE              olsztyn-matk  NaN  NaN
# 7                   Cierny Vah   SK   SEPS                cierny vah  NaN  NaN
# 13                     JUPILLE   BE   ELIA                   jupille  NaN  NaN
# 20    ALEGRO CONVERTOR STATION   BE   ELIA  alegro convertor station  NaN  NaN
# 32                    MAERLANT   BE   ELIA                   marlant  NaN  NaN
# ...                        ...  ...    ...                       ...  ...  ...
# 1444               V. Kapusany   SK   SEPS               v. kapusany  NaN  NaN
# 1469       PIQUAGE A PLUVIGNER   FR    RTE       piquage a pluvigner  NaN  NaN
# 1470              Craiova Nord   RO    TEL              craiova nord  NaN  NaN
# 1480                 BERTRANGE   DE  Creos                 bertrange  NaN  NaN
# 1491                 DUVIGNEAU   FR    RTE                 duvigneau  NaN  NaN
#
# [146 rows x 6 columns]

# %%
ox.settings.timeout = 3

for index, row in df_missing_manual.iterrows():
    try:
        tags = {
            'power_source': True,
            'substation': True,
            'electricity': True,
        }
        osm_find = ox.geometries_from_address(row['name'] + ', ' + row['zone'], tags)
        #osm_find = ox.overpass_request(query_data, pause=3, error_pause=3)
        if len(osm_find) > 0:
            display(osm_find.iloc[0])
            df_missing_manual.loc[index, 'osm_find'] = osm_find.iloc[0, 'name']
            df_missing_manual.loc[index, 'osmid'] = osm_find.iloc[0, 'osmid']
        else:
            print('Not found: ', row['name'], ', ', index)
    except ValueError as ve:
        print('Value error, ', row['name'], ', ', index)
    except requests.exceptions.RequestException as rt:
        print('Timeout, ', row['name'], ', ', index)

# %%
display(df_missing_manual)
