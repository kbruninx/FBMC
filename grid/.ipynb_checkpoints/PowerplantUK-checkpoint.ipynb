# %%
import pandas as pd

pd.set_option('display.max_rows', 450)

# %%
df_powerplants = pd.read_csv('./powerplants.csv')

# %%
df_pp_uk = df_powerplants[df_powerplants.Country.isin(['Italy'])]
display(df_pp_uk)
# Out:
#         id               Name     Fueltype     Technology  Set Country  \
# 4        4             Fusina    Hard Coal  Steam Turbine   PP   Italy
# 6        6            Cassano  Natural Gas           CCGT  CHP   Italy
# 7        7     Cte Del Mincio  Natural Gas           CCGT   PP   Italy
# 8        8  Enipower Brindisi  Natural Gas           CCGT  CHP   Italy
# 9        9   Enipower Ravenna  Natural Gas           CCGT  CHP   Italy
# ...    ...                ...          ...            ...  ...     ...
# 4805  5075             Rancia   Geothermal            NaN   PP   Italy
# 4808  5085              Sasso   Geothermal            NaN   PP   Italy
# 4809  5088              Selva   Geothermal            NaN   PP   Italy
# 4810  5089              Sesta   Geothermal            NaN   PP   Italy
# 4813  5113            Travale   Geothermal            NaN   PP   Italy
#
#         Capacity  Efficiency  DateIn  DateRetrofit  DateOut        lat  \
# 4      899.81047         NaN  1964.0           NaN   2025.0  45.431400
# 6      789.00000     0.51303  2003.0           NaN      NaN  45.512340
# 7      400.00000     0.55000  1983.0           NaN      NaN  45.399910
# 8     1275.00000         NaN  2005.0           NaN      NaN  40.643978
# 9      930.00000         NaN  2003.0           NaN      NaN  44.448780
# ...          ...         ...     ...           ...      ...        ...
# 4805    36.00000         NaN     NaN           NaN      NaN  43.238000
# 4808    20.00000         NaN     NaN           NaN      NaN  43.178300
# 4809    19.00000         NaN     NaN           NaN      NaN  43.188900
# 4810    18.00000         NaN     NaN           NaN      NaN  43.239300
# 4813    59.00000         NaN     NaN           NaN      NaN  43.166100
#
#             lon  Duration  Volume_Mm3  DamHeight_m  StorageCapacity_MWh  \
# 4     12.245800       NaN         0.0          0.0                  0.0
# 6      9.509790       NaN         0.0          0.0                  0.0
# 7     10.714280       NaN         0.0          0.0                  0.0
# 8     17.980304       NaN         0.0          0.0                  0.0
# 9     12.237920       NaN         0.0          0.0                  0.0
# ...         ...       ...         ...          ...                  ...
# 4805  11.175100       NaN         0.0          0.0                  0.0
# 4808  10.858600       NaN         0.0          0.0                  0.0
# 4809  10.927600       NaN         0.0          0.0                  0.0
# 4810  10.982300       NaN         0.0          0.0                  0.0
# 4813  11.036000       NaN         0.0          0.0                  0.0
#
#                                            EIC  \
# 4                         {'26WIMPI-S05FTSNK'}
# 6     {'26WIMPI-0817510V', '26WIMPI-S03ACMNW'}
# 7                         {'26WIMPI-S03ACMSM'}
# 8                         {'26WIMPI-S16EBNPL'}
# 9                         {'26WIMPI-S08ERNPQ'}
# ...                                        ...
# 4805  {'26WIMPI-S09RNCAY', '26WIMPI-S09R2NC7'}
# 4808                      {'26WIMPI-S09S2SST'}
# 4809                      {'26WIMPI-S09S1LVB'}
# 4810                      {'26WIMPI-S09S1STV'}
# 4813  {'26WIMPI-S09T3RVH', '26WIMPI-S09T4RVD'}
#
#                                               projectID
# 4     {'BEYONDCOAL': {'BEYOND-IT-24'}, 'ENTSOE': {'2...
# 6     {'ENTSOE': {'26WIMPI-0817510V', '26WIMPI-S03AC...
# 7     {'ENTSOE': {'26WIMPI-S03ACMSM'}, 'OPSD': {'OEU...
# 8     {'ENTSOE': {'26WIMPI-S16EBNPL'}, 'OPSD': {'OEU...
# 9     {'ENTSOE': {'26WIMPI-S08ERNPQ'}, 'OPSD': {'OEU...
# ...                                                 ...
# 4805  {'ENTSOE': {'26WIMPI-S09RNCAY', '26WIMPI-S09R2...
# 4808                   {'ENTSOE': {'26WIMPI-S09S2SST'}}
# 4809                   {'ENTSOE': {'26WIMPI-S09S1LVB'}}
# 4810                   {'ENTSOE': {'26WIMPI-S09S1STV'}}
# 4813  {'ENTSOE': {'26WIMPI-S09T3RVH', '26WIMPI-S09T4...
#
# [449 rows x 19 columns]

# %%
df_pp_uk.to_excel('powerplants_uk.xlsx')
