# %%
import pandas as pd
import networkx as nx
import numpy as np

# %%
df_grid = pd.read_excel('./jao_static_grid.xlsx', sheet_name='Lines', skiprows=[0])
df_grid = df_grid[[
    'NE_name', 'EIC_Code', 'TSO', 
    'Full_name', 'Full_name.1', 'Voltage_level(kV)', 
    'Resistance_R(Ω)', 'Reactance_X(Ω)', 'Susceptance_B(μS)', 'Length_(km)'
]]
df_grid = df_grid.rename(columns={
    'NE_name': 'name', 
    'EIC_Code': 'eic',
    'TSO': 'tso',
    'Voltage_level(kV)': 'voltage',
    'Resistance_R(Ω)': 'resistance',
    'Reactance_X(Ω)': 'reactance',
    'Susceptance_B(μS)': 'susceptance',
    'Length_(km)': 'length',
    'Full_name': 'substation_1',
    'Full_name.1': 'substation_2',
})

tso_zone_map = {
    '50HERTZ': 'DE', 
    'Amprion GmbH': 'DE', 
    'APG': 'AT', 
    'CEPS': 'CZ', 
    'Creos': 'DE', 
    'ELES': 'SI', 
    'ELIA': 'BE',
    'HOPS': 'HR', 
    'MAVIR': 'HU', 
    'PSE': 'PL', 
    'RTE': 'FR', 
    'SEPS': 'SK', 
    'TEL': 'RO', 
    'TENNET NL': 'NL',
    'TENNETGMBH': 'DE', 
    'TRANSNETBW': 'DE'
}

df_grid['zone'] = df_grid.apply(lambda row : tso_zone_map[row.tso], axis=1)

display(df_grid)
# Out:
#                                           name               eic         tso  \
# 0                         Eula - Röhrsdorf 203  11TD8L203------C     50HERTZ
# 1                        Röhrsdorf - Weida 207  11TD8L207------H     50HERTZ
# 2                             Eula - Weida 208  11TD8L208------9     50HERTZ
# 3                      Bentwisch - Güstrow 275  11TD8L275------7     50HERTZ
# 4                       Wuhlheide - Thyrow 291  11TD8L291------L     50HERTZ
# ...                                        ...               ...         ...
# 2657  Y-Stokach (-Gurtweil - Laufenburg) ge-rt  11T0-0000-1626-3  TRANSNETBW
# 2658    Y-Villingen (-Engstlatt - Kuehmoss) gn  11TD400000587-3M  TRANSNETBW
# 2659      Y-Weier (-Daxlanden - Kuppenheim) ge  11TD40000A574-36  TRANSNETBW
# 2660            Y-Weinheim (-GKM - Neurott) rt  11T0-0000-1640-D  TRANSNETBW
# 2661   Y-Wiesloch (-Hueffenhardt - Neurott) ge  11TD400000542-3P  TRANSNETBW
#
#         substation_1 substation_2  voltage  resistance  reactance susceptance  \
# 0               Eula    Röhrsdorf      220      4.0937     18.349  161.163703
# 1          Röhrsdorf        Weida      220      7.5895     31.888  348.716785
# 2               Eula        Weida      220      5.0537     19.541  264.239358
# 3          Bentwisch      Güstrow      220      1.9090     12.055  158.084942
# 4          Wuhlheide       Thyrow      220      2.9672     11.191     266.784
# ...              ...          ...      ...         ...        ...         ...
# 2657      Y-Gurtweil     Stockach      220      2.1000     16.800    347.3659
# 2658     Y-Engstlatt    Villingen      400      0.4500      3.820    78.22566
# 2659     Y-Daxlanden        Weier      220      1.4000     10.750    230.6872
# 2660             GKM     Weinheim      220      0.1000      0.200        1.57
# 2661  Y-Hueffenhardt     Wiesloch      400      0.0600      0.560    9.864602
#
#       length zone
# 0     51.511   DE
# 1     98.324   DE
# 2     67.550   DE
# 3     41.418   DE
# 4     38.882   DE
# ...      ...  ...
# 2657  69.710   DE
# 2658  16.200   DE
# 2659  46.710   DE
# 2660   0.120   DE
# 2661   2.200   DE
#
# [2662 rows x 11 columns]

# %%
s1 = set(df_grid.substation_1.unique())
s1 = s1.union(df_grid.substation_2.unique())
substations = list(s1)

substation_location_map = {}
for s in substations:
    substation_location_map[s] = None

# %%
df_scigrid_substations = pd.read_csv('vertices_eu_power_160718.csvdata', delimiter=',', quotechar="'")
df_scigrid_substations = df_scigrid_substations[df_scigrid_substations.typ == 'substation']
df_scigrid_substations = df_scigrid_substations.dropna(subset=['name'])
df_scigrid_substations = df_scigrid_substations[[
    'lon', 'lat', 'name', 'operator'
]]

# %%
scigrid_substations = df_scigrid_substations.name
scigrid_substations = list(map(str.lower, scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique de ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique du ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste électrique des', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("poste électrique d'", ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace('poste de ', ''), scigrid_substations))
scigrid_substations = list(map(lambda s: s.replace("poste d'", ''), scigrid_substations))

sorted(scigrid_substations)
# Out:
# [' mazures',
#  '150 kv enstedværket',
#  '150 kv holsted',
#  '220 kv-umspannwerk birkenfeld',
#  '220-kv-umspannwerk eichstetten',
#  '220-kv-umspannwerk kuppenheim',
#  '220kv bergum',
#  '220kv groningen vierverlaten',
#  '380 kv borssele',
#  '380 kv gölbaşı tm',
#  '380-kv-umspannwerk eichstetten',
#  '380-kv-umspannwerk großgartach',
#  '380kv avelgem',
#  '380kv diemen',
#  '380kv geertruidenberg',
#  '380kv maasbracht',
#  '380kv oostzaan',
#  '380kv-umspannwerk grünkraut',
#  '380kv-umspannwerk pulverdingen',
#  '400 kv endrup',
#  '400 kv fraugde',
#  '400 kv hemsjö',
#  '400 kv idomlund',
#  '400 kv kassø',
#  '400/132 kv hovegård',
#  '400/132 kv ishøj',
#  '400/132/50 kv glentegård',
#  '400/150 kv kingstrup',
#  '400/150kv ferslev',
#  '400kv asnæsværket',
#  '400kv hallsberg',
#  '400kv horred',
#  '400kv koblingsstation revsing',
#  '400kv nybro',
#  '400kv skærbækværket',
#  '400kv/150kv landerupgård',
#  'aathal',
#  'abbenfleth',
#  'abham substation',
#  'acciaiolo',
#  'acea electrabel',
#  'adana tm',
#  'adapazarı-1 dgkç',
#  'adria sud',
#  'afyon-2 380kv tm',
#  'afşin-elbistan a tes tm',
#  'afşin-elbistan b tes 380kv tm',
#  'aghada 220kv substation',
#  'albertirsa alállomás',
#  'albertville',
#  'albrechtice',
#  'alfstedt',
#  'algermissen',
#  'aliano',
#  'allinges',
#  'alverdiscott substation',
#  'amelsbüren',
#  'andırın tm',
#  'apg umspannwerk lienz',
#  'apg umspannwerk westtirol',
#  'arenella',
#  'argoeuves',
#  'arklow',
#  'arnage',
#  'aruküla 330kv alajaam',
#  'asphard',
#  'astroni',
#  'atatürk hes tm',
#  'atlantic',
#  'audorf',
#  'audorf',
#  'aurelia',
#  'aussois',
#  'avelin',
#  'avise',
#  'avoine',
#  'babylon',
#  'baggio',
#  'ballycronan more hvdc static inverter plant',
#  'balti ej alajaam',
#  'bargi',
#  'barnabos',
#  'basf',
#  'bassecourt',
#  'bayet',
#  'bağlum tm',
#  'beaucouzé',
#  'beaumont monteux',
#  'beerfelden',
#  'belle-epine',
#  'belleville sur loire',
#  'bellolampo',
#  'benteler stahlwerk',
#  'bentwisch',
#  'bentwisch hgü',
#  'bergholz',
#  'berlin/mitte',
#  'bertikow',
#  'beuren',
#  'bezaumont',
#  'bezděčín',
#  'beznau',
#  'bickigen',
#  'bickingen',
#  'bicske dél alállomás',
#  'bjæverskov hvdc kontek',
#  'blançon',
#  'bocklemünd',
#  'bois-tollot',
#  'boismorand',
#  'bolène',
#  'bonaduz',
#  'borwin alpha',
#  'borwin beta',
#  'boutre',
#  'bovisio',
#  'bramley substation',
#  'brandenburg-west',
#  'brennilis',
#  'brinsworth switching station',
#  'brokdorf',
#  'brommat 1',
#  'brugherio - smistamento elettrico terna',
#  'bulciago',
#  'bühl',
#  'cabriès realtor',
#  'caen dit de la dronnière',
#  'cagliari sud',
#  'cagno',
#  'calan',
#  'calenzano',
#  'canterbury north substation',
#  'caorso',
#  'caracoli',
#  'carpi fossoli',
#  'casanova',
#  'casellina',
#  'cassano',
#  'castelluccia',
#  'castelnuovo',
#  'caudon',
#  'cellarhead substation',
#  'central eléctrica de alcántara',
#  'centrale bargi',
#  'centrale tirso',
#  'chabrillan',
#  'chaffard',
#  'chaingy',
#  'chamoson',
#  'champagnier',
#  'champagnolle',
#  'chanceaux',
#  'charpenay',
#  'chatillon centrale',
#  'chavanod',
#  'chevallet',
#  'chiaramonte gulfi',
#  'chiari',
#  'chignolo po',
#  'chivasso termica 380kv',
#  'chodov',
#  'chotějovice',
#  'chrást',
#  'châteauneuf-du rhône',
#  'cilf cilfynydd',
#  'ciserano',
#  'cislago',
#  'civaux',
#  'cize',
#  'clashavoon',
#  'cleve hill substation',
#  'cloppenburg 220 kv',
#  'codrongianos',
#  'colunga',
#  'concarneau',
#  'connahs quay substation',
#  'conneforde',
#  'conneforde 110/220 kv',
#  'cordemais-poste',
#  'cordignano',
#  'corduff',
#  'cordéac',
#  'cornier',
#  'corriolo',
#  'coulange',
#  'cowley substation',
#  'cremona',
#  'creney-prés-troyes 225kv',
#  'creney-prés-troyes 400kv',
#  'creys-malville',
#  'crossen',
#  'cruseilles',
#  'cubnezais',
#  'cullenagh 220 kv station',
#  'daines substation',
#  'dambelin',
#  'dambron',
#  'dasný',
#  'denizli osb tm',
#  'didcot substation',
#  'dieffeln',
#  'diele',
#  'dillenburg',
#  'distré',
#  'diyarbakır-3 tm',
#  'dollern',
#  'dolo',
#  'domloup',
#  'dugale',
#  'dunamenti',
#  'dunaújváros transzformátorállomás',
#  'dunstown 400kv substation',
#  'dörnigheim 110 kv',
#  'east claydon substation',
#  'echinghen',
#  'eds',
#  'eesti ej alajaam',
#  'eickum',
#  'eisenach',
#  'eisenhüttenstadt',
#  'electric sub station',
#  'electrical substation',
#  'elektrická stanica lemešany',
#  'elia zandvliet',
#  'elstree substation',
#  'elverlingsen',
#  'emden-borßum',
#  'enbw umspannwerk altbach 1',
#  'enbw umspannwerk bünzwangen',
#  'enbw umspannwerk endersbach',
#  'enbw umspannwerk engstlatt',
#  'enbw umspannwerk laichingen',
#  'enbw umspannwerk wendlingen',
#  'eni power',
#  'entracque',
#  'ercolano',
#  'erzhausen',
#  'esb substation',
#  'eula',
#  'eurallumina',
#  'exeter substation',
#  'fano entroterra',
#  'favara',
#  'feckenham',
#  'ferrara nord',
#  'ferrera erbognone',
#  'fessenheim',
#  'finglas',
#  'fiumesanto carbo 380',
#  'flebour',
#  'fleet substation',
#  'flensburg',
#  'flero',
#  'flers',
#  'foretaille',
#  'forlì via oraziana',
#  'fourstones substation',
#  'frattamaggiore',
#  'freiberg/nord (380 kv)',
#  'freiluftschaltanlage kw schärding-neuhaus',
#  'froloo',
#  'fruges',
#  'fréjus',
#  'fusina termica sezione 1 400',
#  'föhring',
#  'ganderkesee',
#  'gavrelle',
#  'gaziantep-2',
#  'geithe',
#  'gemeinschaftskraftwerk neckarwestheim 2',
#  'germencik 380kv tm',
#  'ghrighine centrale',
#  'givors 1',
#  'givors 2',
#  'gleidingen 220 kv',
#  'godenau',
#  'gorlago',
#  'gorman substation',
#  'grafenrheinfeld',
#  'grande-synthe',
#  'grande-île',
#  'granzay',
#  'graustein',
#  'great island substation',
#  'grisolles',
#  'grosne',
#  'großschwabhausen',
#  'grynau',
#  'grépilles',
#  'gstaad',
#  'gundremmingen',
#  'győr kelet alállomás',
#  'génissiat',
#  'göd alállomás',
#  'göksun skm',
#  'gökçekaya hes tm',
#  'gönyü 400kv alállomás',
#  'görries',
#  'gösgen',
#  'götzdorf',
#  'gørløsegård',
#  'güstrow',
#  'güstrow',
#  'halden',
#  'hamburg nord',
#  'hanekenfähr',
#  'hannover/west',
#  'hardegsen',
#  'harker substation',
#  'harku ajajaam',
#  'hauptumspannwerk menzing',
#  'hengelo',
#  'hennigsdorf',
#  'heysham substation',
#  'hgü baltic-cable - stromrichterstation herrenwyk',
#  'high marnham substation',
#  'horní životice',
#  'houdreville',
#  'hradec',
#  'hutton substation',
#  'hévíz 400/120 kv alállomás',
#  'ilanz',
#  'impp imperial park',
#  'indian queens substation',
#  'ingolstadt',
#  'inhausen',
#  'interconnection de saint-vulbas',
#  'inverkip substation',
#  'iron acton substation',
#  'irsching',
#  'isar',
#  'isp cremona',
#  'issoirre',
#  'ittiri',
#  'itzehoe/west',
#  'iver substation',
#  'izernore',
#  'işıklar tm',
#  'jochenstein',
#  'jævnstrømsstation tjele',
#  'karakaya hes 380kv tm',
#  'karlsruhe-daxlanden',
#  'karlsruhe-west',
#  'karlstein',
#  'kayabaşı 380kv tm',
#  'kayseri skm',
#  'kells',
#  'kemsley substation',
#  'kernkraftwerk unterweser',
#  'kiel-süd',
#  'kiisa alajaam',
#  'killonan 220kv substation',
#  'kilmarnock south substation',
#  'kingsnorth substation',
#  'klein ilsede',
#  'kletné',
#  'knockraha substation',
#  'konti-scan lindome hvdc static inverter',
#  'konya-4 tm',
#  'kraftwerkschaltanlage ibbenbüren',
#  'kraftwerkschaltanlage knapsack 1',
#  'kraftwerkseinspeisung staudinger',
#  'krasíkov',
#  'kriegenbrunn',
#  'križovany',
#  'krümmel',
#  'kummerfeld',
#  'kw heyden',
#  'kw lünersee',
#  'kw neurath',
#  'la bathie',
#  'la boisse',
#  'la capelle',
#  'la casella',
#  'la casella centrale',
#  'la coche',
#  'la corbière',
#  'la doberie',
#  'la gaudière',
#  'la martyre',
#  'la mouche',
#  'la picocherie',
#  'la praz saint-andré',
#  'la spezia',
#  'laboratori cesi chivasso',
#  'lacchiarella',
#  'lachmatt',
#  'lackenby substation',
#  'lahe',
#  'laino',
#  'laleham substation',
#  'landerneau',
#  'landesbergen',
#  'landulph substation',
#  'lanzada',
#  'larino',
#  'larçay',
#  'lastverteilung/schaltanlage kühmoos',
#  'latena',
#  'laufenburg',
#  'launay',
#  'laval',
#  'le breuil',
#  'le broc-carros',
#  'le tricastin',
#  'legacy substation',
#  'leibstadt',
#  'leinì',
#  'les attaques',
#  'les jumeaux',
#  'les mandarins',
#  'les quintes',
#  'lignat',
#  'lindenholz',
#  'lingostière',
#  'litér 400/120 kv alállomás',
#  'lmg',
#  'logis-neuf',
#  'lonato',
#  'longefan',
#  'lonny',
#  'loscoat',
#  'louisfert',
#  'louth substation',
#  'lískovec',
#  'lübeck',
#  'lüneburg',
#  'macclesfield substation',
#  'magadino',
#  'magdeburg (50hertz)',
#  'magherafelt',
#  'magliano',
#  'maleo',
#  'malešice',
#  'malintrat',
#  'mannheim',
#  'mantova',
#  'markersbach',
#  'marlenheim',
#  'marmagne',
#  'martignone',
#  'martonvásár alállomás',
#  'mastaing',
#  'maureix',
#  'mecklar',
#  'meeden',
#  'mehrum (220 kv)',
#  'melksham substation',
#  'menuel',
#  'meppen',
#  'mercallo',
#  'mercure',
#  'mettlen',
#  'milín',
#  'minety',
#  'mions',
#  'mittelbexbach',
#  'moneypoint switching station',
#  'monfalcone sezione 1 400',
#  'montagny-les lanches',
#  'montalto',
#  'montalto centrale',
#  'montecorvino',
#  'montjovet centrale',
#  'montlingen',
#  'montluçon',
#  'mop end substation',
#  'moulaine',
#  'musignano',
#  'mâcon',
#  'méry-sur-seine',
#  'mírovka',
#  'mörschwil',
#  'mühleberg/ost',
#  'mühleberg/west',
#  'münchwilen',
#  'neilston',
#  'neilston',
#  'neoules',
#  'netze bw umspannwerk oberjettingen',
#  'netzleitstelle mutterstadt',
#  'neuenhagen',
#  'neuves maisons',
#  'neznášov',
#  'niederhausen',
#  'niedervieland',
#  'niederwiesa',
#  'niederwil',
#  'nocera',
#  'nogarole rocca',
#  'norton sub station',
#  'nošovice',
#  'obrigheim',
#  'oftringen',
#  'oldstreet substation',
#  'omformerstation herslev',
#  'opočínek',
#  'oraison',
#  'ormalingen',
#  'oroszlány alállomás',
#  'ospiate',
#  'ostiglia',
#  'ostiglia centrale',
#  'otrokovice',
#  'ottana',
#  'otterbach',
#  'oymapınar hes tm',
#  'paide alajaam',
#  'paks alállomás',
#  'palente',
#  'partanna',
#  'partinico',
#  'pasewalk',
#  'patria',
#  'pembroke substation',
#  'penly',
#  'pentir substation',
#  'penwortham substation',
#  'pertain',
#  'peyrat-le-château',
#  'philippsburg 380 kv',
#  'piacenza',
#  'pian camuno',
#  'pian della speranza',
#  'pianezza',
#  'pied-de-borne',
#  'pieve albignola',
#  'piossasco',
#  'plaine-haute',
#  "plan d'orgon",
#  'planais',
#  'plaud',
#  'pleyber-christ',
#  'poggio a caiano',
#  'pont-escoffier',
#  'pontarlier',
#  'pontchâteau',
#  'porto corsini sezione 1',
#  'porto tolle',
#  'poste electrique de landres',
#  'poste électrique henri-paul',
#  'poste électrique rte de eybens',
#  'poteau-rouge',
#  'pozzuoli',
#  'pratclaux',
#  'pressy',
#  'prosenice',
#  'prospect 220kv substation',
#  'préguillac',
#  'pulgar',
#  'pumpspeicherwerk goldisthal',
#  'pusy',
#  'püssi alajaam',
#  'raffeen substation',
#  'rakvere alajaam',
#  'ratsbusch',
#  'redipuglia',
#  'remise',
#  'rennes',
#  'revin',
#  'rfx',
#  'rheinzink',
#  'robbia',
#  'rolampont',
#  'romanel',
#  'roncovalgrande',
#  'rondissone',
#  'roost',
#  'roquerousse',
#  'roselectra',
#  'rosen',
#  'rospez',
#  'rothenbrunnen',
#  'rotonda',
#  'rozvodna kočín',
#  'rozvodna přeštice',
#  'rozvodna čechy střed',
#  'rozvodna řeporyje',
#  'rtp cirkovce',
#  'rtp krško',
#  'rtp maribor',
#  'rtp podlog',
#  'rubiera',
#  'rueyres',
#  'rulhat',
#  'rumianca',
#  'rupperswil',
#  'rzeszów systemowa (widełka) 750/400/110 kv',
#  'révigny sur ornain',
#  'sa bauler',
#  'saint-alban saint-maurice',
#  'saint-auban',
#  'saint-avold',
#  'saint-barthélémy',
#  'saint-cyr-en-val',
#  'saint-eloi',
#  'saint-michel de maurienne',
#  'saint-tulle',
#  'sainte-estève',
#  'sajószöged alállomás',
#  'salerno nord',
#  'salgareda',
#  'salon',
#  'salzgitter-hallendorf',
#  'samim',
#  'samim',
#  'san damaso',
#  'san filippo del mela gruppi 1,2,3,4',
#  'san filippo del mela gruppi 5 e 6',
#  'san fiorano',
#  'san martino in xx',
#  'san rocco po',
#  'san sebastiano',
#  'san severo',
#  'san valentino',
#  'sandershausen',
#  'sandrigo',
#  "sanssac l'église",
#  "sant'antimo",
#  'santa barbara',
#  'santa lucia',
#  'sarlux',
#  'sarrans',
#  'sautet',
#  'schaltanlage datteln 4',
#  'schaltanlage leupolz',
#  'schaltanlage ovenstädt',
#  'schaltanlage tavanasa',
#  'scheer',
#  'schwandorf',
#  'schweinfurt',
#  'sedrun',
#  'selargius',
#  'sellindge converter station',
#  'senica',
#  'sermide',
#  'serre-ponçon',
#  'setzer wiese',
#  'seuil',
#  'seydişehir tm',
#  'seyitömer tes tm',
#  'siedenbrünzow',
#  'sierentz',
#  'siersdorf',
#  'sinard',
#  'sincan tm',
#  'sindi alajaam',
#  'sisteron',
#  'slavětice',
#  'sokolnice',
#  'sondrio',
#  'sorgente',
#  'sottostazione elettrica oristano',
#  'sottrum',
#  'sous-station de la herse',
#  'sous-station des mollettes',
#  'sous-station rff de chambaud',
#  'sous-station rff de réaltor',
#  'sous-station sncf de weppes',
#  'sous-station électrique usine rio tinto alcan',
#  'soverzene',
#  'spennymoor substation',
#  'spezia centrale',
#  'squividan',
#  'srananagh sub station',
#  'st.triphon',
#  'stacja elektrenergetyczna 400/110kv "słupsk wierzbięcino"',
#  'stacja elektroenergetyczna "abramowice" 220/110 kv',
#  'stacja elektroenergetyczna "aniołów" 220/110 kv',
#  'stacja elektroenergetyczna "azoty tarnów" 220/110kv',
#  'stacja elektroenergetyczna "białystok" 220/110 kv',
#  'stacja elektroenergetyczna "bieruń" 220/110 kv',
#  'stacja elektroenergetyczna "blachownia" 220/110kv',
#  'stacja elektroenergetyczna "boguchwała" 220/110 kv',
#  'stacja elektroenergetyczna "boguszów" 220/110 kv',
#  'stacja elektroenergetyczna "bujaków" 220kv',
#  'stacja elektroenergetyczna "bydgoszcz zachód" 220/110 kv',
#  'stacja elektroenergetyczna "chełm" 220/110 kv',
#  'stacja elektroenergetyczna "chmielów" 220/110 kv',
#  'stacja elektroenergetyczna "cieplice" 220/110 kv',
#  'stacja elektroenergetyczna "czarna" 400/110 kv',
#  'stacja elektroenergetyczna "czerwonak" 220/110 kv',
#  'stacja elektroenergetyczna "dobrzeń" 400/110 kv',
#  'stacja elektroenergetyczna "dunowo" 400/220/110 kv',
#  'stacja elektroenergetyczna "ełk" 220/110 kv',
#  'stacja elektroenergetyczna "gdańsk błonia" 400/110 kv',
#  'stacja elektroenergetyczna "gdańsk i" 400/220/110 kv',
#  'stacja elektroenergetyczna "glinki" 220/110 kv',
#  'stacja elektroenergetyczna "grudziądz - węgrowo" 400/220/110 kv',
#  'stacja elektroenergetyczna "halemba" 220/110kv',
#  'stacja elektroenergetyczna "huta częstochowa" 220/110 kv',
#  'stacja elektroenergetyczna "jamki" 220/110kv',
#  'stacja elektroenergetyczna "janów" 220/110 kv',
#  'stacja elektroenergetyczna "jasiniec" 220/110 kv',
#  'stacja elektroenergetyczna "katowice" 220/110 kv',
#  'stacja elektroenergetyczna "kielce piaski" 220/110/30/15kv',
#  'stacja elektroenergetyczna "kielce" 400/220kv',
#  'stacja elektroenergetyczna "klikowa" 220/110 kv',
#  'stacja elektroenergetyczna "koksochemia" 220kv',
#  'stacja elektroenergetyczna "komorowice" 220/110 kv',
#  'stacja elektroenergetyczna "konin" 220/110 kv',
#  'stacja elektroenergetyczna "kopanina" 220/110 kv',
#  'stacja elektroenergetyczna "kozienice" 400/220/110 kv',
#  'stacja elektroenergetyczna "krajnik" 400/220 kv',
#  'stacja elektroenergetyczna "krosno iskrzynia" 400/110 kv',
#  'stacja elektroenergetyczna "kędzierzyn" 220/110kv',
#  'stacja elektroenergetyczna "leszno" 220/110 kv',
#  'stacja elektroenergetyczna "leśniów" 220/110 kv',
#  'stacja elektroenergetyczna "lublin" 400/110kv',
#  'stacja elektroenergetyczna "lubocza" 220/110kv',
#  'stacja elektroenergetyczna "miłosna" 400/220/110 kv',
#  'stacja elektroenergetyczna "mory" 220/110kv',
#  'stacja elektroenergetyczna "morzyczyn" 400/220/110 kv',
#  'stacja elektroenergetyczna "mościska" 400/110 kv',
#  'stacja elektroenergetyczna "ostrowiec" 400/110 kv',
#  'stacja elektroenergetyczna "ostrów" 400/110 kv',
#  'stacja elektroenergetyczna "ołtarzew" 400/220/110kv',
#  'stacja elektroenergetyczna "pabianice" 220/110 kv',
#  'stacja elektroenergetyczna "piła krzewina" 220/110 kv',
#  'stacja elektroenergetyczna "plewiska" 400/220/110 kv',
#  'stacja elektroenergetyczna "podolszyce" 220/110kv',
#  'stacja elektroenergetyczna "police" 220/110kv',
#  'stacja elektroenergetyczna "polkowice" 220/110 kv',
#  'stacja elektroenergetyczna "połaniec" 400/220/110kv',
#  'stacja elektroenergetyczna "puławy" 220kv',
#  'stacja elektroenergetyczna "pątnów" 220/110 kv',
#  'stacja elektroenergetyczna "radkowice" 220/110/30/15kv',
#  'stacja elektroenergetyczna "rogowiec" 400/220 kv',
#  'stacja elektroenergetyczna "rokitnica" 400/110kv',
#  'stacja elektroenergetyczna "skawina" 220/110kv',
#  'stacja elektroenergetyczna "sochaczew" 220/110kv',
#  'stacja elektroenergetyczna "towarowa" 220/110/15kv',
#  'stacja elektroenergetyczna "wrocław" 400/110kv',
#  'stacja elektroenergetyczna "wrzosowa" 220/110 kv',
#  'stacja elektroenergetyczna "włocławek azoty" 220/110 kv',
#  'stacja elektroenergetyczna "łagisza" 400/220/110 kv',
#  'stacja elektroenergetyczna "świebodzice" 400 kv',
#  'stacja elektroenergetyczna "żarnowiec" 400/110 kv',
#  'stacja elektroenergetyczna "żukowice" 220/110 kv',
#  'stacja elektroenergetyczna "żydowo" 220/110 kv',
#  'stacja elektroenergetyczna 220/110 kv poznań południe',
#  'stacja elektroenergetyczna 400/220/110kv "ostrołęka"',
#  'stacja elektroenergetyczna adamów 220/110 kv',
#  'stacja elektroenergetyczna kromolice 400/110kv',
#  'stacja elektroenergetyczna „byczyna” 220 kv',
#  'stacja elektroenergetyczna „czeczot” 220/110 kv',
#  'stacja elektroenergetyczna „joachimów” 400/220 kv',
#  'stacja elektroenergetyczna „mikułowa” 400/220/110 kv',
#  'stacja elektroenergetyczna „mokre” 220/110 kv',
#  'stacja elektroenergetyczna „moszczenica” 220/110 kv',
#  'stacja elektroenergetyczna „narew” 400/110 kv',
#  'stacja elektroenergetyczna „olsztyn i” 220/110/15 kv',
#  'stacja elektroenergetyczna „olsztyn mątki” 400/220/110 kv',
#  'stacja elektroenergetyczna „pasikurowice” 400/110 kv',
#  'stacja elektroenergetyczna „piaseczno” 220/110 kv',
#  'stacja elektroenergetyczna „piotrków” 220/110 kv',
#  'stacja elektroenergetyczna „poręba” 220/110 kv',
#  'stacja elektroenergetyczna „płock” 400/110 kv',
#  'stacja elektroenergetyczna „rożki” 220/110 kv',
#  'stacja elektroenergetyczna „siersza” 220/110kv',
#  'stacja elektroenergetyczna „tarnów” 400/110 kv',
#  'stacja elektroenergetyczna „toruń - elana” 220/110 kv',
#  'stacja elektroenergetyczna „trębaczew” 400/110 kv',
#  'stacja elektroenergetyczna „tucznawa” 400/110 kv',
#  'stacja elektroenergetyczna „wanda” 220/110 kv',
#  'stacja elektroenergetyczna „wielopole” 400/220/110 kv',
#  'stacja elektroenergetyczna „zamość” 220/110 kv',
#  'stacja elektroenergetyczna „zgierz” 220/110 kv',
#  'stacja elektroenergetyczna „ząbkowice” 220/110 kv',
#  'stacja elektroenergetyczna „łośnice” 220/110kv',
#  'stacja elektroenergetyczna „świebodzice” 220/110 kv',
#  'stacja energetyczna "groszowice" 220/110 kv',
#  'stade',
#  'stadorf',
#  'stanah substation',
#  'station arpe',
#  'station beeck',
#  'station bergmannsglück',
#  'station bochum',
#  'station bollenacker',
#  'station brauweiler',
#  'station bürstadt',
#  'station büscherhof',
#  'station dahlem',
#  'station dauersberg',
#  'station dhünnaue',
#  'station dülken',
#  'station dünnwald',
#  'station edelstahl krefeld',
#  'station eiberg',
#  'station eiserfeld',
#  'station eller',
#  'station elmenhorst',
#  'station enniger',
#  'station gellep',
#  'station gersteinwerk',
#  'station gohrpunkt',
#  'station gremberghoven',
#  'station gronau',
#  'station halfeshof',
#  'station hambach',
#  'station hamborn',
#  'station handbach',
#  'station hattingen',
#  'station heisdorf',
#  'station hesseln',
#  'station hüllen',
#  'station ibbenbüren',
#  'station karnap',
#  'station kelsterbach',
#  'station knapsack',
#  'station koblenz',
#  'station kruckel',
#  'station kusenhorst',
#  'station laer',
#  'station ließem',
#  'station limburg',
#  'station linde',
#  'station lippborg',
#  'station lippe',
#  'station lüstringen',
#  'station meitingen',
#  'station mengede',
#  'station möllen',
#  'station mündelheim',
#  'station münster',
#  'station nehden',
#  'station niederrhein',
#  'station niederstedem',
#  'station nordlicht',
#  'station norf',
#  'station oberzier',
#  'station ohligs',
#  'station opladen',
#  'station osburg',
#  'station ossenberg',
#  'station osterath',
#  'station osterath',
#  'station paffendorf',
#  'station pfalzdorf',
#  'station pöppinghausen',
#  'station quint',
#  'station rath',
#  'station reisholz',
#  'station rheinau',
#  'station rheinhausen',
#  'station rosenblumendelle',
#  'station roxel',
#  'station ruhrort',
#  'station saarwellingen',
#  'station sankt hülfe',
#  'station sankt peter 220 kv',
#  'station sankt peter 380 kv',
#  'station sechtem',
#  'station selbeck',
#  'station siegburg',
#  'station stockem',
#  'station trier',
#  'station uentrop',
#  'station unna',
#  'station utfort',
#  'station verlautenheide',
#  'station walsum',
#  'station wambel',
#  'station weißenthurm',
#  'station welper',
#  'station wengerohr',
#  'station westerkappeln',
#  'station zensenbusch',
#  'stazione elettrica "ravenna canala"',
#  'stazione elettrica di camin',
#  'stazione elettrica di focomorto',
#  'stazione elettrica marginone',
#  'stazione primaria di edolo',
#  'stella west sub station',
#  'stendal/west',
#  'stenkullen',
#  'strathaven substation',
#  'stupava',
#  'styrum',
#  'subestación de almaraz',
#  'subestación de guillena',
#  'subestação de rio maior',
#  'subestação de sines',
#  'sundon substation',
#  'sursee',
#  'swansea north substation',
#  'swansea north substation',
#  'swansea north substation',
#  'szolnok 220/120/20 kv-os alállomás',
#  'szombathely 400/120 kv alállomás',
#  'sándorfalva alállomás',
#  'tabarderie',
#  'taloro 2',
#  'tamareau',
#  'tandragee',
#  'tarbert 220/110kv substation',
#  'tarbert 220/110kv substation',
#  'tartu alajaam',
#  'taunton substation',
#  'taute',
#  'tavarnuzze',
#  'tavazzano centrale',
#  'tavel',
#  'teksid carmagnola',
#  'temelli tm',
#  'tennet tso gmbh - betriebszentrum lehrte',
#  'terrier',
#  'teufelsbruch',
#  'thurcroft substation',
#  'thyrow',
#  'tiengen',
#  'tierfehd',
#  'tilbury substation',
#  'tirreno power torrevaldaliga',
#  'toponár 400/120 kv alállomás',
#  'torino nord',
#  'torre nord',
#  'torrevaldiga nord',
#  'tourbe',
#  'trans en provence',
#  'travagliato',
#  'trawsfynydd substation',
#  'trevas',
#  'trino centrale',
#  'trollhättan',
#  'trégueux',
#  'ts bilice',
#  'ts ernestinovo',
#  'ts konjsko',
#  'ts mostar',
#  'ts mraclin',
#  'ts tumbri',
#  'ts velebit',
#  'ts žerjavinec',
#  'tsinguliina alajaam',
#  'turano centrale',
#  'turbigo',
#  'turlough hill substation',
#  'tuscania',
#  'tutes şalt tm',
#  'tábor',
#  'týnec',
#  'ua dillinger hütte mitte',
#  'ua obergraben',
#  'udine ovest',
#  'uerdingen',
#  'umrichterwerk neckarwestheim',
#  'umspannanlage ensdorf',
#  'umspannanlage heidelberg-süd',
#  'umspannanlage pfungstadt',
#  'umspannanlage würgassen',
#  'umspannstation bischofsheim',
#  'umspannstation hoheneck amprion',
#  'umspannstation irsingen',
#  'umspannwerk altenfeld',
#  'umspannwerk altheim',
#  'umspannwerk altlußheim',
#  'umspannwerk aschaffenburg',
#  'umspannwerk avegno',
#  'umspannwerk bechterdissen',
#  'umspannwerk bergrheinfeld',
#  'umspannwerk bergshausen',
#  'umspannwerk bidingen nr. 697 s',
#  'umspannwerk bielefeld ost',
#  'umspannwerk biesdorf nord',
#  'umspannwerk bisamberg',
#  'umspannwerk bixterheide',
#  'umspannwerk blankenhagen',
#  'umspannwerk blockland',
#  'umspannwerk borken',
#  'umspannwerk braunschweig nord',
#  'umspannwerk bruchsal-kändelweg',
#  'umspannwerk bärwalde',
#  'umspannwerk bürs',
#  'umspannwerk charlottenburg',
#  'umspannwerk dd-süd',
#  'umspannwerk dellmensingen',
#  'umspannwerk dürnrohr',
#  'umspannwerk elsen',
#  'umspannwerk eltmann',
#  'umspannwerk etzenricht',
#  'umspannwerk farge',
#  'umspannwerk frankfurt nord',
#  'umspannwerk frankfurt südwest',
#  'umspannwerk friedrichshain',
#  'umspannwerk förderstedt',
#  'umspannwerk garenfeld',
#  'umspannwerk gießen nord',
#  'umspannwerk gießen nord',
#  'umspannwerk goldshöfe',
#  'umspannwerk großdalzig',
#  'umspannwerk großkrotzenburg',
#  'umspannwerk gundelfingen',
#  'umspannwerk gurtweil',
#  'umspannwerk hagenwerder',
#  'umspannwerk hamburg-nord',
#  'umspannwerk hamburg/ost',
#  'umspannwerk hamburg/süd',
#  'umspannwerk hattorf',
#  ...]

# %%
substations = list(map(str.lower, substations))
substations = list(map(lambda s: s.replace(' (le)', ''), substations))
substations = list(map(lambda s: s.replace(' (la)', ''), substations))
substations = list(map(lambda s: s.replace(' (les)', ''), substations))

sorted(substations)
# Out:
# [' t.sup / prion - tavel',
#  'abramowice',
#  'achene',
#  'achene sncb',
#  'adamow',
#  'aftakking buggenhout 380kv',
#  'aftakking liefkenshoek 380kv',
#  'aftakking mekingen 380kv',
#  'aftakking rodenhuize 380kv',
#  'aftakking zuttendaal 380kv',
#  'agasses',
#  'airvault',
#  'alba iulia',
#  'albertirsa',
#  'albertville',
#  'albrechtice',
#  'alegro convertor station',
#  'alfstedt',
#  'algermissen',
#  'allinges',
#  'altbach',
#  'altenfeld',
#  'altenkleusheim',
#  'altentreptow/nord',
#  'altentreptow/süd',
#  'altheim',
#  'altlussheim',
#  'amelsbueren',
#  'andre dumont',
#  'aniolow',
#  'anould',
#  'aoste',
#  'aqueducs',
#  'arad',
#  'ardoise (l )',
#  'arefu',
#  'arenc',
#  'argia (bayonne sud)',
#  'argiesans',
#  'argoeuves',
#  'arlod',
#  'arnage',
#  'arpe',
#  'arrighi',
#  'aschach',
#  'aschaffenburg',
#  'asslar',
#  'attaques',
#  'aubange',
#  'aube',
#  'aubusson',
#  'audorf',
#  'audorf/s',
#  'aulnoye',
#  'aussois',
#  'auzat',
#  'avallon',
#  'avelgem',
#  'avelin',
#  'avignon (poste)',
#  'avoine',
#  'avoine (poste 400 kv)',
#  'awirs',
#  'babylon',
#  'bacalan',
#  'bacau sud',
#  'bacharach',
#  'baia mare 3',
#  'baixas',
#  'balaruc',
#  'balma (poste)',
#  'barbosi',
#  'barbuise',
#  'barjac',
#  'barnabos',
#  'baru mare',
#  'basf',
#  'bastillac',
#  'bastogne',
#  'batzendorf',
#  'bauler',
#  'bauler',
#  'bayer',
#  'bayet',
#  'beauchamps',
#  'beaulieu',
#  'beaumont-monteux',
#  'beauregard (saint-laurent-nouan)',
#  'beautor (poste)',
#  'bec',
#  'bechterdissen',
#  'bekescsaba',
#  'belle-de-mai',
#  'belle-epine',
#  'belval',
#  'benteler',
#  'bentwisch',
#  'berchem ',
#  'berge',
#  'bergholz',
#  'bergmannsglueck',
#  'bergrheinfeld/w',
#  'bergshausen',
#  'bergum',
#  'bergum ',
#  'bericevo',
#  'berneau',
#  'bertikow',
#  'bertrange',
#  'bertrange ',
#  'beuren',
#  'beverwijk',
#  'bezaumont',
#  'bezdecin',
#  'beziers-est',
#  'bezon',
#  'biancon',
#  'bicske del',
#  'bierun',
#  'bilice',
#  'birkenfeld',
#  'bisamberg',
#  'bischofsheim',
#  'bissy',
#  'bixterheide',
#  'blachownia',
#  'bleiswijk',
#  'bleiswijk ',
#  'blocaux',
#  'blockland',
#  'blooren ',
#  'bochum',
#  'bocklemuend',
#  'boctois',
#  'boguchwala',
#  'boguszow',
#  'bois-tollot',
#  'boisse',
#  'bollenacker',
#  'bollene (poste reseau)',
#  'bonneau',
#  'bonnieres',
#  'borken',
#  'borssele',
#  'bosaca',
#  'boudeyre',
#  'boule',
#  'bourguignon',
#  'boutre',
#  'boxmeer ',
#  'bradu',
#  'brailly-cornehotte',
#  'brasov',
#  'braud',
#  'braunschweig/n',
#  'brauweiler',
#  'brazi vest',
#  'brennilis',
#  'brens (cnr)',
#  'breuil',
#  'breukelen kortrijk',
#  'brinje',
#  'broc-carros',
#  'brode',
#  'brokdorf',
#  'bruchsal/kaendelweg',
#  'bruegel',
#  'bruges',
#  'brume',
#  'brume sncb',
#  'brunsbuettel',
#  'brunsbüttel',
#  'bucuresti sud',
#  'buehl',
#  'buenzwangen',
#  'buers',
#  'buerstadt',
#  'buescherhof',
#  'buettel',
#  'buire',
#  'buj',
#  'bujakow',
#  'buttes-chaumont',
#  'byczyna',
#  'bydgoszcz za',
#  'bystricany',
#  'bärwalde',
#  'bürs',
#  'c. stred',
#  'caen',
#  'calafat',
#  'calan',
#  'calea aradului',
#  'campia turzii',
#  'cantegrit',
#  'capelle',
#  'carrieres',
#  'castelle',
#  'castellet',
#  'cazaril',
#  'cebin',
#  'centrale coo',
#  'cergy',
#  'cernavoda',
#  'cernay',
#  'cestas',
#  'cetate',
#  'chabossiere',
#  'chaffard',
#  'chaingy',
#  'chalon',
#  'chambry',
#  'champagnier',
#  'champagnole',
#  'champfleur',
#  'champion (namur)',
#  'champs-regnaud',
#  'champvans',
#  'chanceaux',
#  'chancenay',
#  'charenton',
#  'charlottenburg',
#  'charpenay',
#  'chateau-gombert',
#  'chateauneuf-du-rhone',
#  'chateaurenard',
#  'chaussee',
#  'chavanod',
#  'chelm',
#  'chesnoy',
#  'chevalet',
#  'chevilly',
#  'chevire',
#  'chmielow',
#  'chodov',
#  'cholet',
#  'chooz',
#  'chotejovice',
#  'chrast',
#  'cieplice',
#  'cierny vah',
#  'cirkovce',
#  'cirolliers',
#  'cissac',
#  'cize',
#  'cleon',
#  'clerac',
#  'cloppenburg',
#  'cluj est',
#  'cluj floresti',
#  'coche',
#  'colayrac',
#  'commerveil',
#  'compiegne',
#  'concarneau',
#  'confluent',
#  'conneforde',
#  'conneforde/o',
#  'constanta nord',
#  'contamine',
#  'coquainvilliers',
#  'corbiere',
#  'cordemais-poste',
#  'coriolis',
#  'cornier',
#  'cossigny',
#  'couchey',
#  'coudon',
#  'coulange',
#  'courcelles',
#  'courrieres',
#  'courtry',
#  'craiova nord',
#  'crayestein ',
#  'crechets',
#  'creney',
#  'cretaine',
#  'creys',
#  'croisiere',
#  'croix-de-metz',
#  'cubnezais',
#  'cusset-poste',
#  'custine',
#  'czarna',
#  'czeczot',
#  'czerwonak',
#  'd. mostistea',
#  'dambron',
#  'damery',
#  'dantou',
#  'darse',
#  'darste',
#  'dasny',
#  'datteln',
#  'dauersberg',
#  'daxlanden',
#  'dechy',
#  'dellmensingen',
#  'detk',
#  'dettingen',
#  'diefflen',
#  'diele',
#  'diemen',
#  'digue-des-francais',
#  'dillenburg',
#  'dipperz',
#  'distre',
#  'divaca',
#  'doberie',
#  'dobrzen',
#  'dodewaard',
#  'doekegat ',
#  'doel',
#  'doernigheim',
#  'doerpen west',
#  'doerpen/w',
#  'doetinchem',
#  'dollern',
#  'domloup',
#  'domnesti',
#  'donzac',
#  'donzenac',
#  'draganesti olt',
#  'dreibein mellach',
#  'dresden/süd',
#  'drogenbos',
#  'dronniere',
#  'duelken',
#  'duennwald',
#  'duernrohr',
#  'dumbrava',
#  'dunamenti',
#  'dunowo',
#  'duvigneau',
#  'echalas',
#  'echinghen',
#  'edelstahl',
#  'eeklo noord',
#  'eemshaven',
#  'eemshaven ',
#  'eemshaven het hogeland',
#  'eemshaven oost',
#  'eemshaven oude schip',
#  'eguzon',
#  'eiberg',
#  'eichstetten',
#  'eickum',
#  'eindhoven',
#  'eindhoven ',
#  'eisenach',
#  'eisenhüttenstadt',
#  'eisenhüttenstadt (abzweig)',
#  'eiserfeld',
#  'elancourt',
#  'elk',
#  'elk bis',
#  'eller',
#  'elmenhorst',
#  'elsen',
#  'elsfleth/w',
#  'eltmann',
#  'emden/borssum',
#  'emden/o',
#  'emscherbruch',
#  'enco-de-botte',
#  'endersbach',
#  'engstlatt',
#  'enniger',
#  'ens',
#  'ensdorf',
#  'enval',
#  'ernestinovo',
#  'ernsthofen',
#  'erzhausen',
#  'escaillon (l )',
#  'etival',
#  'etupes',
#  'etzenricht',
#  'etzersdorf',
#  'eula',
#  'eybens',
#  'fai',
#  'fallou',
#  'famars',
#  'fantanele',
#  'farge',
#  'farradiere',
#  'faux frenais',
#  'fedderwarden',
#  'feistritz',
#  'felsozsolca',
#  'ferouge',
#  'feuillane',
#  'filesti',
#  'flandre',
#  'fleac',
#  'flebour',
#  'flebour ',
#  'flers',
#  'fleyriat',
#  'floirac',
#  'florensac',
#  'focsani vest',
#  'font',
#  'fosses',
#  'fouscais',
#  'frankfurt',
#  'frankfurt/n',
#  'frankfurt/sw',
#  'frasne',
#  'freiberg/nord',
#  'frejus',
#  'friedrichshain',
#  'froncles',
#  'fruges',
#  'fuehlingen',
#  'fundeni ',
#  'fwh-s',
#  'förderstedt',
#  'gabcikovo',
#  'gadalin',
#  'galceag',
#  'galoreaux',
#  'gampaloup',
#  'ganderkesee',
#  'ganges',
#  'garchizy',
#  'garenfeld',
#  'gatinais',
#  'gaudiere',
#  'gauglin',
#  'gavrelle',
#  'gdansk',
#  'gdansk przyjazn',
#  'gdansk-bloni',
#  'geertruidenberg',
#  'geertruidenberg ',
#  'geithe',
#  'gellep',
#  'gelsenberg',
#  'genissiat-poste',
#  'gersteinwerk',
#  'gezelle',
#  'gheorgheni',
#  'ghizdaru',
#  'giessen/n',
#  'ginestous',
#  'givors',
#  'givors-bans',
#  'gkm',
#  'gkmb',
#  'gkn2',
#  'gleidingen',
#  'glinki',
#  'god',
#  'godenau',
#  'godin',
#  'goettingen',
#  'goetzdorf',
#  'gohrpunkt',
#  'goldshoefe',
#  'gonyu',
#  'gorzow',
#  'gourjade',
#  'gouy',
#  'gradiste',
#  'grafenrheinfeld',
#  'graffenstaden',
#  'gramme',
#  'grand-coeur',
#  'grand-couronne',
#  'grand-quevilly',
#  'grande-ile',
#  'grande-synthe',
#  'grandval',
#  'gransee',
#  'granzay',
#  'graustein',
#  'gremberghoven',
#  'grepilles',
#  'greuth',
#  'grezillac',
#  'grille-avoine',
#  'grimaud',
#  'grisolles',
#  'grohnde',
#  'gronau',
#  'gros-caillou',
#  'grosne',
#  'grossgartach',
#  'grossgartach ',
#  'grossgartach  2',
#  'grosskrotzenburg',
#  'groszowice',
#  'großkrotzenburg',
#  'grudziadz',
#  'gruenkraut',
#  'guarbecque',
#  'guebwiller',
#  'guetersloh',
#  'gueugnon',
#  'gundelfingen',
#  'gupie',
#  'gura ialomitei',
#  'gura ialomitei ',
#  'gurtweil',
#  'gutinas',
#  'gyor',
#  'görries',
#  'güstrow',
#  'h. zdana',
#  'h. zivotice',
#  'h.zivotice',
#  'hagenwerder',
#  'halemba',
#  'halfeshof',
#  'hallendorf',
#  'hamborn',
#  'hamburg/n',
#  'hamburg/nord',
#  'hamburg/ost',
#  'hamburg/s',
#  'hamburg/süd',
#  'handewitt',
#  'hanekenfaehr',
#  'hannover/w',
#  'harcourt (poste blinde)',
#  'hardegsen',
#  'hasdat',
#  'hattingen',
#  'hattorf',
#  'hausruck',
#  'havre (poste)',
#  'heide/w',
#  'heidelberg',
#  'heilbronn',
#  'heinersdorf',
#  'heinersdorf (abzweig)',
#  'heinsch',
#  'heisdorf ',
#  'helmstedt',
#  'hengelo',
#  'hennigsdorf',
#  'henri-paul',
#  'herbertingen',
#  'herie-la-vieville',
#  'herrenwyk',
#  'herse(la)',
#  'hesseln',
#  'hessenberg',
#  'hessenweg',
#  'heviz',
#  'hoepfingen',
#  'hoheneck',
#  'holque',
#  'homburg',
#  'horta',
#  'houdreville',
#  'houffalize',
#  'hourat',
#  'hradec',
#  'hueffenhardt',
#  'huellen',
#  'huntorf',
#  'husum/n',
#  'huta czestochowa',
#  'iaz',
#  'ibbenbueren',
#  'iernut',
#  'ile-napoleon',
#  'ingolstadt',
#  'inhausen',
#  'irsching',
#  'isaccea',
#  'isalnita',
#  'isalnita ',
#  'isar',
#  'issel',
#  'issoire',
#  'itzehoe/w',
#  'izegem',
#  'izernore',
#  'j. bohunice',
#  'jacquard',
#  'jalis',
#  'jamki',
#  'janow',
#  'jardelund',
#  'jasiniec',
#  'jessen/nord',
#  'joachimow',
#  'jochenstein',
#  'jonquieres',
#  'joux-la-ville',
#  'jozsa',
#  'jumeaux',
#  'jupille',
#  'kainachtal',
#  'kallo',
#  'karben',
#  'karlsruhe',
#  'karlsruhewest',
#  'karnap',
#  'katowice',
#  'kedzierzyn',
#  'kelsterbach',
#  'kembs',
#  'kerepes',
#  'kiel/s',
#  'kiel/w',
#  'kielce',
#  'kielce piaski',
#  'kisvarda',
#  'klaus',
#  'klece',
#  'kledering',
#  'klein ilsede',
#  'kletne',
#  'klikowa',
#  'klostermansfeld',
#  'knapsack',
#  'koblenz',
#  'kocin',
#  'koksochemia',
#  'komorowice',
#  'konin',
#  'konjsko',
#  'kopanina',
#  'kosice',
#  'kottigerhook',
#  'kozienice',
#  'krajnik',
#  'krasikov',
#  'kriegenbrunn',
#  'kriftel',
#  'krimpen a/d ijssel',
#  'krizovany',
#  'kromolice',
#  'kronstorf',
#  'krosno iskrzynia',
#  'krsko',
#  'kruckel',
#  'kruemmel',
#  'kruen',
#  'krümmel',
#  'kuehmoos',
#  'kuehtai',
#  'kummerfeld',
#  'kupferzell',
#  'kuppenheim',
#  'kusenhorst',
#  'l. mara',
#  'la troque',
#  'lacu sarat',
#  'laer',
#  'lage',
#  'lagisza',
#  'laichingen',
#  'lambsheim',
#  'landerneau',
#  'landesbergen',
#  'landres',
#  'laneuveville',
#  'lannemezan',
#  'larcay',
#  'latena',
#  'latour',
#  'lauchstädt',
#  'launay',
#  'lavera',
#  'laveyrune',
#  'le val',
#  'lechhausen',
#  'leguevin',
#  'lehrte',
#  'lelystad',
#  'lelystad ',
#  'lemesany',
#  'lescar',
#  'lesniow',
#  'lesquive',
#  'leszno',
#  'leupolz',
#  'levi',
#  'levice',
#  'lienz',
#  'liessem',
#  'lignat',
#  'lillo',
#  'limburg',
#  'limeux',
#  'linde',
#  'lingostiere',
#  'lint',
#  'lippborg',
#  'lippe',
#  'liskovec',
#  'liter',
#  'liviere',
#  'lixhe',
#  'logelbach',
#  'loges',
#  'logis-neuf',
#  'lomza systemowa',
#  'long-champ',
#  'longefan',
#  'longuenesse',
#  'lonny',
#  'loscoat',
#  'losnice',
#  'lotru',
#  'louisfert',
#  'louwsmeer',
#  'lublin',
#  'lubmin',
#  'lubocza',
#  'ludersheim',
#  'luebeck',
#  'lueneburg',
#  'luestringen',
#  'lumes',
#  'lutterbach',
#  'lüdershagen',
#  'maade',
#  'maasbracht',
#  'maasvlakte',
#  'macon',
#  'maerlant',
#  'malchow',
#  'malesice',
#  'malgovert',
#  'malintrat',
#  'mambelin',
#  'mandarins',
#  'manoir',
#  'marbach',
#  'marcourt',
#  'margeride',
#  'maribor',
#  'marienberg',
#  'mariselu',
#  'marke',
#  'marlenheim',
#  'marmagne',
#  'marquis',
#  'marsillon',
#  'martonvasar',
#  'martyre',
#  'marzahn',
#  'masquet',
#  'massenhoven',
#  'mastaing',
#  'maubeuge',
#  'mauges',
#  'maureix',
#  'maximiliansau',
#  'mayrhofen',
#  'mazures',
#  'mechlenreuth',
#  'meckenheim',
#  'mecklar',
#  'medgidia sud',
#  'meduric',
#  'medzibrod',
#  'meeden',
#  'meerhout',
#  'mehrum',
#  'meissen',
#  'meitingen',
#  'melina',
#  'mengede',
#  'menuel',
#  'meppen',
#  'mercator',
#  'merlatiere',
#  'mery-sur-seine',
#  'mettmann',
#  'metzingen',
#  'mezerolles',
#  'miegebat',
#  'mikulowa',
#  'milin',
#  'milosna',
#  'mintia',
#  'mions',
#  'mirovka',
#  'mitry-mory (e.d.f.)',
#  'mitte',
#  'mittelbexbach',
#  'mochovce',
#  'mohon',
#  'moimont',
#  'moirans',
#  'mokre',
#  'moldava',
#  'mole',
#  'moliere',
#  'mondion',
#  'montagny-les-lanches',
#  'montcroisette',
#  'montezic (poste exterieur)',
#  'montgros',
#  'montguyon',
#  'montlucon',
#  'montois',
#  'montpellier',
#  'montpezat',
#  'montvicq',
#  'morbras',
#  'moreau',
#  'moru',
#  'mory',
#  'morzyczyn',
#  'mosciska',
#  'moszczenica',
#  'motte (villeneuve-les-avignon)',
#  'mouche',
#  'mougins',
#  'mouguerre',
#  'moulaine',
#  'moulineaux',
#  'mousseaux',
#  'mraclin',
#  'muehlhausen',
#  'muendelheim',
#  'muenster',
#  'muhlbach',
#  'munteni',
#  'mureaux',
#  'mutterstadt',
#  'nadab',
#  'naoutot',
#  'narew',
#  'nehden',
#  'nemours',
#  'neoules',
#  'neuenhagen',
#  'neufinsing',
#  'neurott',
#  'neusiedl',
#  'neuves-maisons',
#  'neznasov',
#  'niederlangen',
#  'niederrhein',
#  'niederstedem',
#  'niederstotzingen',
#  'niedervieland',
#  'niort',
#  'nogentel',
#  'nordlicht',
#  'norf',
#  'nosovice',
#  'nourottes',
#  'novion',
#  'oberbachern',
#  'oberbrunn',
#  'oberhaid',
#  'oberjettingen',
#  'obermooweiler',
#  'oberottmarshausen',
#  'obersielach',
#  'oberwald',
#  'oberzier',
#  'ocsa',
#  'oechtel',
#  'offshore switchyard',
#  'offshore windpark',
#  'ohlensehlen',
#  'ohligs',
#  'okroglo',
#  'olsztyn',
#  'olsztyn matki',
#  'olsztyn-matk',
#  'oltarzew',
#  'onet-le-chateau',
#  'oostzaan',
#  'opladen',
#  'opocinek',
#  'oradea sud',
#  'orangerie (l)',
#  'ormes',
#  'oroszlany',
#  'osburg',
#  'ossenberg',
#  'osterath',
#  'ostroleka',
#  'ostrow wlkp',
#  'ostrowiec',
#  'oststeiermark',
#  'otelarie h',
#  'otrokovice',
#  'ottenhofen',
#  'otterbach',
#  'ottmarsheim',
#  'oudehaske',
#  'oudon',
#  'ovenstaedt',
#  'oxylux ',
#  'p. biskupice',
#  'p. bystrica',
#  'pabianice',
#  'paffendorf',
#  'paks',
#  'palente',
#  'palun',
#  'parchim/süd',
#  'pariset',
#  'paroseni',
#  'pasewalk',
#  'pasikurowice',
#  'passy',
#  'patis',
#  'patnow',
#  'pecs 1',
#  'pecs 2',
#  'pehlin',
#  'pelicanu',
#  'pelissier',
#  'pelplin',
#  'penchard',
#  'penly (poste evacuation)',
#  'perizet',
#  'perkata',
#  'perleberg',
#  'perleberg - putlitz',
#  'pertain',
#  'pessac',
#  'pestis',
#  'pestis ',
#  'petite-rosselle',
#  'peyrat-le-chateau',
#  'pfalzdorf',
#  'pfungstadt',
#  'philippsburg',
#  'phyrn',
#  'piaseczno',
#  'picocherie',
#  'pierrette',
#  'pila krzewina',
#  'piotrkow',
#  'piquage a duvigneau',
#  'piquage a foncrose',
#  'piquage a la praz-st-andre',
#  'piquage a pluvigner',
#  'piquage a saint gerons',
#  'piquage a villiers-le-bel',
#  'pirach',
#  'pitesti sud',
#  'pivoz-cordier',
#  'plaine haute',
#  'plaisance',
#  'plan-d orgon',
#  'plan-de-grasse',
#  'plattling',
#  'plaud',
#  'pleinting',
#  'plessis-gassot',
#  'plewiska',
#  'pleyber-christ',
#  'plock',
#  'plomin',
#  'podlog',
#  'podolszyce',
#  'poeppinghausen',
#  'polaniec',
#  'police',
#  'polkowice',
#  'pont-eveque',
#  'pont-sept',
#  'pont-sur-sambre',
#  'pontarlier',
#  'pontchateau',
#  'ponteau',
#  'porabka-zar',
#  'porcheville',
#  'poreba',
#  'port-de-bouc (client)',
#  'port-jerome',
#  'portet-st-simon',
#  'portile de fier',
#  'portile de fier ',
#  'poste de transition longue vue 220kv',
#  'poteau-rouge',
#  'poznan pld',
#  'praga',
#  'pragneres',
#  'pratclaux',
#  'praz-st-andre',
#  'preguillac',
#  'preilack',
#  'preles',
#  'pressy',
#  'prestice',
#  'primeveres',
#  'prionnet',
#  'prosenice',
#  'puiseux',
#  'pulawy',
#  'pulgar',
#  'pulverdingen',
#  ...]

# %%
s2 = set(scigrid_substations)
s2 = s2.intersection(substations)
print(len(s2))
# Out:
# 174
