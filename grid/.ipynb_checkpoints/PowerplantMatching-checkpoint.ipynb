# %%
import pandas as pd
from scipy import spatial

# %%
df_substations = pd.read_excel('./substations.xlsx', index_col=0)

substation_locs = []
for index, row in df_substations.iterrows():
    substation_locs.append((row.lon, row.lat))
    
substation_tree = spatial.KDTree(substation_locs)

# %%
df_powerplants = pd.read_csv('./powerplants.csv')

relevant_countries = ['Germany', 'Luxembourg', 'Austria', 'Czech Republic', 'Slovenia', 'Belgium', 'Croatia', 'Hungary', 'Poland', 'France', 'Slovakia', 'Romania', 'Netherlands']
country_zone_map = {
    'Germany': 'DE', 
    'Luxembourg': 'DE', 
    'Austria': 'AT', 
    'Czech Republic': 'CZ', 
    'Slovenia': 'SI', 
    'Belgium': 'BE',
    'Croatia': 'HR', 
    'Hungary': 'HU', 
    'Poland': 'PL', 
    'France': 'FR', 
    'Slovakia': 'SK', 
    'Romania': 'RO', 
    'Netherlands': 'NL',
}

df_powerplants = df_powerplants[df_powerplants.Country.isin(relevant_countries)]
df_powerplants['zone'] = df_powerplants.apply(lambda row : country_zone_map[row.Country], axis=1)

display(df_powerplants[(df_powerplants.zone == 'FR') & (df_powerplants.Fueltype == 'Natural Gas')])
print(df_powerplants[(df_powerplants.zone == 'FR') & (df_powerplants.Fueltype == 'Natural Gas')].Capacity.sum())

df_powerplants.Technology.unique()
# Out:
#         id                                Name     Fueltype     Technology  \
# 1014  1014    Debreceni Kombinaltciklusu Eromu  Natural Gas           CCGT
# 1022  1022                     Dunamenti Eromu  Natural Gas           CCGT
# 1032  1032                        Gonyui Eromu  Natural Gas           CCGT
# 1037  1037                       Ujpesti Eromu  Natural Gas           CCGT
# 1038  1038  Nyiregyhazi Kombinaltciklusu Eromu  Natural Gas           CCGT
# 1889  1889                      Tvk Industrial  Natural Gas           CCGT
# 1890  1890                          Sajoszoged  Natural Gas  Steam Turbine
# 1891  1891                               Liter  Natural Gas  Steam Turbine
# 1892  1892                          Borsodchem  Natural Gas  Steam Turbine
# 1925  1925                      Kispesti Eromu  Natural Gas           CCGT
# 1926  1926                    Kelenfoldi Eromu  Natural Gas           CCGT
# 1927  1927                  Alpiq Csepel Eromu  Natural Gas           CCGT
# 3115  3119                                Ajka  Natural Gas  Steam Turbine
# 3197  3201                                 Isd  Natural Gas           CCGT
# 3222  3226                               Matra  Natural Gas  Steam Turbine
# 3224  3228                        Miskolc Hold  Natural Gas           CCGT
# 3228  3232                          North Buda  Natural Gas  Steam Turbine
#
#       Set  Country  Capacity  Efficiency  DateIn  DateRetrofit  DateOut  \
# 1014  CHP  Hungary      95.0         NaN  2000.0           NaN      NaN
# 1022  CHP  Hungary     782.7         NaN  1994.0           NaN      NaN
# 1032   PP  Hungary     426.6        0.59  2011.0           NaN      NaN
# 1037  CHP  Hungary     102.3         NaN  2002.0           NaN      NaN
# 1032  {'ENTSOE': {'15WGONYU-----PP5'}, 'GGPT': {'G40...   HU
# 1037  {'ENTSOE': {'15WUJPEST----PPO'}, 'GGPT': {'G40...   HU
# 1038  {'ENTSOE': {'15WNYKCE-----PP6'}, 'GGPT': {'G40...   HU
# 1889        {'GGPT': {'G400320'}, 'GEO': {'GEO-42681'}}   HU
# 1890        {'GGPT': {'G400319'}, 'GEO': {'GEO-42665'}}   HU
# 1891        {'GGPT': {'G400314'}, 'GEO': {'GEO-42666'}}   HU
# 1892        {'GGPT': {'G400306'}, 'GEO': {'GEO-42682'}}   HU
# 1925  {'ENTSOE': {'15WKISP------PP6'}, 'GGPT': {'G40...   HU
# 1926  {'ENTSOE': {'15WKELENF----PP8'}, 'GGPT': {'G40...   HU
# 1927  {'ENTSOE': {'15WCSEPEL----PPI'}, 'GGPT': {'G40...   HU
# 3115                   {'GGPT': {'G400304', 'G400305'}}   HU
# 3197                              {'GGPT': {'G410435'}}   HU
# 3222                   {'GGPT': {'G400315', 'G400316'}}   HU
# 3224                              {'GGPT': {'G400317'}}   HU
# 3228                              {'GGPT': {'G406351'}}   HU
# 2811.9
# array(['Steam Turbine', 'CCGT', 'Pumped Storage', 'Run-Of-River',
#        'Reservoir', nan, 'Marine', 'Onshore', 'Offshore', 'not found',
#        'Combustion Engine'], dtype=object)

# %%
df_powerplants = pd.read_csv('./powerplants.csv')

relevant_countries = ['Germany', 'Luxembourg', 'Austria', 'Czech Republic', 'Slovenia', 'Belgium', 'Croatia', 'Hungary', 'Poland', 'France', 'Slovakia', 'Romania', 'Netherlands']
country_zone_map = {
    'Germany': 'DE', 
    'Luxembourg': 'DE', 
    'Austria': 'AT', 
    'Czech Republic': 'CZ', 
    'Slovenia': 'SI', 
    'Belgium': 'BE',
    'Croatia': 'HR', 
    'Hungary': 'HU', 
    'Poland': 'PL', 
    'France': 'FR', 
    'Slovakia': 'SK', 
    'Romania': 'RO', 
    'Netherlands': 'NL',
}

df_powerplants = df_powerplants[df_powerplants.Country.isin(relevant_countries)]
df_powerplants['zone'] = df_powerplants.apply(lambda row : country_zone_map[row.Country], axis=1)
df_powerplants = df_powerplants.drop(columns=['id', 'Duration', 'Volume_Mm3', 'StorageCapacity_MWh', 'DamHeight_m', 'DateIn', 'DateRetrofit', 'Country'])

df_powerplants = df_powerplants.rename(columns={
    'Name': 'name', 
    'Fueltype': 'fuel_type',
    'Technology': 'technology',
    'Set': 'set',
    'Capacity': 'capacity',
    'Efficiency': 'efficiency',
    'DateOut': 'date_out',
    'EIC': 'eic',
    'projectID': 'project_id',
})
df_powerplants = df_powerplants.reset_index(drop=True)

# %%
for index, row in df_powerplants.iterrows():
    result = substation_tree.query([(row.lon,row.lat)])
    df_powerplants.loc[index, 'node'] = result[1][0]

# %%
display(df_powerplants)
# Out:
#                       name    fuel_type     technology  set     capacity  \
# 0                  Emsland      Nuclear  Steam Turbine  CHP  1336.000000
# 1                  Mellach    Hard Coal  Steam Turbine  CHP   200.000000
# 2                Eemshaven    Hard Coal           CCGT   PP  1604.170304
# 3             Emile Huchet    Hard Coal           CCGT   PP   596.493211
# 4               Belleville      Nuclear  Steam Turbine   PP  2620.000000
# ...                    ...          ...            ...  ...          ...
# 2160              Sandbank         Wind       Offshore   PP   288.000000
# 2161            Staudinger  Natural Gas           CCGT   PP  1132.000000
# 2162        Westermeerwind         Wind       Offshore   PP   144.000000
# 2163         Wikinger Prod         Wind       Offshore   PP   350.000000
# 2164  Windpark Nordsee One         Wind       Offshore   PP   332.000000
#
#       efficiency  date_out        lat        lon  \
# 0           0.33    2022.0  52.481878   7.306658
# 1            NaN    2020.0  46.911700  15.488300
# 2           0.58    2029.0  53.440500   6.861200
# 3            NaN    2022.0  49.152500   6.698100
# 4            NaN    2028.0  47.508790   2.875740
# ...          ...       ...        ...        ...
# 2160         NaN       NaN  51.165691  10.451526
# 2161         NaN       NaN  51.165691  10.451526
# 2162         NaN       NaN  52.132633   5.291266
# 2163         NaN       NaN  51.165691  10.451526
# 2164         NaN       NaN  56.511018   3.515625
#
#                                            eic  \
# 0                         {'11WD7KKE-1K--KW5'}
# 1                         {'14W-WML-KW-----0'}
# 2                         {'49W000000000044-'}
# 3     {'17W100P100P0345B', '17W100P100P0344D'}
# 4     {'17W100P100P01865', '17W100P100P01857'}
# ...                                        ...
# 2160                      {'11WD2OWS0000352F'}
# 2161                      {'11WD2STAU0001800'}
# 2162                      {'49W0000000001411'}
# 2163                      {'11W0-0000-0026-Y'}
# 2164                      {'11W0-0000-0029-P'}
#
#                                              project_id zone  node
# 0     {'ENTSOE': {'11WD7KKE-1K--KW5'}, 'OPSD': {'BNA...   DE   343
# 1     {'BEYONDCOAL': {'BEYOND-AT-11'}, 'ENTSOE': {'1...   AT  1091
# 2     {'BEYONDCOAL': {'BEYOND-NL-12'}, 'ENTSOE': {'4...   NL   818
# 3     {'BEYONDCOAL': {'BEYOND-FR-67'}, 'ENTSOE': {'1...   FR   446
# 4     {'ENTSOE': {'17W100P100P01865', '17W100P100P01...   FR  1085
# ...                                                 ...  ...   ...
# 2160                   {'ENTSOE': {'11WD2OWS0000352F'}}   DE  1472
# 2161                   {'ENTSOE': {'11WD2STAU0001800'}}   DE  1472
# 2162                   {'ENTSOE': {'49W0000000001411'}}   NL    76
# 2163                   {'ENTSOE': {'11W0-0000-0026-Y'}}   DE  1472
# 2164                   {'ENTSOE': {'11W0-0000-0029-P'}}   DE   841
#
# [2165 rows x 13 columns]

# %%
df_powerplants.to_excel("power_plants.xlsx")
