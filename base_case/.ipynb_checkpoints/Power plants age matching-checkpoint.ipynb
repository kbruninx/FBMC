# %%
import pandas as pd
import json

# %%
df_plants = pd.read_excel('../flow_based_domain/plants.xlsx', index_col=0)
df_powerplants = pd.read_csv('../grid/powerplants.csv')

relevant_countries = ['Germany', 'Luxembourg', 'Austria', 'Czech Republic', 'Slovenia', 'Belgium', 'Croatia', 'Hungary', 'Poland', 'France', 'Slovakia', 'Romania', 'Netherlands']
country_zone_map = {
    'Germany': 'DE', 
    'Luxembourg': 'DE', 
    'Austria': 'AT', 
    'Czech Republic': 'CZ', 
    'Slovenia': 'SI', 
    'Belgium': 'BE',
    'Croatia': 'HR', 
    'Hungary': 'HU', 
    'Poland': 'PL', 
    'France': 'FR', 
    'Slovakia': 'SK', 
    'Romania': 'RO', 
    'Netherlands': 'NL',
}

df_powerplants = df_powerplants[df_powerplants.Country.isin(relevant_countries)]
df_powerplants['zone'] = df_powerplants.apply(lambda row : country_zone_map[row.Country], axis=1)
df_powerplants = df_powerplants[~df_powerplants.DateIn.isna()]

# %%
df_powerplants['projectID'] = df_powerplants['projectID'].astype('object')
for index, plant in df_powerplants.iterrows():
    if plant['projectID'] != None:
        project = eval(plant['projectID'])
        if 'ENTSOE' in project:
            df_powerplants.at[index, 'projectID'] = list(project['ENTSOE'])
        else:
            df_powerplants.loc[index, 'projectID'] = None
    else:
        df_powerplants.loc[index, 'projectID'] = None

# %%
display(df_powerplants[~df_powerplants.projectID.isna()])
# Out:
#         id                    Name     Fueltype     Technology  Set  \
# 0        0                 Emsland      Nuclear  Steam Turbine  CHP
# 1        1                 Mellach    Hard Coal  Steam Turbine  CHP
# 2        2               Eemshaven    Hard Coal           CCGT   PP
# 3        3            Emile Huchet    Hard Coal           CCGT   PP
# 5        5              Belleville      Nuclear  Steam Turbine   PP
# ...    ...                     ...          ...            ...  ...
# 2678  2679  Industriekraftwerk Pck          Oil  Steam Turbine   PP
# 2695  2696        Herrenhausen Kwh  Natural Gas           CCGT   PP
# 2696  2697                 Hamborn    Hard Coal           CCGT   PP
# 2697  2699              Cycofos Tv        Other            NaN   PP
# 3071  3075                   Tychy    Hard Coal            NaN   PP
#
#           Country     Capacity  Efficiency  DateIn  DateRetrofit  DateOut  \
# 0         Germany  1336.000000    0.330000  1988.0        1988.0   2022.0
# 1         Austria   200.000000         NaN  1986.0        1986.0   2020.0
# 2     Netherlands  1604.170304    0.580000  2015.0           NaN   2029.0
# 3          France   596.493211         NaN  1958.0        2010.0   2022.0
# 5          France  2620.000000         NaN  1987.0           NaN   2028.0
# ...           ...          ...         ...     ...           ...      ...
# 2678      Germany   359.000000    0.382473  1972.0        2011.0      NaN
# 2695      Germany   100.000000    0.357500  1975.0        1975.0      NaN
# 2696      Germany   385.000000         NaN  1958.0        2003.0      NaN
# 2697       France    62.000000         NaN  2009.0        2009.0      NaN
# 3071       Poland   142.900228         NaN  2003.0           NaN      NaN
#
#             lat        lon  Duration  Volume_Mm3  DamHeight_m  \
# 0     52.481878   7.306658       NaN         0.0          0.0
# 1     46.911700  15.488300       NaN         0.0          0.0
# 2     53.440500   6.861200       NaN         0.0          0.0
# 3     49.152500   6.698100       NaN         0.0          0.0
# 5     47.508790   2.875740       NaN         0.0          0.0
# ...         ...        ...       ...         ...          ...
# 2678  53.098180  14.234540       NaN         0.0          0.0
# 2695  52.420000   9.648611       NaN         0.0          0.0
# 2696  51.494201   6.728433       NaN         0.0          0.0
# 2697  43.428010   4.886520       NaN         0.0          0.0
# 3071  50.106300  19.014300       NaN         0.0          0.0
#
#       StorageCapacity_MWh                                       EIC  \
# 0                     0.0                      {'11WD7KKE-1K--KW5'}
# 1                     0.0                      {'14W-WML-KW-----0'}
# 2                     0.0                      {'49W000000000044-'}
# 3                     0.0  {'17W100P100P0345B', '17W100P100P0344D'}
# 5                     0.0  {'17W100P100P01865', '17W100P100P01857'}
# ...                   ...                                       ...
# 2678                  0.0                      {'11WD8SCHW5X----D'}
# 2695                  0.0                      {'11WD2HERR5GKW--1'}
# 2696                  0.0                      {'11WD7BEEC5XHAKW5'}
# 2697                  0.0                      {'17W100P100P0352E'}
# 3071                  0.0                      {'19W000000000197M'}
#
#                                  projectID zone
# 0                       [11WD7KKE-1K--KW5]   DE
# 1                       [14W-WML-KW-----0]   AT
# 2                       [49W000000000044-]   NL
# 3     [17W100P100P0345B, 17W100P100P0344D]   FR
# 5     [17W100P100P01865, 17W100P100P01857]   FR
# ...                                    ...  ...
# 2678                    [11WD8SCHW5X----D]   DE
# 2695                    [11WD2HERR5GKW--1]   DE
# 2696                    [11WD7BEEC5XHAKW5]   DE
# 2697                    [17W100P100P0352E]   FR
# 3071                    [19W000000000197M]   PL
#
# [375 rows x 20 columns]
