# %%
from entsoe import EntsoePandasClient
import pandas as pd
import matplotlib.pyplot as plt

client = EntsoePandasClient(api_key="b18dfce9-f1e3-4d07-822f-4abd1438e602")

# %%
start = pd.Timestamp('20220901', tz='Europe/Amsterdam')
end = pd.Timestamp('20230228', tz='Europe/Amsterdam')

countries = ['AT', 'BE', 'CZ', 'DE_LU', 'FR', 'HR', 'HU', 'NL', 'PL', 'RO', 'SI', 'SK']

# %%
df_demand = pd.DataFrame()
for country_code in countries:
    df_da = client.query_load(country_code, start=start, end=end)
    print(country_code)

    df_da = df_da.rename(columns={
        'Actual Load': country_code, 
    })
    
    df_da = df_da.tz_localize(None)
    df_da = df_da.resample("H").agg(["mean"])
    df_da.columns = [country_code]
    
    if df_demand.empty:
        df_demand = df_da.copy()
    else:
        df_demand[country_code] = df_da[country_code]
        
df_demand.to_excel("demand.xlsx")
# Out:
# AT
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 10
#       4 print(country_code)
#       6 df_da = df_da.rename(columns={
#       7     'Actual Load': country_code,
#       8 })
# ---> 10 df_da.index = pd.to_datetime(df_da.indez)
#      11 df_da = df_da.tz_localize(None)
#      12 df_da = df_da.resample("H").agg(["mean"])
#
# File ~\FBMC\fbmc_env\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'indez'

# %%
display(df_demand)
# Out:
#                           AT        BE      CZ     DE_LU       FR      HR  \
# 2023-03-14 00:00:00  6120.75   8689.50  6690.0  51658.50  47797.0  1679.0
# 2023-03-14 01:00:00  5867.00   8348.00  6719.0  48576.00  46569.0  1570.0
# 2023-03-14 02:00:00  5775.50   7918.00  6612.0  47201.75  45837.0  1501.0
# 2023-03-14 03:00:00  5723.50   7965.25  6482.0  48572.00  43549.0  1484.0
# 2023-03-14 04:00:00  5909.25   8218.75  6631.0  49912.50  43204.0  1526.0
# 2023-03-14 05:00:00  6564.75   8646.25  7166.0  53548.00  45951.0  1675.0
# 2023-03-14 06:00:00  7592.25   9528.50  8073.0  60205.50  51337.0  1987.0
# 2023-03-14 07:00:00  8308.75  10196.25  8558.0  64712.50  55435.0  2208.0
# 2023-03-14 08:00:00  8520.00  10507.75  8636.0  67361.50  57564.0  2259.0
# 2023-03-14 09:00:00  8475.25  10942.00  8688.0  68424.00  57871.0  2289.0
# 2023-03-14 10:00:00  8471.75  11049.00  8677.0  69897.00  57418.0  2259.0
# 2023-03-14 11:00:00  8402.25  11172.50  8724.0  70871.25  57531.0  2289.0
# 2023-03-14 12:00:00  8112.25  11221.50  8862.0  71361.75  56176.0  2289.0
# 2023-03-14 13:00:00  8031.00  11409.25  8852.0  69303.25  54059.0  2297.0
# 2023-03-14 14:00:00  7935.25  10835.00  8583.0  67809.00  54097.0  2234.0
# 2023-03-14 15:00:00  7916.75  10603.25  8510.0  66889.75  53418.0  2194.0
# 2023-03-14 16:00:00  7970.25  10391.00  8355.0  65848.75  52394.0  2220.0
